# %%
try ssh

# %%
import os, random, glob
import numpy as np
import pandas as pd
from PIL import Image
from sklearn.model_selection import train_test_split
from sklearn.metrics import log_loss
from sklearn.preprocessing import LabelEncoder

import matplotlib.pyplot as plt
from matplotlib import ticker
import seaborn as sns
# %matplotlib inline 

from keras.models import Sequential, Model, load_model
from keras.layers import GlobalAveragePooling2D, Flatten, Dropout, Dense
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, TensorBoard
from keras.preprocessing.image import ImageDataGenerator
from keras.utils import np_utils
from keras import backend as K
# Out:
# Using TensorFlow backend.

# %%
TRAIN_DIR = '../data/train/'
TEST_DIR = '../data/test_stg1/'
FISH_CLASSES = ['ALB', 'BET', 'DOL', 'LAG', 'NoF', 'OTHER', 'SHARK', 'YFT']
ROWS = 224
COLS = 224
BatchSize = 64
LearningRate = 1e-4

# %%
#Loading data

import pickle

def get_images(fish):
    """Load files from train folder"""
    fish_dir = TRAIN_DIR+'{}'.format(fish)
    images = [fish+'/'+im for im in os.listdir(fish_dir)]
    return images

def read_image(src):
    """Read and resize individual images"""
    im = Image.open(src)
    im = im.resize((COLS, ROWS), Image.BILINEAR)
    im = np.asarray(im)
    return im
    
if os.path.exists('../data/data_train_{}_{}.pickle'.format(ROWS, COLS)):
    print ('Exist data_train_{}_{}.pickle. Loading data from file.'.format(ROWS, COLS))
    with open('../data/data_train_{}_{}.pickle'.format(ROWS, COLS), 'rb') as f:
        data_train = pickle.load(f)
    X_train = data_train['X_train']
    y_train = data_train['y_train']
else:
    print ('Loading data from original images. Generating data_train_{}_{}.pickle.'.format(ROWS, COLS))

    files = []
    y_train = []

    for fish in FISH_CLASSES:
        fish_files = get_images(fish)
        files.extend(fish_files)

        y_fish = np.tile(fish, len(fish_files))
        y_train.extend(y_fish)
        #print("{0} photos of {1}".format(len(fish_files), fish))

    y_train = np.array(y_train)
    X_train = np.ndarray((len(files), ROWS, COLS, 3), dtype=np.uint8)

    for i, im in enumerate(files): 
        X_train[i] = read_image(TRAIN_DIR+im)
        if i%1000 == 0: print('Processed {} of {}'.format(i, len(files)))

    #X_train = X_train / 255.
    #print(X_train.shape)

    # One Hot Encoding Labels
    y_train = LabelEncoder().fit_transform(y_train)
    y_train = np_utils.to_categorical(y_train)

    #save data to file
    data_train = {'X_train': X_train,'y_train': y_train }

    with open('../data/data_train_{}_{}.pickle'.format(ROWS, COLS), 'wb') as f:
        pickle.dump(data_train, f)

X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=0.2, random_state=None, stratify=y_train)
# Out:
# Exist data_train_224_224.pickle. Loading data from file.

# %%
#data preprocessing

train_datagen = ImageDataGenerator(
    #featurewise_center=True,
    #featurewise_std_normalization=True,
    rescale=1./255,
    rotation_range=180,
    shear_range=np.pi/6.,
    zoom_range=[1,1.1],
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    vertical_flip=True)

#train_datagen.fit(X_train)
train_generator = train_datagen.flow(X_train, y_train, batch_size=BatchSize, shuffle=True, seed=None)

valid_datagen = ImageDataGenerator(rescale=1./255)

valid_generator = valid_datagen.flow(X_valid, y_valid, batch_size=BatchSize, shuffle=True, seed=None)

# %%
#callbacks

early_stopping = EarlyStopping(monitor='val_loss', min_delta=0, patience=25, verbose=1, mode='auto')        

model_checkpoint = ModelCheckpoint(filepath='./checkpoints/weights.{epoch:03d}-{val_loss:.4f}.hdf5', monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False, mode='auto')
        
learningrate_schedule = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=10, verbose=1, mode='auto', epsilon=0.001, cooldown=0, min_lr=0)

tensorboard = TensorBoard(log_dir='./logs', histogram_freq=0, write_graph=True, write_images=True)

# %%
#stg1 training

from keras.applications.vgg16 import VGG16

optimizer = Adam(lr=LearningRate)

base_model = VGG16(weights='imagenet', include_top=False)

x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(256, init='glorot_normal', activation='relu')(x)
#x = Dropout(0.5)(x)
x = Dense(256, init='glorot_normal', activation='relu')(x)
#x = Dropout(0.5)(x)
predictions = Dense(len(FISH_CLASSES), init='glorot_normal', activation='softmax')(x)

# this is the model we will train
model = Model(input=base_model.input, output=predictions)

# first: train only the top layers (which were randomly initialized)
# i.e. freeze all convolutional VGG16 layers
for layer in base_model.layers:
    layer.trainable = False

# compile the model (should be done *after* setting layers to non-trainable)
model.compile(optimizer=optimizer, loss='categorical_crossentropy')

# train the model on the new data for a few epochs
model.fit_generator(train_generator, samples_per_epoch=len(X_train), nb_epoch=300, verbose=1, 
                    callbacks=[early_stopping, model_checkpoint, learningrate_schedule, tensorboard], 
                    validation_data=valid_generator, nb_val_samples=len(X_valid), nb_worker=3, pickle_safe=True)

# %%
#stg2 training

from keras.applications.vgg16 import VGG16

optimizer = Adam(lr=LearningRate)

base_model = VGG16(weights='imagenet', include_top=False)
# at this point, the top layers are well trained and we can start fine-tuning
# convolutional layers from inception V3. We will freeze the bottom N layers
# and train the remaining top layers.

# let's visualize layer names and layer indices to see how many layers
# we should freeze:
for i, layer in enumerate(base_model.layers):
   print(i, layer.name)

# we chose to train the top 2 inception blocks, i.e. we will freeze
# the first 172 layers and unfreeze the rest:
for layer in model.layers[:14]:
   layer.trainable = False
for layer in model.layers[14:]:
   layer.trainable = True

# we need to recompile the model for these modifications to take effect
# we use SGD with a low learning rate
model.compile(optimizer=optimizer, loss='categorical_crossentropy')

# we train our model again (this time fine-tuning the top 2 inception blocks
# alongside the top Dense layers
model.fit_generator(train_generator, samples_per_epoch=len(X_train), nb_epoch=300, verbose=1, 
                    callbacks=[early_stopping, model_checkpoint, learningrate_schedule, tensorboard], 
                    validation_data=valid_generator, nb_val_samples=len(X_valid), nb_worker=3, pickle_safe=True)
# Out:
# 0 input_3
# 1 block1_conv1
# 2 block1_conv2
# 3 block1_pool
# 4 block2_conv1
# 5 block2_conv2
# 6 block2_pool
# 7 block3_conv1
# 8 block3_conv2
# 9 block3_conv3
# 10 block3_pool
# 11 block4_conv1
# 12 block4_conv2
# 13 block4_conv3
# 14 block4_pool
# 15 block5_conv1
# 16 block5_conv2
# 17 block5_conv3
# 18 block5_pool
# Epoch 1/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 1.2538
# /opt/anaconda3/lib/python3.5/site-packages/keras/engine/training.py:1470: UserWarning: Epoch comprised more than `samples_per_epoch` samples, which might affect learning results. Set `samples_per_epoch` correctly to avoid this warning.
#   warnings.warn('Epoch comprised more than '
# Epoch 00000: val_loss improved from inf to 1.04548, saving model to ./checkpoints/weights.000-1.0455.hdf5
# 3072/3021 [==============================] - 85s - loss: 1.2478 - val_loss: 1.0455
# Epoch 2/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.9460Epoch 00001: val_loss improved from 1.04548 to 0.80567, saving model to ./checkpoints/weights.001-0.8057.hdf5
# 3072/3021 [==============================] - 70s - loss: 0.9437 - val_loss: 0.8057
# Epoch 3/300
# 2983/3021 [============================>.] - ETA: 0s - loss: 0.7676Epoch 00002: val_loss did not improve
# 3047/3021 [==============================] - 71s - loss: 0.7734 - val_loss: 0.9774
# Epoch 4/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.6906Epoch 00003: val_loss improved from 0.80567 to 0.63040, saving model to ./checkpoints/weights.003-0.6304.hdf5
# 3072/3021 [==============================] - 70s - loss: 0.6909 - val_loss: 0.6304
# Epoch 5/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.5838Epoch 00004: val_loss did not improve
# 3072/3021 [==============================] - 70s - loss: 0.5813 - val_loss: 0.7017
# Epoch 6/300
# 2983/3021 [============================>.] - ETA: 0s - loss: 0.5608Epoch 00005: val_loss improved from 0.63040 to 0.61503, saving model to ./checkpoints/weights.005-0.6150.hdf5
# 3047/3021 [==============================] - 69s - loss: 0.5596 - val_loss: 0.6150
# Epoch 7/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.5016Epoch 00006: val_loss improved from 0.61503 to 0.53570, saving model to ./checkpoints/weights.006-0.5357.hdf5
# 3072/3021 [==============================] - 70s - loss: 0.4975 - val_loss: 0.5357
# Epoch 8/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.4361Epoch 00007: val_loss did not improve
# 3072/3021 [==============================] - 70s - loss: 0.4361 - val_loss: 0.5432
# Epoch 9/300
# 2983/3021 [============================>.] - ETA: 0s - loss: 0.4059Epoch 00008: val_loss did not improve
# 3047/3021 [==============================] - 69s - loss: 0.4032 - val_loss: 0.5752
# Epoch 10/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.3733Epoch 00009: val_loss improved from 0.53570 to 0.33159, saving model to ./checkpoints/weights.009-0.3316.hdf5
# 3072/3021 [==============================] - 70s - loss: 0.3744 - val_loss: 0.3316
# Epoch 11/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.3254Epoch 00010: val_loss did not improve
# 3072/3021 [==============================] - 69s - loss: 0.3243 - val_loss: 0.4274
# Epoch 12/300
# 2983/3021 [============================>.] - ETA: 0s - loss: 0.3495Epoch 00011: val_loss did not improve
# 3047/3021 [==============================] - 69s - loss: 0.3477 - val_loss: 0.4750
# Epoch 13/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.3056Epoch 00012: val_loss did not improve
# 3072/3021 [==============================] - 70s - loss: 0.3016 - val_loss: 0.5004
# Epoch 14/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.2465Epoch 00013: val_loss improved from 0.33159 to 0.26357, saving model to ./checkpoints/weights.013-0.2636.hdf5
# 3072/3021 [==============================] - 70s - loss: 0.2496 - val_loss: 0.2636
# Epoch 15/300
# 2983/3021 [============================>.] - ETA: 0s - loss: 0.2556Epoch 00014: val_loss did not improve
# 3047/3021 [==============================] - 70s - loss: 0.2575 - val_loss: 0.3512
# Epoch 16/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.2091Epoch 00015: val_loss did not improve
# 3072/3021 [==============================] - 70s - loss: 0.2092 - val_loss: 0.3096
# Epoch 17/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.2256Epoch 00016: val_loss improved from 0.26357 to 0.22867, saving model to ./checkpoints/weights.016-0.2287.hdf5
# 3072/3021 [==============================] - 70s - loss: 0.2235 - val_loss: 0.2287
# Epoch 18/300
# 2983/3021 [============================>.] - ETA: 0s - loss: 0.2045Epoch 00017: val_loss did not improve
# 3047/3021 [==============================] - 70s - loss: 0.2033 - val_loss: 0.2895
# Epoch 19/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.1903Epoch 00018: val_loss did not improve
# 3072/3021 [==============================] - 70s - loss: 0.1889 - val_loss: 0.2927
# Epoch 20/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.1784Epoch 00019: val_loss did not improve
# 3072/3021 [==============================] - 70s - loss: 0.1772 - val_loss: 0.3048
# Epoch 21/300
# 2983/3021 [============================>.] - ETA: 0s - loss: 0.1967Epoch 00020: val_loss did not improve
# 3047/3021 [==============================] - 69s - loss: 0.1949 - val_loss: 0.3690
# Epoch 22/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.1538Epoch 00021: val_loss did not improve
# 3072/3021 [==============================] - 71s - loss: 0.1568 - val_loss: 0.3551
# Epoch 23/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.1695Epoch 00022: val_loss did not improve
# 3072/3021 [==============================] - 70s - loss: 0.1685 - val_loss: 0.3090
# Epoch 24/300
# 2983/3021 [============================>.] - ETA: 0s - loss: 0.1290Epoch 00023: val_loss did not improve
# 3047/3021 [==============================] - 69s - loss: 0.1279 - val_loss: 0.2879
# Epoch 25/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.1346Epoch 00024: val_loss did not improve
# 3072/3021 [==============================] - 70s - loss: 0.1344 - val_loss: 0.2958
# Epoch 26/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.1212Epoch 00025: val_loss did not improve
# 3072/3021 [==============================] - 70s - loss: 0.1207 - val_loss: 0.3149
# Epoch 27/300
# 2983/3021 [============================>.] - ETA: 0s - loss: 0.1540Epoch 00026: val_loss did not improve
# 3047/3021 [==============================] - 70s - loss: 0.1538 - val_loss: 0.3790
# Epoch 28/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.1096Epoch 00027: val_loss did not improve
#
# Epoch 00027: reducing learning rate to 1.9999999494757503e-05.
# 3072/3021 [==============================] - 70s - loss: 0.1103 - val_loss: 0.2986
# Epoch 29/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.0657Epoch 00028: val_loss improved from 0.22867 to 0.20805, saving model to ./checkpoints/weights.028-0.2080.hdf5
# 3072/3021 [==============================] - 70s - loss: 0.0655 - val_loss: 0.2080
# Epoch 30/300
# 2983/3021 [============================>.] - ETA: 0s - loss: 0.0542Epoch 00029: val_loss did not improve
# 3047/3021 [==============================] - 70s - loss: 0.0550 - val_loss: 0.2437
# Epoch 31/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.0487Epoch 00030: val_loss did not improve
# 3072/3021 [==============================] - 70s - loss: 0.0499 - val_loss: 0.2660
# Epoch 32/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.0522Epoch 00031: val_loss improved from 0.20805 to 0.20593, saving model to ./checkpoints/weights.031-0.2059.hdf5
# 3072/3021 [==============================] - 71s - loss: 0.0518 - val_loss: 0.2059
# Epoch 33/300
# 2983/3021 [============================>.] - ETA: 0s - loss: 0.0492Epoch 00032: val_loss did not improve
# 3047/3021 [==============================] - 70s - loss: 0.0486 - val_loss: 0.2317
# Epoch 34/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.0539Epoch 00033: val_loss improved from 0.20593 to 0.17129, saving model to ./checkpoints/weights.033-0.1713.hdf5
# 3072/3021 [==============================] - 70s - loss: 0.0542 - val_loss: 0.1713
# Epoch 35/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.0475Epoch 00034: val_loss did not improve
# 3072/3021 [==============================] - 70s - loss: 0.0474 - val_loss: 0.2162
# Epoch 36/300
# 2983/3021 [============================>.] - ETA: 0s - loss: 0.0455Epoch 00035: val_loss did not improve
# 3047/3021 [==============================] - 69s - loss: 0.0465 - val_loss: 0.2032
# Epoch 37/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.0410Epoch 00036: val_loss did not improve
# 3072/3021 [==============================] - 70s - loss: 0.0404 - val_loss: 0.2118
# Epoch 38/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.0423Epoch 00037: val_loss did not improve
# 3072/3021 [==============================] - 70s - loss: 0.0420 - val_loss: 0.1720
# Epoch 39/300
# 2983/3021 [============================>.] - ETA: 0s - loss: 0.0413Epoch 00038: val_loss did not improve
# 3047/3021 [==============================] - 70s - loss: 0.0407 - val_loss: 0.2387
# Epoch 40/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.0350Epoch 00039: val_loss did not improve
# 3072/3021 [==============================] - 70s - loss: 0.0348 - val_loss: 0.2889
# Epoch 41/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.0315Epoch 00040: val_loss did not improve
# 3072/3021 [==============================] - 69s - loss: 0.0326 - val_loss: 0.2150
# Epoch 42/300
# 2983/3021 [============================>.] - ETA: 0s - loss: 0.0361Epoch 00041: val_loss did not improve
# 3047/3021 [==============================] - 69s - loss: 0.0357 - val_loss: 0.2293
# Epoch 43/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.0305Epoch 00042: val_loss did not improve
# 3072/3021 [==============================] - 70s - loss: 0.0301 - val_loss: 0.1747
# Epoch 44/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.0385Epoch 00043: val_loss improved from 0.17129 to 0.17055, saving model to ./checkpoints/weights.043-0.1705.hdf5
# 3072/3021 [==============================] - 70s - loss: 0.0386 - val_loss: 0.1705
# Epoch 45/300
# 2983/3021 [============================>.] - ETA: 0s - loss: 0.0363Epoch 00044: val_loss did not improve
#
# Epoch 00044: reducing learning rate to 3.999999898951501e-06.
# 3047/3021 [==============================] - 69s - loss: 0.0360 - val_loss: 0.2691
# Epoch 46/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.0322Epoch 00045: val_loss improved from 0.17055 to 0.15367, saving model to ./checkpoints/weights.045-0.1537.hdf5
# 3072/3021 [==============================] - 70s - loss: 0.0320 - val_loss: 0.1537
# Epoch 47/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.0282Epoch 00046: val_loss did not improve
# 3072/3021 [==============================] - 70s - loss: 0.0280 - val_loss: 0.2337
# Epoch 48/300
# 2983/3021 [============================>.] - ETA: 0s - loss: 0.0262Epoch 00047: val_loss did not improve
# 3047/3021 [==============================] - 70s - loss: 0.0263 - val_loss: 0.2304
# Epoch 49/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.0219Epoch 00048: val_loss did not improve
# 3072/3021 [==============================] - 70s - loss: 0.0217 - val_loss: 0.2491
# Epoch 50/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.0351Epoch 00049: val_loss did not improve
# 3072/3021 [==============================] - 70s - loss: 0.0370 - val_loss: 0.1880
# Epoch 51/300
# 2983/3021 [============================>.] - ETA: 0s - loss: 0.0267Epoch 00050: val_loss improved from 0.15367 to 0.13505, saving model to ./checkpoints/weights.050-0.1350.hdf5
# 3047/3021 [==============================] - 70s - loss: 0.0265 - val_loss: 0.1350
# Epoch 52/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.0243Epoch 00051: val_loss did not improve
# 3072/3021 [==============================] - 70s - loss: 0.0257 - val_loss: 0.2410
# Epoch 53/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.0243Epoch 00052: val_loss did not improve
# 3072/3021 [==============================] - 70s - loss: 0.0251 - val_loss: 0.2465
# Epoch 54/300
# 2983/3021 [============================>.] - ETA: 0s - loss: 0.0250Epoch 00053: val_loss did not improve
# 3047/3021 [==============================] - 69s - loss: 0.0262 - val_loss: 0.1908
# Epoch 55/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.0237Epoch 00054: val_loss did not improve
# 3072/3021 [==============================] - 70s - loss: 0.0233 - val_loss: 0.3144
# Epoch 56/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.0200Epoch 00055: val_loss did not improve
# 3072/3021 [==============================] - 70s - loss: 0.0198 - val_loss: 0.2361
# Epoch 57/300
# 2983/3021 [============================>.] - ETA: 0s - loss: 0.0180Epoch 00056: val_loss did not improve
# 3047/3021 [==============================] - 70s - loss: 0.0184 - val_loss: 0.1965
# Epoch 58/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.0246Epoch 00057: val_loss did not improve
# 3072/3021 [==============================] - 70s - loss: 0.0246 - val_loss: 0.1858
# Epoch 59/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.0248Epoch 00058: val_loss did not improve
# 3072/3021 [==============================] - 70s - loss: 0.0252 - val_loss: 0.2242
# Epoch 60/300
# 2983/3021 [============================>.] - ETA: 0s - loss: 0.0271Epoch 00059: val_loss did not improve
# 3047/3021 [==============================] - 70s - loss: 0.0270 - val_loss: 0.2275
# Epoch 61/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.0202Epoch 00060: val_loss did not improve
# 3072/3021 [==============================] - 70s - loss: 0.0201 - val_loss: 0.1711
# Epoch 62/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.0244Epoch 00061: val_loss did not improve
#
# Epoch 00061: reducing learning rate to 7.999999979801942e-07.
# 3072/3021 [==============================] - 70s - loss: 0.0242 - val_loss: 0.1970
# Epoch 63/300
# 2983/3021 [============================>.] - ETA: 0s - loss: 0.0244Epoch 00062: val_loss did not improve
# 3047/3021 [==============================] - 69s - loss: 0.0242 - val_loss: 0.2559
# Epoch 64/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.0231Epoch 00063: val_loss did not improve
# 3072/3021 [==============================] - 70s - loss: 0.0233 - val_loss: 0.2054
# Epoch 65/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.0206Epoch 00064: val_loss did not improve
# 3072/3021 [==============================] - 70s - loss: 0.0204 - val_loss: 0.2215
# Epoch 66/300
# 2983/3021 [============================>.] - ETA: 0s - loss: 0.0249Epoch 00065: val_loss did not improve
# 3047/3021 [==============================] - 70s - loss: 0.0249 - val_loss: 0.1982
# Epoch 67/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.0198Epoch 00066: val_loss did not improve
# 3072/3021 [==============================] - 70s - loss: 0.0196 - val_loss: 0.2284
# Epoch 68/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.0235Epoch 00067: val_loss did not improve
# 3072/3021 [==============================] - 70s - loss: 0.0231 - val_loss: 0.2271
# Epoch 69/300
# 2983/3021 [============================>.] - ETA: 0s - loss: 0.0219Epoch 00068: val_loss did not improve
# 3047/3021 [==============================] - 70s - loss: 0.0216 - val_loss: 0.1576
# Epoch 70/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.0197Epoch 00069: val_loss did not improve
# 3072/3021 [==============================] - 70s - loss: 0.0193 - val_loss: 0.1911
# Epoch 71/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.0241Epoch 00070: val_loss did not improve
# 3021/3021 [==============================] - 69s - loss: 0.0241 - val_loss: 0.1895
# Epoch 72/300
# 2970/3021 [============================>.] - ETA: 0s - loss: 0.0236Epoch 00071: val_loss did not improve
#
# Epoch 00071: reducing learning rate to 1.600000018697756e-07.
# 3034/3021 [==============================] - 70s - loss: 0.0232 - val_loss: 0.2577
# Epoch 73/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.0229Epoch 00072: val_loss did not improve
# 3072/3021 [==============================] - 70s - loss: 0.0232 - val_loss: 0.1452
# Epoch 74/300
# 2983/3021 [============================>.] - ETA: 0s - loss: 0.0228Epoch 00073: val_loss did not improve
# 3047/3021 [==============================] - 70s - loss: 0.0226 - val_loss: 0.1755
# Epoch 75/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.0190Epoch 00074: val_loss improved from 0.13505 to 0.10881, saving model to ./checkpoints/weights.074-0.1088.hdf5
# 3072/3021 [==============================] - 70s - loss: 0.0196 - val_loss: 0.1088
# Epoch 76/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.0224Epoch 00075: val_loss did not improve
# 3072/3021 [==============================] - 70s - loss: 0.0230 - val_loss: 0.1868
# Epoch 77/300
# 2983/3021 [============================>.] - ETA: 0s - loss: 0.0224Epoch 00076: val_loss did not improve
# 3047/3021 [==============================] - 70s - loss: 0.0220 - val_loss: 0.1434
# Epoch 78/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.0238Epoch 00077: val_loss did not improve
# 3072/3021 [==============================] - 70s - loss: 0.0235 - val_loss: 0.2376
# Epoch 79/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.0172Epoch 00078: val_loss did not improve
# 3072/3021 [==============================] - 70s - loss: 0.0170 - val_loss: 0.1615
# Epoch 80/300
# 2983/3021 [============================>.] - ETA: 0s - loss: 0.0218Epoch 00079: val_loss did not improve
# 3047/3021 [==============================] - 69s - loss: 0.0227 - val_loss: 0.1963
# Epoch 81/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.0218Epoch 00080: val_loss did not improve
# 3072/3021 [==============================] - 69s - loss: 0.0228 - val_loss: 0.2624
# Epoch 82/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.0210Epoch 00081: val_loss did not improve
# 3072/3021 [==============================] - 70s - loss: 0.0209 - val_loss: 0.1959
# Epoch 83/300
# 2983/3021 [============================>.] - ETA: 0s - loss: 0.0222Epoch 00082: val_loss did not improve
# 3047/3021 [==============================] - 69s - loss: 0.0224 - val_loss: 0.1929
# Epoch 84/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.0184Epoch 00083: val_loss did not improve
# 3072/3021 [==============================] - 70s - loss: 0.0182 - val_loss: 0.1770
# Epoch 85/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.0184Epoch 00084: val_loss did not improve
# 3072/3021 [==============================] - 70s - loss: 0.0187 - val_loss: 0.1540
# Epoch 86/300
# 2983/3021 [============================>.] - ETA: 0s - loss: 0.0222Epoch 00085: val_loss did not improve
#
# Epoch 00085: reducing learning rate to 3.199999980552093e-08.
# 3047/3021 [==============================] - 70s - loss: 0.0221 - val_loss: 0.1892
# Epoch 87/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.0206Epoch 00086: val_loss did not improve
# 3072/3021 [==============================] - 70s - loss: 0.0203 - val_loss: 0.1861
# Epoch 88/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.0197Epoch 00087: val_loss did not improve
# 3072/3021 [==============================] - 70s - loss: 0.0199 - val_loss: 0.1536
# Epoch 89/300
# 2983/3021 [============================>.] - ETA: 0s - loss: 0.0202Epoch 00088: val_loss did not improve
# 3047/3021 [==============================] - 70s - loss: 0.0208 - val_loss: 0.1542
# Epoch 90/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.0167Epoch 00089: val_loss did not improve
# 3072/3021 [==============================] - 70s - loss: 0.0165 - val_loss: 0.2076
# Epoch 91/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.0193Epoch 00090: val_loss did not improve
# 3072/3021 [==============================] - 70s - loss: 0.0191 - val_loss: 0.2714
# Epoch 92/300
# 2983/3021 [============================>.] - ETA: 0s - loss: 0.0205Epoch 00091: val_loss did not improve
# 3047/3021 [==============================] - 70s - loss: 0.0201 - val_loss: 0.1680
# Epoch 93/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.0217Epoch 00092: val_loss did not improve
# 3072/3021 [==============================] - 70s - loss: 0.0213 - val_loss: 0.1884
# Epoch 94/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.0248Epoch 00093: val_loss did not improve
# 3072/3021 [==============================] - 70s - loss: 0.0245 - val_loss: 0.1890
# Epoch 95/300
# 2983/3021 [============================>.] - ETA: 0s - loss: 0.0213Epoch 00094: val_loss did not improve
# 3047/3021 [==============================] - 69s - loss: 0.0212 - val_loss: 0.2831
# Epoch 96/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.0201Epoch 00095: val_loss did not improve
#
# Epoch 00095: reducing learning rate to 6.399999818995639e-09.
# 3072/3021 [==============================] - 70s - loss: 0.0198 - val_loss: 0.2074
# Epoch 97/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.0164Epoch 00096: val_loss did not improve
# 3072/3021 [==============================] - 70s - loss: 0.0164 - val_loss: 0.2718
# Epoch 98/300
# 2983/3021 [============================>.] - ETA: 0s - loss: 0.0218Epoch 00097: val_loss did not improve
# 3047/3021 [==============================] - 70s - loss: 0.0214 - val_loss: 0.2625
# Epoch 99/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.0208Epoch 00098: val_loss did not improve
# 3072/3021 [==============================] - 70s - loss: 0.0209 - val_loss: 0.1456
# Epoch 100/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.0216Epoch 00099: val_loss did not improve
# 3072/3021 [==============================] - 70s - loss: 0.0214 - val_loss: 0.2114
# Epoch 101/300
# 2983/3021 [============================>.] - ETA: 0s - loss: 0.0203Epoch 00100: val_loss did not improve
# 3047/3021 [==============================] - 69s - loss: 0.0200 - val_loss: 0.1885
# Epoch 00100: early stopping

# %%
#resume training

files = glob.glob('./checkpoints/*')
val_losses = [float(f.split('-')[-1][:-5]) for f in files]
index = val_losses.index(min(val_losses))
print('Loading model from checkpoints file ' + files[index])
model = load_model(files[index])

model.fit_generator(train_generator, samples_per_epoch=len(X_train), nb_epoch=300, verbose=1, 
                    callbacks=[early_stopping, model_checkpoint, learningrate_schedule, tensorboard], 
                    validation_data=valid_generator, nb_val_samples=len(X_valid), nb_worker=3, pickle_safe=True)
# Out:
# Loading model from checkpoints file ./checkpoints/weights.024-0.0414.hdf5
# Epoch 1/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.0957
# /opt/anaconda3/lib/python3.5/site-packages/keras/engine/training.py:1470: UserWarning: Epoch comprised more than `samples_per_epoch` samples, which might affect learning results. Set `samples_per_epoch` correctly to avoid this warning.
#   warnings.warn('Epoch comprised more than '
# Epoch 00000: val_loss improved from inf to 0.08854, saving model to ./checkpoints/weights.000-0.0885.hdf5
# 3072/3021 [==============================] - 86s - loss: 0.0949 - val_loss: 0.0885
# Epoch 2/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.0798Epoch 00001: val_loss did not improve
# 3072/3021 [==============================] - 69s - loss: 0.0794 - val_loss: 0.1272
# Epoch 3/300
# 2983/3021 [============================>.] - ETA: 0s - loss: 0.0815Epoch 00002: val_loss improved from 0.08854 to 0.04676, saving model to ./checkpoints/weights.002-0.0468.hdf5
# 3047/3021 [==============================] - 71s - loss: 0.0803 - val_loss: 0.0468
# Epoch 4/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.0800Epoch 00003: val_loss did not improve
# 3072/3021 [==============================] - 69s - loss: 0.0793 - val_loss: 0.0563
# Epoch 5/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.0635Epoch 00004: val_loss did not improve
# 3072/3021 [==============================] - 69s - loss: 0.0627 - val_loss: 0.0742
# Epoch 6/300
# 2983/3021 [============================>.] - ETA: 0s - loss: 0.0694Epoch 00005: val_loss did not improve
# 3047/3021 [==============================] - 69s - loss: 0.0714 - val_loss: 0.0842
# Epoch 7/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.0603Epoch 00006: val_loss did not improve
# 3072/3021 [==============================] - 69s - loss: 0.0621 - val_loss: 0.0547
# Epoch 8/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.0524Epoch 00007: val_loss did not improve
# 3072/3021 [==============================] - 69s - loss: 0.0518 - val_loss: 0.0846
# Epoch 9/300
# 2983/3021 [============================>.] - ETA: 0s - loss: 0.0591Epoch 00008: val_loss did not improve
# 3047/3021 [==============================] - 69s - loss: 0.0583 - val_loss: 0.0819
# Epoch 10/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.0457Epoch 00009: val_loss did not improve
# 3072/3021 [==============================] - 69s - loss: 0.0455 - val_loss: 0.0487
# Epoch 11/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.0534Epoch 00010: val_loss did not improve
# 3072/3021 [==============================] - 69s - loss: 0.0537 - val_loss: 0.0489
# Epoch 12/300
# 2983/3021 [============================>.] - ETA: 0s - loss: 0.0601Epoch 00011: val_loss did not improve
# 3047/3021 [==============================] - 69s - loss: 0.0610 - val_loss: 0.0981
# Epoch 13/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.0467Epoch 00012: val_loss did not improve
# 3072/3021 [==============================] - 69s - loss: 0.0471 - val_loss: 0.0606
# Epoch 14/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.0508Epoch 00013: val_loss did not improve
#
# Epoch 00013: reducing learning rate to 1.9999999494757505e-06.
# 3072/3021 [==============================] - 69s - loss: 0.0502 - val_loss: 0.0727
# Epoch 15/300
# 2983/3021 [============================>.] - ETA: 0s - loss: 0.0405Epoch 00014: val_loss improved from 0.04676 to 0.04248, saving model to ./checkpoints/weights.014-0.0425.hdf5
# 3047/3021 [==============================] - 68s - loss: 0.0397 - val_loss: 0.0425
# Epoch 16/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.0352Epoch 00015: val_loss improved from 0.04248 to 0.02683, saving model to ./checkpoints/weights.015-0.0268.hdf5
# 3072/3021 [==============================] - 69s - loss: 0.0353 - val_loss: 0.0268
# Epoch 17/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.0338Epoch 00016: val_loss did not improve
# 3072/3021 [==============================] - 69s - loss: 0.0332 - val_loss: 0.0314
# Epoch 18/300
# 2983/3021 [============================>.] - ETA: 0s - loss: 0.0378Epoch 00017: val_loss did not improve
# 3047/3021 [==============================] - 68s - loss: 0.0374 - val_loss: 0.0393
# Epoch 19/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.0272Epoch 00018: val_loss did not improve
# 3072/3021 [==============================] - 69s - loss: 0.0271 - val_loss: 0.0338
# Epoch 20/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.0317Epoch 00019: val_loss did not improve
# 3072/3021 [==============================] - 69s - loss: 0.0313 - val_loss: 0.0536
# Epoch 21/300
# 2983/3021 [============================>.] - ETA: 0s - loss: 0.0282Epoch 00020: val_loss did not improve
# 3047/3021 [==============================] - 69s - loss: 0.0278 - val_loss: 0.0435
# Epoch 22/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.0260Epoch 00021: val_loss did not improve
# 3072/3021 [==============================] - 69s - loss: 0.0263 - val_loss: 0.0399
# Epoch 23/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.0317Epoch 00022: val_loss did not improve
# 3072/3021 [==============================] - 69s - loss: 0.0313 - val_loss: 0.0508
# Epoch 24/300
# 2983/3021 [============================>.] - ETA: 0s - loss: 0.0278Epoch 00023: val_loss did not improve
# 3047/3021 [==============================] - 68s - loss: 0.0284 - val_loss: 0.0612
# Epoch 25/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.0261Epoch 00024: val_loss did not improve
# 3072/3021 [==============================] - 69s - loss: 0.0283 - val_loss: 0.0385
# Epoch 26/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.0273Epoch 00025: val_loss did not improve
# 3072/3021 [==============================] - 69s - loss: 0.0269 - val_loss: 0.0377
# Epoch 27/300
# 2983/3021 [============================>.] - ETA: 0s - loss: 0.0291Epoch 00026: val_loss did not improve
#
# Epoch 00026: reducing learning rate to 1.9999999949504855e-07.
# 3047/3021 [==============================] - 69s - loss: 0.0291 - val_loss: 0.0415
# Epoch 28/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.0333Epoch 00027: val_loss did not improve
# 3072/3021 [==============================] - 69s - loss: 0.0328 - val_loss: 0.0353
# Epoch 29/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.0272Epoch 00028: val_loss did not improve
# 3072/3021 [==============================] - 69s - loss: 0.0283 - val_loss: 0.0458
# Epoch 30/300
# 2983/3021 [============================>.] - ETA: 0s - loss: 0.0293Epoch 00029: val_loss did not improve
# 3047/3021 [==============================] - 68s - loss: 0.0292 - val_loss: 0.0390
# Epoch 31/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.0341Epoch 00030: val_loss did not improve
# 3072/3021 [==============================] - 69s - loss: 0.0337 - val_loss: 0.0344
# Epoch 32/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.0265Epoch 00031: val_loss did not improve
# 3072/3021 [==============================] - 69s - loss: 0.0262 - val_loss: 0.0404
# Epoch 33/300
# 2983/3021 [============================>.] - ETA: 0s - loss: 0.0272Epoch 00032: val_loss did not improve
# 3047/3021 [==============================] - 68s - loss: 0.0268 - val_loss: 0.0447
# Epoch 34/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.0283Epoch 00033: val_loss did not improve
# 3072/3021 [==============================] - 69s - loss: 0.0279 - val_loss: 0.0470
# Epoch 35/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.0306Epoch 00034: val_loss did not improve
# 3072/3021 [==============================] - 69s - loss: 0.0308 - val_loss: 0.0505
# Epoch 36/300
# 2983/3021 [============================>.] - ETA: 0s - loss: 0.0242Epoch 00035: val_loss did not improve
# 3047/3021 [==============================] - 68s - loss: 0.0247 - val_loss: 0.0501
# Epoch 37/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.0270Epoch 00036: val_loss did not improve
#
# Epoch 00036: reducing learning rate to 2.000000023372195e-08.
# 3072/3021 [==============================] - 69s - loss: 0.0268 - val_loss: 0.0298
# Epoch 38/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.0282Epoch 00037: val_loss did not improve
# 3072/3021 [==============================] - 69s - loss: 0.0279 - val_loss: 0.0476
# Epoch 39/300
# 2983/3021 [============================>.] - ETA: 0s - loss: 0.0306Epoch 00038: val_loss did not improve
# 3047/3021 [==============================] - 69s - loss: 0.0303 - val_loss: 0.0327
# Epoch 40/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.0242Epoch 00039: val_loss did not improve
# 3072/3021 [==============================] - 69s - loss: 0.0242 - val_loss: 0.0354
# Epoch 41/300
# 3008/3021 [============================>.] - ETA: 0s - loss: 0.0269Epoch 00040: val_loss did not improve
# 3072/3021 [==============================] - 69s - loss: 0.0274 - val_loss: 0.0369
# Epoch 42/300
# 2983/3021 [============================>.] - ETA: 0s - loss: 0.0289Epoch 00041: val_loss did not improve
# 3047/3021 [==============================] - 69s - loss: 0.0290 - val_loss: 0.0483
# Epoch 00041: early stopping

# %%
#test submission

import datetime

if os.path.exists('../data/data_test_{}_{}.pickle'.format(ROWS, COLS)):
    print ('Exist data_test_{}_{}.pickle. Loading test data from file.'.format(ROWS, COLS))
    with open('../data/data_test_{}_{}.pickle'.format(ROWS, COLS), 'rb') as f:
        data_test = pickle.load(f)
    X_test = data_test['X_test']
    test_files = data_test['test_files']
else:
    print ('Loading test data from original images. Generating data_test_{}_{}.pickle.'.format(ROWS, COLS))

    test_files = [im for im in os.listdir(TEST_DIR)]
    X_test = np.ndarray((len(test_files), ROWS, COLS, 3), dtype=np.uint8)

    for i, im in enumerate(test_files): 
        X_test[i] = read_image(TEST_DIR+im)
        if i%300 == 0: print('Processed {} of {}'.format(i, len(test_files)))
            
    data_test = {'X_test': X_test,'test_files': test_files }
    
    with open('../data/data_test_{}_{}.pickle'.format(ROWS, COLS), 'wb') as f:
        pickle.dump(data_test, f)
            
X_test = X_test / 255.

files = glob.glob('./checkpoints/*')
val_losses = [float(f.split('-')[-1][:-5]) for f in files]
index = val_losses.index(min(val_losses))
model = load_model(files[index])

test_preds = model.predict(X_test, batch_size=BatchSize, verbose=1)
#test_preds= test_preds / np.sum(test_preds,axis=1,keepdims=True)

submission = pd.DataFrame(test_preds, columns=FISH_CLASSES)
#submission.loc[:, 'image'] = pd.Series(test_files, index=submission.index)
submission.insert(0, 'image', test_files)

now = datetime.datetime.now()
info = 'VGG16TF_' + '{:.4f}'.format(min(val_losses))
sub_file = 'submission_' + info + '_' + str(now.strftime("%Y-%m-%d-%H-%M")) + '.csv'
submission.to_csv(sub_file, index=False)
# Out:
# Exist data_test_224_224.pickle. Loading test data from file.
# 1000/1000 [==============================] - 28s

# %%
os.listdir(TEST_DIR)
# Out:
# ['img_01373.jpg',
#  'img_05426.jpg',
#  'img_03283.jpg',
#  'img_05976.jpg',
#  'img_04872.jpg',
#  'img_01116.jpg',
#  'img_03711.jpg',
#  'img_00518.jpg',
#  'img_02398.jpg',
#  'img_00170.jpg',
#  'img_04285.jpg',
#  'img_04306.jpg',
#  'img_00442.jpg',
#  'img_05516.jpg',
#  'img_03847.jpg',
#  'img_03239.jpg',
#  'img_02486.jpg',
#  'img_02422.jpg',
#  'img_02899.jpg',
#  'img_06207.jpg',
#  'img_06203.jpg',
#  'img_07084.jpg',
#  'img_05922.jpg',
#  'img_06261.jpg',
#  'img_01853.jpg',
#  'img_00446.jpg',
#  'img_06189.jpg',
#  'img_07157.jpg',
#  'img_01388.jpg',
#  'img_05284.jpg',
#  'img_04532.jpg',
#  'img_04723.jpg',
#  'img_03867.jpg',
#  'img_00764.jpg',
#  'img_02956.jpg',
#  'img_04726.jpg',
#  'img_06734.jpg',
#  'img_04814.jpg',
#  'img_05030.jpg',
#  'img_03805.jpg',
#  'img_06637.jpg',
#  'img_05236.jpg',
#  'img_06368.jpg',
#  'img_00232.jpg',
#  'img_06186.jpg',
#  'img_06424.jpg',
#  'img_00380.jpg',
#  'img_03342.jpg',
#  'img_00816.jpg',
#  'img_03087.jpg',
#  'img_00398.jpg',
#  'img_06800.jpg',
#  'img_02285.jpg',
#  'img_03064.jpg',
#  'img_01249.jpg',
#  'img_07792.jpg',
#  'img_05016.jpg',
#  'img_01860.jpg',
#  'img_01688.jpg',
#  'img_00650.jpg',
#  'img_00612.jpg',
#  'img_03169.jpg',
#  'img_04496.jpg',
#  'img_04888.jpg',
#  'img_06510.jpg',
#  'img_07278.jpg',
#  'img_05068.jpg',
#  'img_05950.jpg',
#  'img_06663.jpg',
#  'img_04013.jpg',
#  'img_05828.jpg',
#  'img_02556.jpg',
#  'img_04461.jpg',
#  'img_01198.jpg',
#  'img_05879.jpg',
#  'img_00302.jpg',
#  'img_04061.jpg',
#  'img_03199.jpg',
#  'img_07538.jpg',
#  'img_00175.jpg',
#  'img_01616.jpg',
#  'img_03222.jpg',
#  'img_00726.jpg',
#  'img_02799.jpg',
#  'img_07590.jpg',
#  'img_05137.jpg',
#  'img_02759.jpg',
#  'img_06426.jpg',
#  'img_05612.jpg',
#  'img_04879.jpg',
#  'img_02764.jpg',
#  'img_00765.jpg',
#  'img_05896.jpg',
#  'img_00708.jpg',
#  'img_07448.jpg',
#  'img_04546.jpg',
#  'img_03652.jpg',
#  'img_07237.jpg',
#  'img_01984.jpg',
#  'img_02406.jpg',
#  'img_06966.jpg',
#  'img_01633.jpg',
#  'img_00487.jpg',
#  'img_00331.jpg',
#  'img_05021.jpg',
#  'img_07505.jpg',
#  'img_00855.jpg',
#  'img_06859.jpg',
#  'img_01595.jpg',
#  'img_06559.jpg',
#  'img_06521.jpg',
#  'img_01392.jpg',
#  'img_07231.jpg',
#  'img_03220.jpg',
#  'img_04752.jpg',
#  'img_07467.jpg',
#  'img_04991.jpg',
#  'img_06909.jpg',
#  'img_02876.jpg',
#  'img_04432.jpg',
#  'img_03896.jpg',
#  'img_01490.jpg',
#  'img_04204.jpg',
#  'img_00837.jpg',
#  'img_04885.jpg',
#  'img_02943.jpg',
#  'img_00964.jpg',
#  'img_06646.jpg',
#  'img_03238.jpg',
#  'img_06985.jpg',
#  'img_00376.jpg',
#  'img_03069.jpg',
#  'img_06614.jpg',
#  'img_01874.jpg',
#  'img_05768.jpg',
#  'img_05927.jpg',
#  'img_04671.jpg',
#  'img_06555.jpg',
#  'img_01689.jpg',
#  'img_06401.jpg',
#  'img_05078.jpg',
#  'img_00857.jpg',
#  'img_00763.jpg',
#  'img_02636.jpg',
#  'img_06174.jpg',
#  'img_03231.jpg',
#  'img_02188.jpg',
#  'img_05857.jpg',
#  'img_06489.jpg',
#  'img_07580.jpg',
#  'img_06021.jpg',
#  'img_07060.jpg',
#  'img_04740.jpg',
#  'img_05463.jpg',
#  'img_01224.jpg',
#  'img_02830.jpg',
#  'img_06845.jpg',
#  'img_02811.jpg',
#  'img_00590.jpg',
#  'img_05613.jpg',
#  'img_01669.jpg',
#  'img_01103.jpg',
#  'img_00865.jpg',
#  'img_00358.jpg',
#  'img_03974.jpg',
#  'img_00828.jpg',
#  'img_00383.jpg',
#  'img_06547.jpg',
#  'img_05960.jpg',
#  'img_04990.jpg',
#  'img_03995.jpg',
#  'img_03584.jpg',
#  'img_05718.jpg',
#  'img_02307.jpg',
#  'img_01548.jpg',
#  'img_03628.jpg',
#  'img_00772.jpg',
#  'img_01724.jpg',
#  'img_04921.jpg',
#  'img_01495.jpg',
#  'img_03014.jpg',
#  'img_04719.jpg',
#  'img_04705.jpg',
#  'img_04661.jpg',
#  'img_02347.jpg',
#  'img_07149.jpg',
#  'img_07689.jpg',
#  'img_03943.jpg',
#  'img_02977.jpg',
#  'img_03252.jpg',
#  'img_05264.jpg',
#  'img_02607.jpg',
#  'img_02679.jpg',
#  'img_05076.jpg',
#  'img_04044.jpg',
#  'img_01649.jpg',
#  'img_04757.jpg',
#  'img_06103.jpg',
#  'img_04410.jpg',
#  'img_05882.jpg',
#  'img_01511.jpg',
#  'img_07213.jpg',
#  'img_07616.jpg',
#  'img_00120.jpg',
#  'img_07043.jpg',
#  'img_01537.jpg',
#  'img_04585.jpg',
#  'img_02648.jpg',
#  'img_07188.jpg',
#  'img_02281.jpg',
#  'img_07428.jpg',
#  'img_01441.jpg',
#  'img_06986.jpg',
#  'img_00027.jpg',
#  'img_03475.jpg',
#  'img_05838.jpg',
#  'img_03891.jpg',
#  'img_02074.jpg',
#  'img_06662.jpg',
#  'img_00676.jpg',
#  'img_06812.jpg',
#  'img_06685.jpg',
#  'img_05682.jpg',
#  'img_07103.jpg',
#  'img_02749.jpg',
#  'img_02687.jpg',
#  'img_02299.jpg',
#  'img_05603.jpg',
#  'img_06137.jpg',
#  'img_04370.jpg',
#  'img_00551.jpg',
#  'img_00543.jpg',
#  'img_01413.jpg',
#  'img_04860.jpg',
#  'img_01211.jpg',
#  'img_06369.jpg',
#  'img_00598.jpg',
#  'img_04382.jpg',
#  'img_04830.jpg',
#  'img_01538.jpg',
#  'img_04856.jpg',
#  'img_03677.jpg',
#  'img_04563.jpg',
#  'img_02702.jpg',
#  'img_03587.jpg',
#  'img_01773.jpg',
#  'img_05740.jpg',
#  'img_04004.jpg',
#  'img_07700.jpg',
#  'img_07746.jpg',
#  'img_02699.jpg',
#  'img_05563.jpg',
#  'img_04272.jpg',
#  'img_02865.jpg',
#  'img_05735.jpg',
#  'img_03837.jpg',
#  'img_04233.jpg',
#  'img_00009.jpg',
#  'img_07062.jpg',
#  'img_05119.jpg',
#  'img_07156.jpg',
#  'img_04015.jpg',
#  'img_00469.jpg',
#  'img_04423.jpg',
#  'img_05251.jpg',
#  'img_02834.jpg',
#  'img_00483.jpg',
#  'img_00591.jpg',
#  'img_00642.jpg',
#  'img_03718.jpg',
#  'img_03581.jpg',
#  'img_02726.jpg',
#  'img_06332.jpg',
#  'img_00950.jpg',
#  'img_03456.jpg',
#  'img_07352.jpg',
#  'img_03324.jpg',
#  'img_03452.jpg',
#  'img_04237.jpg',
#  'img_07147.jpg',
#  'img_06211.jpg',
#  'img_07628.jpg',
#  'img_07561.jpg',
#  'img_03426.jpg',
#  'img_07094.jpg',
#  'img_02954.jpg',
#  'img_01996.jpg',
#  'img_04559.jpg',
#  'img_05475.jpg',
#  'img_06549.jpg',
#  'img_05438.jpg',
#  'img_01399.jpg',
#  'img_02974.jpg',
#  'img_00943.jpg',
#  'img_00648.jpg',
#  'img_00244.jpg',
#  'img_04145.jpg',
#  'img_03488.jpg',
#  'img_07905.jpg',
#  'img_05059.jpg',
#  'img_00486.jpg',
#  'img_07270.jpg',
#  'img_06259.jpg',
#  'img_06272.jpg',
#  'img_05805.jpg',
#  'img_07426.jpg',
#  'img_03801.jpg',
#  'img_03764.jpg',
#  'img_07583.jpg',
#  'img_03760.jpg',
#  'img_01930.jpg',
#  'img_01657.jpg',
#  'img_06564.jpg',
#  'img_05948.jpg',
#  'img_03602.jpg',
#  'img_01237.jpg',
#  'img_05015.jpg',
#  'img_05916.jpg',
#  'img_05038.jpg',
#  'img_04240.jpg',
#  'img_05359.jpg',
#  'img_05864.jpg',
#  'img_03223.jpg',
#  'img_07375.jpg',
#  'img_01552.jpg',
#  'img_04479.jpg',
#  'img_05454.jpg',
#  'img_00133.jpg',
#  'img_03457.jpg',
#  'img_06506.jpg',
#  'img_00921.jpg',
#  'img_00152.jpg',
#  'img_00484.jpg',
#  'img_03445.jpg',
#  'img_06732.jpg',
#  'img_06294.jpg',
#  'img_00582.jpg',
#  'img_05492.jpg',
#  'img_04962.jpg',
#  'img_03082.jpg',
#  'img_05087.jpg',
#  'img_02904.jpg',
#  'img_02209.jpg',
#  'img_02318.jpg',
#  'img_02808.jpg',
#  'img_02235.jpg',
#  'img_03195.jpg',
#  'img_06892.jpg',
#  'img_06658.jpg',
#  'img_06321.jpg',
#  'img_01593.jpg',
#  'img_05673.jpg',
#  'img_03967.jpg',
#  'img_00760.jpg',
#  'img_01222.jpg',
#  'img_01684.jpg',
#  'img_02066.jpg',
#  'img_06311.jpg',
#  'img_01561.jpg',
#  'img_05410.jpg',
#  'img_04282.jpg',
#  'img_03128.jpg',
#  'img_05915.jpg',
#  'img_05568.jpg',
#  'img_01204.jpg',
#  'img_07160.jpg',
#  'img_05186.jpg',
#  'img_06571.jpg',
#  'img_02560.jpg',
#  'img_02890.jpg',
#  'img_01673.jpg',
#  'img_06067.jpg',
#  'img_03270.jpg',
#  'img_05623.jpg',
#  'img_06673.jpg',
#  'img_00654.jpg',
#  'img_02252.jpg',
#  'img_06642.jpg',
#  'img_04476.jpg',
#  'img_05210.jpg',
#  'img_01179.jpg',
#  'img_00289.jpg',
#  'img_04369.jpg',
#  'img_03750.jpg',
#  'img_06922.jpg',
#  'img_05508.jpg',
#  'img_07663.jpg',
#  'img_01059.jpg',
#  'img_00730.jpg',
#  'img_03996.jpg',
#  'img_07417.jpg',
#  'img_06616.jpg',
#  'img_06936.jpg',
#  'img_01377.jpg',
#  'img_01371.jpg',
#  'img_05244.jpg',
#  'img_07757.jpg',
#  'img_02920.jpg',
#  'img_02573.jpg',
#  'img_04037.jpg',
#  'img_07818.jpg',
#  'img_02416.jpg',
#  'img_03627.jpg',
#  'img_06268.jpg',
#  'img_06831.jpg',
#  'img_05835.jpg',
#  'img_07799.jpg',
#  'img_05378.jpg',
#  'img_01983.jpg',
#  'img_01405.jpg',
#  'img_01618.jpg',
#  'img_05046.jpg',
#  'img_00102.jpg',
#  'img_05817.jpg',
#  'img_03853.jpg',
#  'img_07051.jpg',
#  'img_03471.jpg',
#  'img_05724.jpg',
#  'img_02367.jpg',
#  'img_05293.jpg',
#  'img_02916.jpg',
#  'img_03260.jpg',
#  'img_01058.jpg',
#  'img_07833.jpg',
#  'img_01404.jpg',
#  'img_04482.jpg',
#  'img_04386.jpg',
#  'img_04390.jpg',
#  'img_06808.jpg',
#  'img_03055.jpg',
#  'img_05222.jpg',
#  'img_00180.jpg',
#  'img_07183.jpg',
#  'img_00129.jpg',
#  'img_00125.jpg',
#  'img_07419.jpg',
#  'img_00007.jpg',
#  'img_06902.jpg',
#  'img_06101.jpg',
#  'img_02842.jpg',
#  'img_05672.jpg',
#  'img_01253.jpg',
#  'img_01035.jpg',
#  'img_07122.jpg',
#  'img_04024.jpg',
#  'img_05967.jpg',
#  'img_02372.jpg',
#  'img_02703.jpg',
#  'img_01168.jpg',
#  'img_04415.jpg',
#  'img_05792.jpg',
#  'img_07318.jpg',
#  'img_07005.jpg',
#  'img_01379.jpg',
#  'img_00979.jpg',
#  'img_00902.jpg',
#  'img_06916.jpg',
#  'img_03229.jpg',
#  'img_03809.jpg',
#  'img_07908.jpg',
#  'img_05731.jpg',
#  'img_06099.jpg',
#  'img_05322.jpg',
#  'img_01888.jpg',
#  'img_02625.jpg',
#  'img_04183.jpg',
#  'img_00599.jpg',
#  'img_07044.jpg',
#  'img_02766.jpg',
#  'img_03726.jpg',
#  'img_07563.jpg',
#  'img_02837.jpg',
#  'img_03504.jpg',
#  'img_02789.jpg',
#  'img_07543.jpg',
#  'img_04115.jpg',
#  'img_04257.jpg',
#  'img_06001.jpg',
#  'img_01647.jpg',
#  'img_04268.jpg',
#  'img_02911.jpg',
#  'img_03520.jpg',
#  'img_00858.jpg',
#  'img_04419.jpg',
#  'img_04624.jpg',
#  'img_06455.jpg',
#  'img_01031.jpg',
#  'img_00172.jpg',
#  'img_05595.jpg',
#  'img_00119.jpg',
#  'img_05185.jpg',
#  'img_01530.jpg',
#  'img_00005.jpg',
#  'img_04554.jpg',
#  'img_00777.jpg',
#  'img_01862.jpg',
#  'img_04130.jpg',
#  'img_00046.jpg',
#  'img_06412.jpg',
#  'img_05539.jpg',
#  'img_03952.jpg',
#  'img_02651.jpg',
#  'img_04128.jpg',
#  'img_04181.jpg',
#  'img_06273.jpg',
#  'img_01328.jpg',
#  'img_06748.jpg',
#  'img_00103.jpg',
#  'img_00171.jpg',
#  'img_00966.jpg',
#  'img_02379.jpg',
#  'img_04657.jpg',
#  'img_00948.jpg',
#  'img_05241.jpg',
#  'img_04949.jpg',
#  'img_06010.jpg',
#  'img_06939.jpg',
#  'img_07921.jpg',
#  'img_01325.jpg',
#  'img_07179.jpg',
#  'img_01781.jpg',
#  'img_03892.jpg',
#  'img_05979.jpg',
#  'img_04036.jpg',
#  'img_07553.jpg',
#  'img_06611.jpg',
#  'img_01177.jpg',
#  'img_03440.jpg',
#  'img_03674.jpg',
#  'img_01803.jpg',
#  'img_06806.jpg',
#  'img_07659.jpg',
#  'img_07050.jpg',
#  'img_04562.jpg',
#  'img_05445.jpg',
#  'img_06144.jpg',
#  'img_04323.jpg',
#  'img_06756.jpg',
#  'img_00959.jpg',
#  'img_05433.jpg',
#  'img_02119.jpg',
#  'img_05908.jpg',
#  'img_05479.jpg',
#  'img_00141.jpg',
#  'img_03886.jpg',
#  'img_02769.jpg',
#  'img_03869.jpg',
#  'img_04640.jpg',
#  'img_04507.jpg',
#  'img_00724.jpg',
#  'img_03942.jpg',
#  'img_07251.jpg',
#  'img_00407.jpg',
#  'img_05074.jpg',
#  'img_00833.jpg',
#  'img_02159.jpg',
#  'img_02622.jpg',
#  'img_06033.jpg',
#  'img_05653.jpg',
#  'img_04250.jpg',
#  'img_04076.jpg',
#  'img_06698.jpg',
#  'img_01384.jpg',
#  'img_04453.jpg',
#  'img_01687.jpg',
#  'img_03080.jpg',
#  'img_01208.jpg',
#  'img_00533.jpg',
#  'img_02083.jpg',
#  'img_00757.jpg',
#  'img_04427.jpg',
#  'img_01831.jpg',
#  'img_06038.jpg',
#  'img_03140.jpg',
#  'img_04261.jpg',
#  'img_02889.jpg',
#  'img_05393.jpg',
#  'img_02546.jpg',
#  'img_01685.jpg',
#  'img_00311.jpg',
#  'img_04138.jpg',
#  'img_00927.jpg',
#  'img_01505.jpg',
#  'img_06508.jpg',
#  'img_02641.jpg',
#  'img_03941.jpg',
#  'img_07906.jpg',
#  'img_00974.jpg',
#  'img_00432.jpg',
#  'img_05434.jpg',
#  'img_04266.jpg',
#  'img_03992.jpg',
#  'img_01802.jpg',
#  'img_02291.jpg',
#  'img_07045.jpg',
#  'img_05064.jpg',
#  'img_03923.jpg',
#  'img_02412.jpg',
#  'img_05084.jpg',
#  'img_05692.jpg',
#  'img_02507.jpg',
#  'img_06065.jpg',
#  'img_02356.jpg',
#  'img_03825.jpg',
#  'img_07434.jpg',
#  'img_03924.jpg',
#  'img_07120.jpg',
#  'img_03446.jpg',
#  'img_05095.jpg',
#  'img_06975.jpg',
#  'img_03346.jpg',
#  'img_02135.jpg',
#  'img_02305.jpg',
#  'img_00780.jpg',
#  'img_04975.jpg',
#  'img_03929.jpg',
#  'img_02993.jpg',
#  'img_05824.jpg',
#  'img_04405.jpg',
#  'img_02540.jpg',
#  'img_00717.jpg',
#  'img_00320.jpg',
#  'img_04959.jpg',
#  'img_02172.jpg',
#  'img_02522.jpg',
#  'img_07086.jpg',
#  'img_02656.jpg',
#  'img_00982.jpg',
#  'img_00697.jpg',
#  'img_06783.jpg',
#  'img_01043.jpg',
#  'img_05459.jpg',
#  'img_04675.jpg',
#  'img_00109.jpg',
#  'img_01571.jpg',
#  'img_05268.jpg',
#  'img_00894.jpg',
#  'img_03310.jpg',
#  'img_05766.jpg',
#  'img_02400.jpg',
#  'img_06477.jpg',
#  'img_05587.jpg',
#  'img_06807.jpg',
#  'img_05580.jpg',
#  'img_00550.jpg',
#  'img_07330.jpg',
#  'img_05548.jpg',
#  'img_05156.jpg',
#  'img_03228.jpg',
#  'img_07137.jpg',
#  'img_02384.jpg',
#  'img_05211.jpg',
#  'img_02078.jpg',
#  'img_05654.jpg',
#  'img_06684.jpg',
#  'img_06780.jpg',
#  'img_04310.jpg',
#  'img_02282.jpg',
#  'img_06076.jpg',
#  'img_02871.jpg',
#  'img_03931.jpg',
#  'img_06059.jpg',
#  'img_03670.jpg',
#  'img_01541.jpg',
#  'img_07146.jpg',
#  'img_01640.jpg',
#  'img_04520.jpg',
#  'img_03181.jpg',
#  'img_07717.jpg',
#  'img_01918.jpg',
#  'img_00889.jpg',
#  'img_06959.jpg',
#  'img_00618.jpg',
#  'img_07508.jpg',
#  'img_01745.jpg',
#  'img_01771.jpg',
#  'img_06681.jpg',
#  'img_04478.jpg',
#  'img_00999.jpg',
#  'img_01681.jpg',
#  'img_05721.jpg',
#  'img_03297.jpg',
#  'img_01519.jpg',
#  'img_05963.jpg',
#  'img_03928.jpg',
#  'img_06914.jpg',
#  'img_03135.jpg',
#  'img_03444.jpg',
#  'img_01444.jpg',
#  'img_04795.jpg',
#  'img_03355.jpg',
#  'img_00876.jpg',
#  'img_07420.jpg',
#  'img_02739.jpg',
#  'img_02082.jpg',
#  'img_07224.jpg',
#  'img_03554.jpg',
#  'img_05292.jpg',
#  'img_04408.jpg',
#  'img_01431.jpg',
#  'img_00962.jpg',
#  'img_06238.jpg',
#  'img_07354.jpg',
#  'img_05794.jpg',
#  'img_06585.jpg',
#  'img_05754.jpg',
#  'img_04002.jpg',
#  'img_01142.jpg',
#  'img_04629.jpg',
#  'img_00716.jpg',
#  'img_03410.jpg',
#  'img_05253.jpg',
#  'img_03945.jpg',
#  'img_05981.jpg',
#  'img_03074.jpg',
#  'img_02666.jpg',
#  'img_04127.jpg',
#  'img_06345.jpg',
#  'img_07110.jpg',
#  'img_06870.jpg',
#  'img_07068.jpg',
#  'img_04647.jpg',
#  'img_01022.jpg',
#  'img_04001.jpg',
#  'img_03946.jpg',
#  'img_07173.jpg',
#  'img_05558.jpg',
#  'img_05525.jpg',
#  'img_02077.jpg',
#  'img_01366.jpg',
#  'img_02733.jpg',
#  'img_04375.jpg',
#  'img_05790.jpg',
#  'img_00729.jpg',
#  'img_00587.jpg',
#  'img_05755.jpg',
#  'img_00128.jpg',
#  'img_05640.jpg',
#  'img_05085.jpg',
#  'img_00798.jpg',
#  'img_07191.jpg',
#  'img_02270.jpg',
#  'img_06955.jpg',
#  'img_03399.jpg',
#  'img_03290.jpg',
#  'img_07469.jpg',
#  'img_04126.jpg',
#  'img_00538.jpg',
#  'img_06318.jpg',
#  'img_05471.jpg',
#  'img_06522.jpg',
#  'img_04101.jpg',
#  'img_02771.jpg',
#  'img_01646.jpg',
#  'img_07893.jpg',
#  'img_01286.jpg',
#  'img_03261.jpg',
#  'img_05328.jpg',
#  'img_05192.jpg',
#  'img_06237.jpg',
#  'img_04503.jpg',
#  'img_00723.jpg',
#  'img_05269.jpg',
#  'img_07578.jpg',
#  'img_01426.jpg',
#  'img_03563.jpg',
#  'img_00272.jpg',
#  'img_00575.jpg',
#  'img_07199.jpg',
#  'img_01171.jpg',
#  'img_03715.jpg',
#  'img_04069.jpg',
#  'img_01716.jpg',
#  'img_02076.jpg',
#  'img_02565.jpg',
#  'img_01976.jpg',
#  'img_03490.jpg',
#  'img_07314.jpg',
#  'img_04811.jpg',
#  'img_07371.jpg',
#  'img_05341.jpg',
#  'img_02001.jpg',
#  'img_00473.jpg',
#  'img_05349.jpg',
#  'img_05958.jpg',
#  'img_00161.jpg',
#  'img_04324.jpg',
#  'img_01188.jpg',
#  'img_00620.jpg',
#  'img_06469.jpg',
#  'img_03527.jpg',
#  'img_07409.jpg',
#  'img_00164.jpg',
#  'img_05196.jpg',
#  'img_07054.jpg',
#  'img_07621.jpg',
#  'img_04750.jpg',
#  'img_04422.jpg',
#  'img_06962.jpg',
#  'img_07474.jpg',
#  'img_05276.jpg',
#  'img_04073.jpg',
#  'img_05489.jpg',
#  'img_06608.jpg',
#  'img_07895.jpg',
#  'img_04118.jpg',
#  'img_00223.jpg',
#  'img_05139.jpg',
#  'img_01824.jpg',
#  'img_04136.jpg',
#  'img_04766.jpg',
#  'img_03749.jpg',
#  'img_07872.jpg',
#  'img_06440.jpg',
#  'img_00053.jpg',
#  'img_06893.jpg',
#  'img_03454.jpg',
#  'img_03043.jpg',
#  'img_01966.jpg',
#  'img_02006.jpg',
#  'img_07319.jpg',
#  'img_06541.jpg',
#  'img_04511.jpg',
#  'img_06947.jpg',
#  'img_01632.jpg',
#  'img_03361.jpg',
#  'img_00196.jpg',
#  'img_00071.jpg',
#  'img_07526.jpg',
#  'img_06475.jpg',
#  'img_03116.jpg',
#  'img_07065.jpg',
#  'img_05743.jpg',
#  'img_05055.jpg',
#  'img_05440.jpg',
#  'img_05336.jpg',
#  'img_06851.jpg',
#  'img_07528.jpg',
#  'img_06037.jpg',
#  'img_02216.jpg',
#  'img_01963.jpg',
#  'img_06165.jpg',
#  'img_03210.jpg',
#  'img_02180.jpg',
#  'img_00138.jpg',
#  'img_02574.jpg',
#  'img_03871.jpg',
#  'img_05989.jpg',
#  'img_05260.jpg',
#  'img_02124.jpg',
#  'img_06798.jpg',
#  'img_05775.jpg',
#  'img_00664.jpg',
#  'img_07304.jpg',
#  'img_03254.jpg',
#  'img_03776.jpg',
#  'img_05953.jpg',
#  'img_04341.jpg',
#  'img_06860.jpg',
#  'img_02231.jpg',
#  'img_01825.jpg',
#  'img_00230.jpg',
#  'img_02857.jpg',
#  'img_00375.jpg',
#  'img_04247.jpg',
#  'img_07678.jpg',
#  'img_06349.jpg',
#  'img_07623.jpg',
#  'img_05520.jpg',
#  'img_06346.jpg',
#  'img_01955.jpg',
#  'img_03502.jpg',
#  'img_07192.jpg',
#  'img_02268.jpg',
#  'img_01543.jpg',
#  'img_04271.jpg',
#  'img_03078.jpg',
#  'img_05026.jpg',
#  'img_07514.jpg',
#  'img_02638.jpg',
#  'img_04321.jpg',
#  'img_06946.jpg',
#  'img_06003.jpg',
#  'img_04696.jpg',
#  'img_00584.jpg',
#  'img_02096.jpg',
#  'img_02964.jpg',
#  'img_04586.jpg',
#  'img_03831.jpg',
#  'img_01782.jpg',
#  'img_05657.jpg',
#  'img_03312.jpg',
#  'img_02563.jpg',
#  'img_06899.jpg',
#  'img_02838.jpg',
#  'img_04263.jpg',
#  'img_00282.jpg',
#  'img_05813.jpg',
#  'img_03739.jpg',
#  'img_04642.jpg',
#  'img_00040.jpg',
#  'img_04221.jpg',
#  'img_01856.jpg',
#  'img_04156.jpg',
#  'img_00212.jpg',
#  'img_05719.jpg',
#  'img_00285.jpg',
#  'img_07594.jpg',
#  'img_04129.jpg',
#  'img_01995.jpg',
#  'img_06371.jpg',
#  'img_01289.jpg',
#  'img_02194.jpg',
#  'img_06832.jpg',
#  'img_04835.jpg',
#  'img_05209.jpg',
#  'img_06285.jpg',
#  'img_03422.jpg',
#  'img_06324.jpg',
#  'img_00564.jpg',
#  'img_05584.jpg',
#  'img_03439.jpg',
#  'img_07348.jpg',
#  'img_06147.jpg',
#  'img_04003.jpg',
#  'img_07023.jpg',
#  'img_04712.jpg',
#  'img_05615.jpg',
#  'img_01562.jpg',
#  'img_02949.jpg',
#  'img_06630.jpg',
#  'img_00018.jpg',
#  'img_01627.jpg',
#  'img_06042.jpg',
#  'img_02479.jpg',
#  'img_05940.jpg',
#  'img_02734.jpg',
#  'img_05572.jpg',
#  'img_07574.jpg',
#  'img_03588.jpg',
#  'img_02602.jpg',
#  'img_03548.jpg',
#  'img_03866.jpg',
#  'img_02309.jpg',
#  'img_03935.jpg',
#  'img_00075.jpg',
#  'img_02709.jpg',
#  'img_06097.jpg',
#  'img_04425.jpg',
#  'img_07859.jpg',
#  'img_02646.jpg',
#  'img_07187.jpg',
#  'img_07910.jpg',
#  'img_06373.jpg',
#  'img_02487.jpg',
#  'img_07501.jpg',
#  'img_00646.jpg',
#  'img_01847.jpg',
#  'img_05488.jpg',
#  'img_06525.jpg',
#  'img_01090.jpg',
#  'img_00914.jpg',
#  'img_00493.jpg',
#  'img_01134.jpg',
#  'img_03333.jpg',
#  'img_01834.jpg',
#  'img_00030.jpg',
#  'img_00417.jpg',
#  'img_03166.jpg',
#  'img_06849.jpg',
#  'img_01102.jpg',
#  'img_00292.jpg',
#  'img_01932.jpg',
#  'img_04603.jpg',
#  'img_06690.jpg',
#  'img_06921.jpg',
#  'img_07143.jpg',
#  'img_06210.jpg',
#  'img_00374.jpg',
#  'img_04870.jpg',
#  'img_06302.jpg',
#  'img_03547.jpg',
#  'img_00985.jpg',
#  'img_00808.jpg',
#  'img_00280.jpg',
#  'img_01213.jpg',
#  'img_06496.jpg',
#  'img_05722.jpg',
#  'img_05439.jpg',
#  'img_07460.jpg',
#  'img_07079.jpg',
#  'img_02146.jpg',
#  'img_05147.jpg',
#  'img_07436.jpg',
#  'img_00773.jpg',
#  'img_00718.jpg',
#  'img_01717.jpg',
#  'img_03370.jpg',
#  'img_05273.jpg',
#  'img_00667.jpg']

# %% [raw]
# ###clear log an checkpoints folder
#
# if not os.path.exists('./checkpoints'):
#     os.mkdir('./checkpoints')
# files = glob.glob('./checkpoints/*')
# for f in files:
#     os.remove(f)
#
# #if not os.path.exists('./logs'):
# #    os.mkdir('./logs')
# files = glob.glob('./logs/*')
# for f in files:
#     os.remove(f)
