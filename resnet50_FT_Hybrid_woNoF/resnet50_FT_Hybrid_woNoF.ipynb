# %% [raw]
# fine tuning stg2 conv5a start_layer = 142
# resnet50 finetuning
# data crop without nof
#
# top layer training to end
# weights.349-0.8371.hdf5
#
# fine tuning stg1 conv5c start_layer = 164
# weights.539-0.3229.hdf5
# 30/30 [==============================] - 50s - loss: 0.4140 - acc: 0.9311 - val_loss: 0.3229 - val_acc: 0.8960
#
# fine tuning stg2 conv5b start_layer = 154
# weights.630-0.2407.hdf5
# 30/30 [==============================] - 53s - loss: 0.2103 - acc: 0.9638 - val_loss: 0.2407 - val_acc: 0.9362
#
# fine tuning stg3 conv5a start_layer = 142
# weights.683-0.1587.hdf5
# 30/30 [==============================] - 58s - loss: 0.0684 - acc: 0.9927 - val_loss: 0.1587 - val_acc: 0.9527
#
# fine tuning stg4 conv4f start_layer = 132
# weights.724-0.1355.hdf5
# 30/30 [==============================] - 58s - loss: 0.0411 - acc: 0.9946 - val_loss: 0.1355 - val_acc: 0.9764
#
# fine tuning stg5 conv4 start_layer = 80
# weights.759-0.1231.hdf5
# 30/30 [==============================] - 74s - loss: 0.0141 - acc: 0.9974 - val_loss: 0.1231 - val_acc: 0.9693

# %%
import os, random, glob, pickle, collections, math, json
import numpy as np
import pandas as pd
from __future__ import division
from __future__ import print_function
from PIL import Image
from sklearn.model_selection import train_test_split
from sklearn.metrics import log_loss
from sklearn.preprocessing import LabelEncoder

import matplotlib.pyplot as plt
# %matplotlib inline 

from keras.models import Sequential, Model, load_model, model_from_json
from keras import layers
from keras.layers import GlobalAveragePooling2D, Flatten, Dropout, Dense, LeakyReLU, Conv2D, Input, BatchNormalization, Activation
from keras.regularizers import l2
from keras.optimizers import Adam, RMSprop
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, TensorBoard
from keras.preprocessing.image import ImageDataGenerator
from keras.utils import np_utils
from keras.preprocessing import image
from keras import backend as K
K.set_image_dim_ordering('tf')
# Out:
# Using TensorFlow backend.

# %%
TRAIN_DIR = '../data/train/'
TEST_DIR = '../RFCN/JPEGImages/'
TRAIN_CROP_DIR = '../data/train_crop/'
TEST_CROP_DIR = '../data/test_stg1_crop/'
RFCN_MODEL = 'resnet101_rfcn_ohem_iter_30000'
CROP_MODEL = 'resnet50_FT_Hybrid_woNoF'
if os.getcwd().split('/')[-1] != CROP_MODEL:
    print('WRONG CROP_MODEL DIR!!!')
CHECKPOINT_DIR = './checkpoint/'
if not os.path.exists(CHECKPOINT_DIR):
    os.mkdir(CHECKPOINT_DIR)
LOG_DIR = './log/'
if not os.path.exists(LOG_DIR):
    os.mkdir(LOG_DIR)
OUTPUT_DIR = './output/'
if not os.path.exists(OUTPUT_DIR):
    os.mkdir(OUTPUT_DIR)
FISH_CLASSES = ['NoF', 'ALB', 'BET', 'DOL', 'LAG', 'OTHER', 'SHARK', 'YFT']
CROP_CLASSES=FISH_CLASSES[:]
CROP_CLASSES.remove('NoF')
TESTFRAC = 0.9
CONF_THRESH = 0.8
ROWS = 224
COLS = 224
BATCHSIZE = 128
LEARNINGRATE = 1e-4
def featurewise_center(x):
    mean = np.mean(x, axis=0, keepdims=True)
    mean = np.mean(mean, axis=(1,2), keepdims=True)
    x_centered = x - mean
    return x_centered

def featurewise_mean(x):
    mean = np.mean(x, axis=0)
    mean = np.mean(mean, axis=(0,1))
    return mean

def preprocess_featurewise(x, featurewise_mean):
    x -= np.reshape(featurewise_mean, [1, 1, 3])
    return x

def load_img(path, bbox, target_size=None):
    img = Image.open(path)
    cropped = img.crop((bbox[0],bbox[1],bbox[2],bbox[3]))
    width_cropped, height_cropped = cropped.size
    if height_cropped > width_cropped: cropped = cropped.transpose(method=2)  
    if target_size:
        cropped = cropped.resize((target_size[1], target_size[0]), Image.BILINEAR)
    return cropped

def get_best_model(checkpoint_dir = CHECKPOINT_DIR):
    files = glob.glob(checkpoint_dir+'*')
    val_losses = [float(f.split('-')[-1][:-5]) for f in files]
    index = val_losses.index(min(val_losses))
    print('Loading model from checkpoint file ' + files[index])
    model = load_model(files[index])
    model_name = files[index].split('/')[-1]
    print('Loading model Done!')
    return (model, model_name)

def data_from_df(df):
    X = np.ndarray((df.shape[0], ROWS, COLS, 3), dtype=np.uint8)
    y = np.zeros((df.shape[0], len(CROP_CLASSES)), dtype=K.floatx())
    i = 0
    for index,row in df.iterrows():
        image_file = row['image_file']
        fish = row['crop_class']
        bbox = [row['xmin'],row['ymin'],row['xmax'],row['ymax']]
        cropped = load_img(TEST_DIR+image_file,bbox,target_size=(ROWS,COLS))
        X[i] = np.asarray(cropped)
        y[i,CROP_CLASSES.index(fish)] = 1
        i += 1
    return (X, y)

def data_load(name):
    file_name = 'data_'+name+'_{}_{}.pickle'.format(ROWS, COLS)
    if os.path.exists(OUTPUT_DIR+file_name):
        print ('Loading from file '+file_name)
        with open(OUTPUT_DIR+file_name, 'rb') as f:
            data = pickle.load(f)
        X = data['X']
        y = data['y']
    else:
        print ('Generating file '+file_name)
        
        if name=='train' or name=='valid': 
            df = GTbbox_df[GTbbox_df['split']==name]
        elif name=='all':
            df = GTbbox_df
        else:
            print('Invalid name '+name)
    
        X, y = data_from_df(df)

        data = {'X': X,'y': y}
        with open(OUTPUT_DIR+file_name, 'wb') as f:
            pickle.dump(data, f)
    X = X.astype(np.float32)
    X /= 255.
    return (X, y)

# %%
# GTbbox_df = ['image_file','image_class','crop_index','crop_class','xmin',''ymin','xmax','ymax','split']

file_name = 'GTbbox_df.pickle'
if os.path.exists(OUTPUT_DIR+file_name):
    print ('Loading from file '+file_name)
    GTbbox_df = pd.read_pickle(OUTPUT_DIR+file_name)
else:
    print ('Generating file '+file_name)       
    GTbbox_df = pd.DataFrame(columns=['image_file','image_class','crop_index','crop_class','xmin','ymin','xmax','ymax'])  

    crop_classes=FISH_CLASSES[:]
    crop_classes.remove('NoF')
    with open("../RFCN/ImageSets/Main/train_test.txt","r") as f:
        train_file_labels = f.readlines()
        
    for c in crop_classes:
        print(c)
        j = json.load(open('../data/BBannotations/{}.json'.format(c), 'r'))
        for l in j: 
            filename = l["filename"]
            head, image_file = os.path.split(filename)
            basename, file_extension = os.path.splitext(image_file)
            for i in range(len(train_file_labels)):
                if train_file_labels[i][:9] == basename:
                    image_class = train_file_labels[i][10:-1]
                    break
            image = Image.open(TEST_DIR+'/'+image_file)
            width_image, height_image = image.size
            for i in range(len(l["annotations"])):
                a = l["annotations"][i]
                xmin = (a["x"])
                ymin = (a["y"])
                width = (a["width"])
                height = (a["height"])
                xmax = xmin + width
                ymax = ymin + height
                assert max(xmin,0)<min(xmax,width_image)
                assert max(ymin,0)<min(ymax,height_image)
                GTbbox_df.loc[len(GTbbox_df)]=[image_file,image_class,i,a["class"],max(xmin,0),max(ymin,0),min(xmax,width_image),min(ymax,height_image)] 

    image_files_df = GTbbox_df[['image_file','image_class']]
    image_files_df.drop_duplicates(inplace = True)
    test_file_nb = image_files_df.shape[0] - int(math.ceil(image_files_df.shape[0]*TESTFRAC))
    train_files_df, valid_files_df = train_test_split(image_files_df, test_size=test_file_nb, random_state=1986, stratify=image_files_df.image_class)
    GTbbox_df['split'] = ['train' if image_file in train_files_df.image_file.tolist() else 'valid' for image_file in GTbbox_df.image_file]

    GTbbox_df.to_pickle(OUTPUT_DIR+file_name)
    print('Done')

# GTbbox_df.loc[(GTbbox_df['image_class']!='NoF') & (GTbbox_df['crop_class']!='NoF') & (GTbbox_df['image_class']!=GTbbox_df['crop_class'])]
# Out:
# Loading from file GTbbox_df.pickle

# %% [raw]
# train_file_df = GTbbox_df.loc[GTbbox_df['split']=='train',['image_file','image_class']]
# train_file_df.drop_duplicates(inplace = True)
# print('total train image:', train_file_df.shape[0])
# print(train_file_df.groupby('image_class').size())
#
# valid_file_df = GTbbox_df.loc[GTbbox_df['split']=='valid',['image_file','image_class']]
# valid_file_df.drop_duplicates(inplace = True)
# print('total valid image:', valid_file_df.shape[0])
# print(valid_file_df.groupby('image_class').size())
#
# train_df = GTbbox_df.loc[GTbbox_df['split']=='train']
# print('total train crop:', train_df.shape[0])
# print(train_df.groupby('crop_class').size())
#
# valid_df = GTbbox_df.loc[GTbbox_df['split']=='valid']
# print('total vaid crop:', valid_df.shape[0])
# print(valid_df.groupby('crop_class').size())

# %%
#Load data

X_all, y_all = data_load('all')
X_train, y_train = data_load('train')
X_valid, y_valid = data_load('valid')  
print('Loading data done.')

print('all sample ', X_all.shape[0])
print('train sample ', X_train.shape[0])
print('valid sample ', X_valid.shape[0])

print('featurewise mean of X_all is ', featurewise_mean(X_all))
print('featurewise mean of X_train is ', featurewise_mean(X_train))
print('featurewise mean of X_valid is ', featurewise_mean(X_valid))
# Out:
# Loading from file data_all_224_224.pickle
# Loading from file data_train_224_224.pickle
# Loading from file data_valid_224_224.pickle
# Loading data done.
# all sample  4371
# train sample  3948
# valid sample  423
# featurewise mean of X_all is  [ 0.40696082  0.43766695  0.3947188 ]
# featurewise mean of X_train is  [ 0.40635169  0.43670505  0.39435506]
# featurewise mean of X_valid is  [ 0.41260275  0.4466438   0.39812338]

# %%
# #class weight = n_samples / (n_classes * np.bincount(y))
# class_weight_fish = dict(GTbbox_df.groupby('crop_class').size())
# class_weight = {}
# n_samples = GTbbox_df.shape[0]
# for key,value in class_weight_fish.items():
#         class_weight[CROP_CLASSES.index(key)] = n_samples / (len(CROP_CLASSES)*value)
# class_weight

train_df = GTbbox_df[GTbbox_df['split']=='train']
class_weight_fish = dict(train_df.groupby('crop_class').size())
class_weight = {}
ref = max(class_weight_fish.values())
for key,value in class_weight_fish.items():
    class_weight[CROP_CLASSES.index(key)] = ref/value
class_weight
# Out:
# {0: 1.0,
#  1: 8.1035714285714278,
#  2: 19.903508771929825,
#  3: 24.138297872340427,
#  4: 7.5132450331125824,
#  5: 13.269005847953217,
#  6: 3.1601671309192199}

# %%
#data preprocessing

all_mean = featurewise_mean(X_all)
def preprocessing_function(x):
    x -= np.reshape(all_mean, [1, 1, 3])
    return x

train_datagen = ImageDataGenerator(
    preprocessing_function=preprocessing_function,
    rotation_range=180,
    shear_range=0.2,
    zoom_range=0.1,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    vertical_flip=True)
train_generator = train_datagen.flow(X_train, y_train, batch_size=BATCHSIZE, shuffle=True, seed=None)
# assert X_train.shape[0]%BATCHSIZE==0
steps_per_epoch = int(math.floor(X_train.shape[0]/BATCHSIZE))

X_valid_centered = X_valid - np.reshape(all_mean, [1, 1, 1, 3])

# %%
#callbacks

early_stopping = EarlyStopping(monitor='val_loss', min_delta=0, patience=25, verbose=1, mode='auto')        

model_checkpoint = ModelCheckpoint(filepath=CHECKPOINT_DIR+'weights.{epoch:03d}-{val_loss:.4f}.hdf5', monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False, mode='auto')
        
learningrate_schedule = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=10, verbose=1, mode='auto', epsilon=0.001, cooldown=0, min_lr=0)

tensorboard = TensorBoard(log_dir=LOG_DIR, histogram_freq=0, write_graph=False, write_images=True)

# %%
# Resnet50
#top layer training to end

from keras.applications.resnet50 import ResNet50

base_model = ResNet50(weights='imagenet', include_top=False)
x = base_model.output
x = GlobalAveragePooling2D()(x)
# x = Dropout(0.5)(x)
predictions = Dense(len(CROP_CLASSES), kernel_initializer='glorot_normal', activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=predictions)

# first: train only the top layers (which were randomly initialized)
for layer in base_model.layers:
    layer.trainable = False

# compile the model (should be done *after* setting layers to non-trainable)
optimizer = Adam(lr=1e-4)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

print('BATCHSIZE:', BATCHSIZE)
# train the model on the new data for a few epochs
model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=2000, verbose=1, 
                    callbacks=[early_stopping, model_checkpoint, learningrate_schedule, tensorboard], 
                    validation_data=(X_valid_centered, y_valid), 
                    class_weight=class_weight, workers=3, pickle_safe=True)

# %%
### Resnet50
# fine tuning stg1
# 164 conv5c+top
# 142 conv5+top
# 80 conv4+conv5+top
# 38 conv3+conv4+conv5+top
# 6 conv2+conv3+conv4+conv5+top
# 2 conv1+conv2+conv3+conv4+conv5+top i.e. FROM SCRATCH
start_layer = 164

model, model_name = get_best_model()
# model = load_model(CHECKPOINT_DIR + 'weights.029-0.3772.hdf5')
# model_name = 'weights.029-0.3772.hdf5'
# print('model_name', model_name)

for layer in model.layers[:start_layer]:
   layer.trainable = False
for layer in model.layers[start_layer:]:
   layer.trainable = True

# we need to recompile the model for these modifications to take effect
# we use SGD with a low learning rate
optimizer = Adam(lr=1e-5)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

print('BATCHSIZE', BATCHSIZE)
model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=2000, verbose=1, 
                    callbacks=[early_stopping, model_checkpoint, learningrate_schedule, tensorboard], 
                    validation_data=(X_valid_centered, y_valid), 
                    class_weight=class_weight, workers=3, pickle_safe=True, initial_epoch=350)
# Out:
# Loading model from checkpoint file ./checkpoint/weights.349-0.8371.hdf5
# Loading model Done!
# BATCHSIZE 128
# Epoch 351/2000
# Epoch 00350: val_loss improved from 0.83747 to 0.80893, saving model to ./checkpoint/weights.350-0.8089.hdf5
# 30/30 [==============================] - 58s - loss: 2.4181 - acc: 0.6773 - val_loss: 0.8089 - val_acc: 0.7305
# Epoch 352/2000
# Epoch 00351: val_loss did not improve
# 30/30 [==============================] - 50s - loss: 2.5682 - acc: 0.6755 - val_loss: 0.8119 - val_acc: 0.7329
# Epoch 353/2000
# Epoch 00352: val_loss improved from 0.80893 to 0.80402, saving model to ./checkpoint/weights.352-0.8040.hdf5
# 30/30 [==============================] - 51s - loss: 2.3679 - acc: 0.6687 - val_loss: 0.8040 - val_acc: 0.7281
# Epoch 354/2000
# Epoch 00353: val_loss did not improve
# 30/30 [==============================] - 50s - loss: 2.4068 - acc: 0.6842 - val_loss: 0.8080 - val_acc: 0.7281
# Epoch 355/2000
# Epoch 00354: val_loss did not improve
# 30/30 [==============================] - 50s - loss: 2.3399 - acc: 0.6745 - val_loss: 0.8062 - val_acc: 0.7305
# Epoch 356/2000
# Epoch 00355: val_loss improved from 0.80402 to 0.77969, saving model to ./checkpoint/weights.355-0.7797.hdf5
# 30/30 [==============================] - 51s - loss: 2.1469 - acc: 0.6953 - val_loss: 0.7797 - val_acc: 0.7376
# Epoch 357/2000
# Epoch 00356: val_loss did not improve
# 30/30 [==============================] - 52s - loss: 2.2256 - acc: 0.6874 - val_loss: 0.7862 - val_acc: 0.7352
# Epoch 358/2000
# Epoch 00357: val_loss improved from 0.77969 to 0.76895, saving model to ./checkpoint/weights.357-0.7690.hdf5
# 30/30 [==============================] - 51s - loss: 2.1696 - acc: 0.6935 - val_loss: 0.7690 - val_acc: 0.7423
# Epoch 359/2000
# Epoch 00358: val_loss did not improve
# 30/30 [==============================] - 50s - loss: 2.1645 - acc: 0.6997 - val_loss: 0.7695 - val_acc: 0.7352
# Epoch 360/2000
# Epoch 00359: val_loss improved from 0.76895 to 0.74536, saving model to ./checkpoint/weights.359-0.7454.hdf5
# 30/30 [==============================] - 50s - loss: 2.0707 - acc: 0.7041 - val_loss: 0.7454 - val_acc: 0.7518
# Epoch 361/2000
# Epoch 00360: val_loss improved from 0.74536 to 0.73107, saving model to ./checkpoint/weights.360-0.7311.hdf5
# 30/30 [==============================] - 51s - loss: 2.0086 - acc: 0.7159 - val_loss: 0.7311 - val_acc: 0.7541
# Epoch 362/2000
# Epoch 00361: val_loss did not improve
# 30/30 [==============================] - 50s - loss: 2.0718 - acc: 0.7208 - val_loss: 0.7416 - val_acc: 0.7518
# Epoch 363/2000
# Epoch 00362: val_loss did not improve
# 30/30 [==============================] - 50s - loss: 2.0549 - acc: 0.7061 - val_loss: 0.7485 - val_acc: 0.7518
# Epoch 364/2000
# Epoch 00363: val_loss did not improve
# 30/30 [==============================] - 50s - loss: 1.9772 - acc: 0.7122 - val_loss: 0.7349 - val_acc: 0.7518
# Epoch 365/2000
# Epoch 00364: val_loss improved from 0.73107 to 0.70915, saving model to ./checkpoint/weights.364-0.7092.hdf5
# 30/30 [==============================] - 51s - loss: 1.8743 - acc: 0.7177 - val_loss: 0.7092 - val_acc: 0.7636
# Epoch 366/2000
# Epoch 00365: val_loss improved from 0.70915 to 0.69178, saving model to ./checkpoint/weights.365-0.6918.hdf5
# 30/30 [==============================] - 50s - loss: 1.8913 - acc: 0.7276 - val_loss: 0.6918 - val_acc: 0.7707
# Epoch 367/2000
# Epoch 00366: val_loss did not improve
# 30/30 [==============================] - 51s - loss: 1.8782 - acc: 0.7372 - val_loss: 0.7057 - val_acc: 0.7612
# Epoch 368/2000
# Epoch 00367: val_loss did not improve
# 30/30 [==============================] - 50s - loss: 1.8715 - acc: 0.7411 - val_loss: 0.7096 - val_acc: 0.7541
# Epoch 369/2000
# Epoch 00368: val_loss did not improve
# 30/30 [==============================] - 50s - loss: 1.8887 - acc: 0.7233 - val_loss: 0.7097 - val_acc: 0.7494
# Epoch 370/2000
# Epoch 00369: val_loss did not improve
# 30/30 [==============================] - 51s - loss: 1.8141 - acc: 0.7432 - val_loss: 0.6978 - val_acc: 0.7541
# Epoch 371/2000
# Epoch 00370: val_loss improved from 0.69178 to 0.68840, saving model to ./checkpoint/weights.370-0.6884.hdf5
# 30/30 [==============================] - 51s - loss: 1.7222 - acc: 0.7513 - val_loss: 0.6884 - val_acc: 0.7612
# Epoch 372/2000
# Epoch 00371: val_loss improved from 0.68840 to 0.68820, saving model to ./checkpoint/weights.371-0.6882.hdf5
# 30/30 [==============================] - 50s - loss: 1.7126 - acc: 0.7304 - val_loss: 0.6882 - val_acc: 0.7636
# Epoch 373/2000
# Epoch 00372: val_loss improved from 0.68820 to 0.68428, saving model to ./checkpoint/weights.372-0.6843.hdf5
# 30/30 [==============================] - 51s - loss: 1.7451 - acc: 0.7505 - val_loss: 0.6843 - val_acc: 0.7612
# Epoch 374/2000
# Epoch 00373: val_loss improved from 0.68428 to 0.67510, saving model to ./checkpoint/weights.373-0.6751.hdf5
# 30/30 [==============================] - 51s - loss: 1.7360 - acc: 0.7461 - val_loss: 0.6751 - val_acc: 0.7589
# Epoch 375/2000
# Epoch 00374: val_loss improved from 0.67510 to 0.66980, saving model to ./checkpoint/weights.374-0.6698.hdf5
# 30/30 [==============================] - 50s - loss: 1.5595 - acc: 0.7674 - val_loss: 0.6698 - val_acc: 0.7565
# Epoch 376/2000
# Epoch 00375: val_loss did not improve
# 30/30 [==============================] - 51s - loss: 1.6453 - acc: 0.7630 - val_loss: 0.6713 - val_acc: 0.7589
# Epoch 377/2000
# Epoch 00376: val_loss improved from 0.66980 to 0.66018, saving model to ./checkpoint/weights.376-0.6602.hdf5
# 30/30 [==============================] - 51s - loss: 1.6065 - acc: 0.7732 - val_loss: 0.6602 - val_acc: 0.7683
# Epoch 378/2000
# Epoch 00377: val_loss improved from 0.66018 to 0.64748, saving model to ./checkpoint/weights.377-0.6475.hdf5
# 30/30 [==============================] - 50s - loss: 1.5422 - acc: 0.7692 - val_loss: 0.6475 - val_acc: 0.7683
# Epoch 379/2000
# Epoch 00378: val_loss improved from 0.64748 to 0.64107, saving model to ./checkpoint/weights.378-0.6411.hdf5
# 30/30 [==============================] - 51s - loss: 1.5353 - acc: 0.7685 - val_loss: 0.6411 - val_acc: 0.7730
# Epoch 380/2000
# Epoch 00379: val_loss improved from 0.64107 to 0.62146, saving model to ./checkpoint/weights.379-0.6215.hdf5
# 30/30 [==============================] - 51s - loss: 1.5212 - acc: 0.7786 - val_loss: 0.6215 - val_acc: 0.7920
# Epoch 381/2000
# Epoch 00380: val_loss improved from 0.62146 to 0.61896, saving model to ./checkpoint/weights.380-0.6190.hdf5
# 30/30 [==============================] - 50s - loss: 1.4973 - acc: 0.7705 - val_loss: 0.6190 - val_acc: 0.7967
# Epoch 382/2000
# Epoch 00381: val_loss improved from 0.61896 to 0.61680, saving model to ./checkpoint/weights.381-0.6168.hdf5
# 30/30 [==============================] - 51s - loss: 1.5030 - acc: 0.7823 - val_loss: 0.6168 - val_acc: 0.7943
# Epoch 383/2000
# Epoch 00382: val_loss improved from 0.61680 to 0.60415, saving model to ./checkpoint/weights.382-0.6042.hdf5
# 30/30 [==============================] - 51s - loss: 1.4974 - acc: 0.7664 - val_loss: 0.6042 - val_acc: 0.7943
# Epoch 384/2000
# Epoch 00383: val_loss improved from 0.60415 to 0.59342, saving model to ./checkpoint/weights.383-0.5934.hdf5
# 30/30 [==============================] - 51s - loss: 1.4096 - acc: 0.7846 - val_loss: 0.5934 - val_acc: 0.7991
# Epoch 385/2000
# Epoch 00384: val_loss did not improve
# 30/30 [==============================] - 50s - loss: 1.3663 - acc: 0.7967 - val_loss: 0.5999 - val_acc: 0.7991
# Epoch 386/2000
# Epoch 00385: val_loss did not improve
# 30/30 [==============================] - 50s - loss: 1.4500 - acc: 0.7922 - val_loss: 0.5970 - val_acc: 0.7991
# Epoch 387/2000
# Epoch 00386: val_loss did not improve
# 30/30 [==============================] - 50s - loss: 1.4072 - acc: 0.7945 - val_loss: 0.5940 - val_acc: 0.7991
# Epoch 388/2000
# Epoch 00387: val_loss improved from 0.59342 to 0.58772, saving model to ./checkpoint/weights.387-0.5877.hdf5
# 30/30 [==============================] - 50s - loss: 1.3266 - acc: 0.7968 - val_loss: 0.5877 - val_acc: 0.8014
# Epoch 389/2000
# Epoch 00388: val_loss improved from 0.58772 to 0.58199, saving model to ./checkpoint/weights.388-0.5820.hdf5
# 30/30 [==============================] - 51s - loss: 1.3275 - acc: 0.7990 - val_loss: 0.5820 - val_acc: 0.8014
# Epoch 390/2000
# Epoch 00389: val_loss improved from 0.58199 to 0.57505, saving model to ./checkpoint/weights.389-0.5751.hdf5
# 30/30 [==============================] - 51s - loss: 1.2373 - acc: 0.8112 - val_loss: 0.5751 - val_acc: 0.8014
# Epoch 391/2000
# Epoch 00390: val_loss improved from 0.57505 to 0.55678, saving model to ./checkpoint/weights.390-0.5568.hdf5
# 30/30 [==============================] - 50s - loss: 1.3787 - acc: 0.7989 - val_loss: 0.5568 - val_acc: 0.8109
# Epoch 392/2000
# Epoch 00391: val_loss improved from 0.55678 to 0.55159, saving model to ./checkpoint/weights.391-0.5516.hdf5
# 30/30 [==============================] - 51s - loss: 1.2597 - acc: 0.8102 - val_loss: 0.5516 - val_acc: 0.8109
# Epoch 393/2000
# Epoch 00392: val_loss improved from 0.55159 to 0.54517, saving model to ./checkpoint/weights.392-0.5452.hdf5
# 30/30 [==============================] - 51s - loss: 1.2231 - acc: 0.8156 - val_loss: 0.5452 - val_acc: 0.8156
# Epoch 394/2000
# Epoch 00393: val_loss improved from 0.54517 to 0.53658, saving model to ./checkpoint/weights.393-0.5366.hdf5
# 30/30 [==============================] - 50s - loss: 1.2333 - acc: 0.8152 - val_loss: 0.5366 - val_acc: 0.8227
# Epoch 395/2000
# Epoch 00394: val_loss did not improve
# 30/30 [==============================] - 51s - loss: 1.2286 - acc: 0.8125 - val_loss: 0.5420 - val_acc: 0.8227
# Epoch 396/2000
# Epoch 00395: val_loss did not improve
# 30/30 [==============================] - 51s - loss: 1.2240 - acc: 0.8172 - val_loss: 0.5420 - val_acc: 0.8227
# Epoch 397/2000
# Epoch 00396: val_loss did not improve
# 30/30 [==============================] - 50s - loss: 1.1960 - acc: 0.8131 - val_loss: 0.5439 - val_acc: 0.8132
# Epoch 398/2000
# Epoch 00397: val_loss did not improve
# 30/30 [==============================] - 51s - loss: 1.1830 - acc: 0.8102 - val_loss: 0.5458 - val_acc: 0.8156
# Epoch 399/2000
# Epoch 00398: val_loss improved from 0.53658 to 0.53101, saving model to ./checkpoint/weights.398-0.5310.hdf5
# 30/30 [==============================] - 51s - loss: 1.1577 - acc: 0.8250 - val_loss: 0.5310 - val_acc: 0.8298
# Epoch 400/2000
# Epoch 00399: val_loss did not improve
# 30/30 [==============================] - 50s - loss: 1.1399 - acc: 0.8359 - val_loss: 0.5335 - val_acc: 0.8227
# Epoch 401/2000
# Epoch 00400: val_loss improved from 0.53101 to 0.53069, saving model to ./checkpoint/weights.400-0.5307.hdf5
# 30/30 [==============================] - 51s - loss: 1.1335 - acc: 0.8201 - val_loss: 0.5307 - val_acc: 0.8227
# Epoch 402/2000
# Epoch 00401: val_loss improved from 0.53069 to 0.50906, saving model to ./checkpoint/weights.401-0.5091.hdf5
# 30/30 [==============================] - 51s - loss: 1.0513 - acc: 0.8357 - val_loss: 0.5091 - val_acc: 0.8251
# Epoch 403/2000
# Epoch 00402: val_loss did not improve
# 30/30 [==============================] - 50s - loss: 1.1281 - acc: 0.8336 - val_loss: 0.5097 - val_acc: 0.8298
# Epoch 404/2000
# Epoch 00403: val_loss did not improve
# 30/30 [==============================] - 51s - loss: 1.0894 - acc: 0.8216 - val_loss: 0.5091 - val_acc: 0.8392
# Epoch 405/2000
# Epoch 00404: val_loss improved from 0.50906 to 0.49905, saving model to ./checkpoint/weights.404-0.4991.hdf5
# 30/30 [==============================] - 51s - loss: 1.0188 - acc: 0.8492 - val_loss: 0.4991 - val_acc: 0.8322
# Epoch 406/2000
# Epoch 00405: val_loss improved from 0.49905 to 0.49285, saving model to ./checkpoint/weights.405-0.4928.hdf5
# 30/30 [==============================] - 50s - loss: 1.0233 - acc: 0.8303 - val_loss: 0.4928 - val_acc: 0.8416
# Epoch 407/2000
# Epoch 00406: val_loss improved from 0.49285 to 0.48974, saving model to ./checkpoint/weights.406-0.4897.hdf5
# 30/30 [==============================] - 51s - loss: 1.0530 - acc: 0.8383 - val_loss: 0.4897 - val_acc: 0.8392
# Epoch 408/2000
# Epoch 00407: val_loss did not improve
# 30/30 [==============================] - 51s - loss: 1.0490 - acc: 0.8349 - val_loss: 0.4924 - val_acc: 0.8345
# Epoch 409/2000
# Epoch 00408: val_loss did not improve
# 30/30 [==============================] - 50s - loss: 1.0149 - acc: 0.8463 - val_loss: 0.4952 - val_acc: 0.8392
# Epoch 410/2000
# Epoch 00409: val_loss did not improve
# 30/30 [==============================] - 51s - loss: 0.9909 - acc: 0.8529 - val_loss: 0.4921 - val_acc: 0.8392
# Epoch 411/2000
# Epoch 00410: val_loss improved from 0.48974 to 0.48286, saving model to ./checkpoint/weights.410-0.4829.hdf5
# 30/30 [==============================] - 51s - loss: 0.9418 - acc: 0.8531 - val_loss: 0.4829 - val_acc: 0.8440
# Epoch 412/2000
# Epoch 00411: val_loss did not improve
# 30/30 [==============================] - 50s - loss: 1.0473 - acc: 0.8463 - val_loss: 0.4841 - val_acc: 0.8392
# Epoch 413/2000
# Epoch 00412: val_loss improved from 0.48286 to 0.47658, saving model to ./checkpoint/weights.412-0.4766.hdf5
# 30/30 [==============================] - 51s - loss: 0.8642 - acc: 0.8565 - val_loss: 0.4766 - val_acc: 0.8463
# Epoch 414/2000
# Epoch 00413: val_loss improved from 0.47658 to 0.47590, saving model to ./checkpoint/weights.413-0.4759.hdf5
# 30/30 [==============================] - 51s - loss: 0.9774 - acc: 0.8609 - val_loss: 0.4759 - val_acc: 0.8463
# Epoch 415/2000
# Epoch 00414: val_loss improved from 0.47590 to 0.46415, saving model to ./checkpoint/weights.414-0.4641.hdf5
# 30/30 [==============================] - 51s - loss: 0.9291 - acc: 0.8560 - val_loss: 0.4641 - val_acc: 0.8487
# Epoch 416/2000
# Epoch 00415: val_loss improved from 0.46415 to 0.46141, saving model to ./checkpoint/weights.415-0.4614.hdf5
# 30/30 [==============================] - 50s - loss: 0.9128 - acc: 0.8579 - val_loss: 0.4614 - val_acc: 0.8440
# Epoch 417/2000
# Epoch 00416: val_loss improved from 0.46141 to 0.45961, saving model to ./checkpoint/weights.416-0.4596.hdf5
# 30/30 [==============================] - 51s - loss: 0.9029 - acc: 0.8521 - val_loss: 0.4596 - val_acc: 0.8440
# Epoch 418/2000
# Epoch 00417: val_loss improved from 0.45961 to 0.44879, saving model to ./checkpoint/weights.417-0.4488.hdf5
# 30/30 [==============================] - 51s - loss: 0.8697 - acc: 0.8609 - val_loss: 0.4488 - val_acc: 0.8511
# Epoch 419/2000
# Epoch 00418: val_loss did not improve
# 30/30 [==============================] - 50s - loss: 0.9276 - acc: 0.8579 - val_loss: 0.4507 - val_acc: 0.8534
# Epoch 420/2000
# Epoch 00419: val_loss improved from 0.44879 to 0.44680, saving model to ./checkpoint/weights.419-0.4468.hdf5
# 30/30 [==============================] - 51s - loss: 0.8252 - acc: 0.8654 - val_loss: 0.4468 - val_acc: 0.8511
# Epoch 421/2000
# Epoch 00420: val_loss did not improve
# 30/30 [==============================] - 51s - loss: 0.9291 - acc: 0.8583 - val_loss: 0.4481 - val_acc: 0.8511
# Epoch 422/2000
# Epoch 00421: val_loss improved from 0.44680 to 0.44646, saving model to ./checkpoint/weights.421-0.4465.hdf5
# 30/30 [==============================] - 50s - loss: 0.8290 - acc: 0.8660 - val_loss: 0.4465 - val_acc: 0.8511
# Epoch 423/2000
# Epoch 00422: val_loss improved from 0.44646 to 0.44335, saving model to ./checkpoint/weights.422-0.4434.hdf5
# 30/30 [==============================] - 51s - loss: 0.8521 - acc: 0.8667 - val_loss: 0.4434 - val_acc: 0.8558
# Epoch 424/2000
# Epoch 00423: val_loss improved from 0.44335 to 0.43470, saving model to ./checkpoint/weights.423-0.4347.hdf5
# 30/30 [==============================] - 51s - loss: 0.8145 - acc: 0.8701 - val_loss: 0.4347 - val_acc: 0.8534
# Epoch 425/2000
# Epoch 00424: val_loss improved from 0.43470 to 0.43452, saving model to ./checkpoint/weights.424-0.4345.hdf5
# 30/30 [==============================] - 51s - loss: 0.7930 - acc: 0.8708 - val_loss: 0.4345 - val_acc: 0.8582
# Epoch 426/2000
# Epoch 00425: val_loss improved from 0.43452 to 0.43274, saving model to ./checkpoint/weights.425-0.4327.hdf5
# 30/30 [==============================] - 51s - loss: 0.8081 - acc: 0.8737 - val_loss: 0.4327 - val_acc: 0.8534
# Epoch 427/2000
# Epoch 00426: val_loss improved from 0.43274 to 0.43006, saving model to ./checkpoint/weights.426-0.4301.hdf5
# 30/30 [==============================] - 51s - loss: 0.7674 - acc: 0.8682 - val_loss: 0.4301 - val_acc: 0.8558
# Epoch 428/2000
# Epoch 00427: val_loss improved from 0.43006 to 0.42481, saving model to ./checkpoint/weights.427-0.4248.hdf5
# 30/30 [==============================] - 50s - loss: 0.8161 - acc: 0.8769 - val_loss: 0.4248 - val_acc: 0.8487
# Epoch 429/2000
# Epoch 00428: val_loss did not improve
# 30/30 [==============================] - 50s - loss: 0.8295 - acc: 0.8695 - val_loss: 0.4258 - val_acc: 0.8511
# Epoch 430/2000
# Epoch 00429: val_loss improved from 0.42481 to 0.41566, saving model to ./checkpoint/weights.429-0.4157.hdf5
# 30/30 [==============================] - 51s - loss: 0.7457 - acc: 0.8737 - val_loss: 0.4157 - val_acc: 0.8558
# Epoch 431/2000
# Epoch 00430: val_loss did not improve
# 30/30 [==============================] - 50s - loss: 0.7321 - acc: 0.8853 - val_loss: 0.4203 - val_acc: 0.8511
# Epoch 432/2000
# Epoch 00431: val_loss did not improve
# 30/30 [==============================] - 51s - loss: 0.7721 - acc: 0.8823 - val_loss: 0.4280 - val_acc: 0.8534
# Epoch 433/2000
# Epoch 00432: val_loss did not improve
# 30/30 [==============================] - 50s - loss: 0.7172 - acc: 0.8813 - val_loss: 0.4170 - val_acc: 0.8534
# Epoch 434/2000
# Epoch 00433: val_loss did not improve
# 30/30 [==============================] - 50s - loss: 0.7104 - acc: 0.8885 - val_loss: 0.4238 - val_acc: 0.8534
# Epoch 435/2000
# Epoch 00434: val_loss did not improve
# 30/30 [==============================] - 50s - loss: 0.7294 - acc: 0.8896 - val_loss: 0.4218 - val_acc: 0.8558
# Epoch 436/2000
# Epoch 00435: val_loss did not improve
# 30/30 [==============================] - 51s - loss: 0.7648 - acc: 0.8813 - val_loss: 0.4261 - val_acc: 0.8558
# Epoch 437/2000
# Epoch 00436: val_loss did not improve
# 30/30 [==============================] - 50s - loss: 0.7170 - acc: 0.8831 - val_loss: 0.4208 - val_acc: 0.8605
# Epoch 438/2000
# Epoch 00437: val_loss improved from 0.41566 to 0.41371, saving model to ./checkpoint/weights.437-0.4137.hdf5
# 30/30 [==============================] - 51s - loss: 0.6728 - acc: 0.8927 - val_loss: 0.4137 - val_acc: 0.8582
# Epoch 439/2000
# Epoch 00438: val_loss improved from 0.41371 to 0.41013, saving model to ./checkpoint/weights.438-0.4101.hdf5
# 30/30 [==============================] - 51s - loss: 0.7325 - acc: 0.8820 - val_loss: 0.4101 - val_acc: 0.8629
# Epoch 440/2000
# Epoch 00439: val_loss improved from 0.41013 to 0.40557, saving model to ./checkpoint/weights.439-0.4056.hdf5
# 30/30 [==============================] - 53s - loss: 0.6671 - acc: 0.8952 - val_loss: 0.4056 - val_acc: 0.8629
# Epoch 441/2000
# Epoch 00440: val_loss improved from 0.40557 to 0.40017, saving model to ./checkpoint/weights.440-0.4002.hdf5
# 30/30 [==============================] - 51s - loss: 0.6699 - acc: 0.8901 - val_loss: 0.4002 - val_acc: 0.8629
# Epoch 442/2000
# Epoch 00441: val_loss improved from 0.40017 to 0.39901, saving model to ./checkpoint/weights.441-0.3990.hdf5
# 30/30 [==============================] - 51s - loss: 0.6592 - acc: 0.8888 - val_loss: 0.3990 - val_acc: 0.8629
# Epoch 443/2000
# Epoch 00442: val_loss improved from 0.39901 to 0.39113, saving model to ./checkpoint/weights.442-0.3911.hdf5
# 30/30 [==============================] - 53s - loss: 0.6779 - acc: 0.8912 - val_loss: 0.3911 - val_acc: 0.8652
# Epoch 444/2000
# Epoch 00443: val_loss improved from 0.39113 to 0.38884, saving model to ./checkpoint/weights.443-0.3888.hdf5
# 30/30 [==============================] - 51s - loss: 0.6451 - acc: 0.9057 - val_loss: 0.3888 - val_acc: 0.8676
# Epoch 445/2000
# Epoch 00444: val_loss improved from 0.38884 to 0.38324, saving model to ./checkpoint/weights.444-0.3832.hdf5
# 30/30 [==============================] - 51s - loss: 0.5861 - acc: 0.8997 - val_loss: 0.3832 - val_acc: 0.8652
# Epoch 446/2000
# Epoch 00445: val_loss improved from 0.38324 to 0.38011, saving model to ./checkpoint/weights.445-0.3801.hdf5
# 30/30 [==============================] - 52s - loss: 0.6331 - acc: 0.9086 - val_loss: 0.3801 - val_acc: 0.8652
# Epoch 447/2000
# Epoch 00446: val_loss did not improve
# 30/30 [==============================] - 50s - loss: 0.5982 - acc: 0.8985 - val_loss: 0.3803 - val_acc: 0.8771
# Epoch 448/2000
# Epoch 00447: val_loss improved from 0.38011 to 0.37558, saving model to ./checkpoint/weights.447-0.3756.hdf5
# 30/30 [==============================] - 51s - loss: 0.6599 - acc: 0.8857 - val_loss: 0.3756 - val_acc: 0.8700
# Epoch 449/2000
# Epoch 00448: val_loss improved from 0.37558 to 0.37093, saving model to ./checkpoint/weights.448-0.3709.hdf5
# 30/30 [==============================] - 52s - loss: 0.6413 - acc: 0.9003 - val_loss: 0.3709 - val_acc: 0.8676
# Epoch 450/2000
# Epoch 00449: val_loss improved from 0.37093 to 0.36486, saving model to ./checkpoint/weights.449-0.3649.hdf5
# 30/30 [==============================] - 50s - loss: 0.5760 - acc: 0.8978 - val_loss: 0.3649 - val_acc: 0.8747
# Epoch 451/2000
# Epoch 00450: val_loss did not improve
# 30/30 [==============================] - 50s - loss: 0.6247 - acc: 0.9042 - val_loss: 0.3719 - val_acc: 0.8723
# Epoch 452/2000
# Epoch 00451: val_loss did not improve
# 30/30 [==============================] - 50s - loss: 0.6082 - acc: 0.9094 - val_loss: 0.3823 - val_acc: 0.8794
# Epoch 453/2000
# Epoch 00452: val_loss did not improve
# 30/30 [==============================] - 50s - loss: 0.5671 - acc: 0.9079 - val_loss: 0.3808 - val_acc: 0.8652
# Epoch 454/2000
# Epoch 00453: val_loss did not improve
# 30/30 [==============================] - 51s - loss: 0.6144 - acc: 0.9049 - val_loss: 0.3776 - val_acc: 0.8723
# Epoch 455/2000
# Epoch 00454: val_loss did not improve
# 30/30 [==============================] - 51s - loss: 0.5792 - acc: 0.8979 - val_loss: 0.3758 - val_acc: 0.8700
# Epoch 456/2000
# Epoch 00455: val_loss did not improve
# 30/30 [==============================] - 50s - loss: 0.5325 - acc: 0.9125 - val_loss: 0.3676 - val_acc: 0.8700
# Epoch 457/2000
# Epoch 00456: val_loss improved from 0.36486 to 0.36139, saving model to ./checkpoint/weights.456-0.3614.hdf5
# 30/30 [==============================] - 51s - loss: 0.5780 - acc: 0.9096 - val_loss: 0.3614 - val_acc: 0.8842
# Epoch 458/2000
# Epoch 00457: val_loss did not improve
# 30/30 [==============================] - 51s - loss: 0.5915 - acc: 0.9065 - val_loss: 0.3648 - val_acc: 0.8794
# Epoch 459/2000
# Epoch 00458: val_loss improved from 0.36139 to 0.35644, saving model to ./checkpoint/weights.458-0.3564.hdf5
# 30/30 [==============================] - 50s - loss: 0.5080 - acc: 0.9116 - val_loss: 0.3564 - val_acc: 0.8794
# Epoch 460/2000
# Epoch 00459: val_loss improved from 0.35644 to 0.35029, saving model to ./checkpoint/weights.459-0.3503.hdf5
# 30/30 [==============================] - 51s - loss: 0.5770 - acc: 0.9109 - val_loss: 0.3503 - val_acc: 0.8818
# Epoch 461/2000
# Epoch 00460: val_loss did not improve
# 30/30 [==============================] - 51s - loss: 0.5318 - acc: 0.9130 - val_loss: 0.3536 - val_acc: 0.8794
# Epoch 462/2000
# Epoch 00461: val_loss improved from 0.35029 to 0.34363, saving model to ./checkpoint/weights.461-0.3436.hdf5
# 30/30 [==============================] - 50s - loss: 0.5339 - acc: 0.9105 - val_loss: 0.3436 - val_acc: 0.8865
# Epoch 463/2000
# Epoch 00462: val_loss improved from 0.34363 to 0.34090, saving model to ./checkpoint/weights.462-0.3409.hdf5
# 30/30 [==============================] - 51s - loss: 0.5606 - acc: 0.9057 - val_loss: 0.3409 - val_acc: 0.8889
# Epoch 464/2000
# Epoch 00463: val_loss improved from 0.34090 to 0.33641, saving model to ./checkpoint/weights.463-0.3364.hdf5
# 30/30 [==============================] - 52s - loss: 0.5026 - acc: 0.9174 - val_loss: 0.3364 - val_acc: 0.8865
# Epoch 465/2000
# Epoch 00464: val_loss did not improve
# 30/30 [==============================] - 50s - loss: 0.5631 - acc: 0.9116 - val_loss: 0.3387 - val_acc: 0.8818
# Epoch 466/2000
# Epoch 00465: val_loss did not improve
# 30/30 [==============================] - 51s - loss: 0.4871 - acc: 0.9154 - val_loss: 0.3399 - val_acc: 0.8865
# Epoch 467/2000
# Epoch 00466: val_loss did not improve
# 30/30 [==============================] - 51s - loss: 0.5390 - acc: 0.9120 - val_loss: 0.3459 - val_acc: 0.8794
# Epoch 468/2000
# Epoch 00467: val_loss did not improve
# 30/30 [==============================] - 50s - loss: 0.4912 - acc: 0.9123 - val_loss: 0.3471 - val_acc: 0.8747
# Epoch 469/2000
# Epoch 00468: val_loss did not improve
# 30/30 [==============================] - 51s - loss: 0.4904 - acc: 0.9216 - val_loss: 0.3500 - val_acc: 0.8771
# Epoch 470/2000
# Epoch 00469: val_loss did not improve
# 30/30 [==============================] - 50s - loss: 0.4812 - acc: 0.9216 - val_loss: 0.3477 - val_acc: 0.8771
# Epoch 471/2000
# Epoch 00470: val_loss did not improve
# 30/30 [==============================] - 50s - loss: 0.4566 - acc: 0.9252 - val_loss: 0.3459 - val_acc: 0.8771
# Epoch 472/2000
# Epoch 00471: val_loss did not improve
# 30/30 [==============================] - 50s - loss: 0.4485 - acc: 0.9224 - val_loss: 0.3397 - val_acc: 0.8771
# Epoch 473/2000
# Epoch 00472: val_loss did not improve
# 30/30 [==============================] - 51s - loss: 0.4872 - acc: 0.9201 - val_loss: 0.3378 - val_acc: 0.8842
# Epoch 474/2000
# Epoch 00473: val_loss did not improve
# 30/30 [==============================] - 50s - loss: 0.5027 - acc: 0.9189 - val_loss: 0.3445 - val_acc: 0.8889
# Epoch 475/2000
# Epoch 00474: val_loss did not improve
#
# Epoch 00474: reducing learning rate to 9.99999974738e-07.
# 30/30 [==============================] - 51s - loss: 0.4589 - acc: 0.9286 - val_loss: 0.3447 - val_acc: 0.8794
# Epoch 476/2000
# Epoch 00475: val_loss did not improve
# 30/30 [==============================] - 50s - loss: 0.4369 - acc: 0.9247 - val_loss: 0.3419 - val_acc: 0.8818
# Epoch 477/2000
# Epoch 00476: val_loss did not improve
# 30/30 [==============================] - 51s - loss: 0.4529 - acc: 0.9250 - val_loss: 0.3406 - val_acc: 0.8842
# Epoch 478/2000
# Epoch 00477: val_loss did not improve
# 30/30 [==============================] - 50s - loss: 0.4289 - acc: 0.9248 - val_loss: 0.3380 - val_acc: 0.8889
# Epoch 479/2000
# Epoch 00478: val_loss did not improve
# 30/30 [==============================] - 51s - loss: 0.4460 - acc: 0.9247 - val_loss: 0.3379 - val_acc: 0.8842
# Epoch 480/2000
# Epoch 00479: val_loss did not improve
# 30/30 [==============================] - 50s - loss: 0.4580 - acc: 0.9172 - val_loss: 0.3378 - val_acc: 0.8889
# Epoch 481/2000
# Epoch 00480: val_loss did not improve
# 30/30 [==============================] - 50s - loss: 0.4457 - acc: 0.9274 - val_loss: 0.3368 - val_acc: 0.8865
# Epoch 482/2000
# Epoch 00481: val_loss improved from 0.33641 to 0.33580, saving model to ./checkpoint/weights.481-0.3358.hdf5
# 30/30 [==============================] - 51s - loss: 0.4386 - acc: 0.9266 - val_loss: 0.3358 - val_acc: 0.8865
# Epoch 483/2000
# Epoch 00482: val_loss improved from 0.33580 to 0.33561, saving model to ./checkpoint/weights.482-0.3356.hdf5
# 30/30 [==============================] - 52s - loss: 0.4635 - acc: 0.9208 - val_loss: 0.3356 - val_acc: 0.8842
# Epoch 484/2000
# Epoch 00483: val_loss improved from 0.33561 to 0.33480, saving model to ./checkpoint/weights.483-0.3348.hdf5
# 30/30 [==============================] - 50s - loss: 0.4359 - acc: 0.9251 - val_loss: 0.3348 - val_acc: 0.8889
# Epoch 485/2000
# Epoch 00484: val_loss did not improve
# 30/30 [==============================] - 51s - loss: 0.4302 - acc: 0.9206 - val_loss: 0.3350 - val_acc: 0.8889
# Epoch 486/2000
# Epoch 00485: val_loss improved from 0.33480 to 0.33456, saving model to ./checkpoint/weights.485-0.3346.hdf5
# 30/30 [==============================] - 51s - loss: 0.4804 - acc: 0.9193 - val_loss: 0.3346 - val_acc: 0.8889
# Epoch 487/2000
# Epoch 00486: val_loss did not improve
# 30/30 [==============================] - 50s - loss: 0.4681 - acc: 0.9315 - val_loss: 0.3357 - val_acc: 0.8865
# Epoch 488/2000
# Epoch 00487: val_loss improved from 0.33456 to 0.33364, saving model to ./checkpoint/weights.487-0.3336.hdf5
# 30/30 [==============================] - 51s - loss: 0.4247 - acc: 0.9229 - val_loss: 0.3336 - val_acc: 0.8889
# Epoch 489/2000
# Epoch 00488: val_loss improved from 0.33364 to 0.33322, saving model to ./checkpoint/weights.488-0.3332.hdf5
# 30/30 [==============================] - 51s - loss: 0.4573 - acc: 0.9159 - val_loss: 0.3332 - val_acc: 0.8865
# Epoch 490/2000
# Epoch 00489: val_loss did not improve
# 30/30 [==============================] - 50s - loss: 0.4710 - acc: 0.9233 - val_loss: 0.3333 - val_acc: 0.8889
# Epoch 491/2000
# Epoch 00490: val_loss improved from 0.33322 to 0.33169, saving model to ./checkpoint/weights.490-0.3317.hdf5
# 30/30 [==============================] - 51s - loss: 0.4320 - acc: 0.9221 - val_loss: 0.3317 - val_acc: 0.8889
# Epoch 492/2000
# Epoch 00491: val_loss improved from 0.33169 to 0.33093, saving model to ./checkpoint/weights.491-0.3309.hdf5
# 30/30 [==============================] - 54s - loss: 0.4396 - acc: 0.9273 - val_loss: 0.3309 - val_acc: 0.8936
# Epoch 493/2000
# Epoch 00492: val_loss did not improve
# 30/30 [==============================] - 50s - loss: 0.4286 - acc: 0.9205 - val_loss: 0.3314 - val_acc: 0.8936
# Epoch 494/2000
# Epoch 00493: val_loss did not improve
# 30/30 [==============================] - 51s - loss: 0.4326 - acc: 0.9315 - val_loss: 0.3316 - val_acc: 0.8960
# Epoch 495/2000
# Epoch 00494: val_loss did not improve
# 30/30 [==============================] - 51s - loss: 0.4680 - acc: 0.9227 - val_loss: 0.3326 - val_acc: 0.8889
# Epoch 496/2000
# Epoch 00495: val_loss did not improve
# 30/30 [==============================] - 50s - loss: 0.4073 - acc: 0.9335 - val_loss: 0.3317 - val_acc: 0.8936
# Epoch 497/2000
# Epoch 00496: val_loss did not improve
# 30/30 [==============================] - 50s - loss: 0.4483 - acc: 0.9240 - val_loss: 0.3312 - val_acc: 0.8913
# Epoch 498/2000
# Epoch 00497: val_loss did not improve
# 30/30 [==============================] - 50s - loss: 0.4347 - acc: 0.9253 - val_loss: 0.3312 - val_acc: 0.8913
# Epoch 499/2000
# Epoch 00498: val_loss improved from 0.33093 to 0.33072, saving model to ./checkpoint/weights.498-0.3307.hdf5
# 30/30 [==============================] - 50s - loss: 0.4406 - acc: 0.9300 - val_loss: 0.3307 - val_acc: 0.8936
# Epoch 500/2000
# Epoch 00499: val_loss improved from 0.33072 to 0.33062, saving model to ./checkpoint/weights.499-0.3306.hdf5
# 30/30 [==============================] - 51s - loss: 0.4279 - acc: 0.9281 - val_loss: 0.3306 - val_acc: 0.8936
# Epoch 501/2000
# Epoch 00500: val_loss improved from 0.33062 to 0.33028, saving model to ./checkpoint/weights.500-0.3303.hdf5
# 30/30 [==============================] - 51s - loss: 0.4539 - acc: 0.9323 - val_loss: 0.3303 - val_acc: 0.8889
# Epoch 502/2000
# Epoch 00501: val_loss did not improve
# 30/30 [==============================] - 50s - loss: 0.4400 - acc: 0.9253 - val_loss: 0.3304 - val_acc: 0.8913
# Epoch 503/2000
# Epoch 00502: val_loss improved from 0.33028 to 0.32983, saving model to ./checkpoint/weights.502-0.3298.hdf5
# 30/30 [==============================] - 51s - loss: 0.4266 - acc: 0.9297 - val_loss: 0.3298 - val_acc: 0.8936
# Epoch 504/2000
# Epoch 00503: val_loss did not improve
# 30/30 [==============================] - 51s - loss: 0.4528 - acc: 0.9253 - val_loss: 0.3303 - val_acc: 0.8936
# Epoch 505/2000
# Epoch 00504: val_loss did not improve
# 30/30 [==============================] - 50s - loss: 0.4447 - acc: 0.9298 - val_loss: 0.3307 - val_acc: 0.8960
# Epoch 506/2000
# Epoch 00505: val_loss did not improve
# 30/30 [==============================] - 50s - loss: 0.4367 - acc: 0.9305 - val_loss: 0.3310 - val_acc: 0.8936
# Epoch 507/2000
# Epoch 00506: val_loss did not improve
# 30/30 [==============================] - 51s - loss: 0.4092 - acc: 0.9299 - val_loss: 0.3310 - val_acc: 0.8913
# Epoch 508/2000
# Epoch 00507: val_loss improved from 0.32983 to 0.32905, saving model to ./checkpoint/weights.507-0.3290.hdf5
# 30/30 [==============================] - 51s - loss: 0.4889 - acc: 0.9216 - val_loss: 0.3290 - val_acc: 0.8960
# Epoch 509/2000
# Epoch 00508: val_loss improved from 0.32905 to 0.32887, saving model to ./checkpoint/weights.508-0.3289.hdf5
# 30/30 [==============================] - 52s - loss: 0.4531 - acc: 0.9276 - val_loss: 0.3289 - val_acc: 0.8960
# Epoch 510/2000
# Epoch 00509: val_loss did not improve
# 30/30 [==============================] - 58s - loss: 0.4550 - acc: 0.9307 - val_loss: 0.3290 - val_acc: 0.8936
# Epoch 511/2000
# Epoch 00510: val_loss did not improve
# 30/30 [==============================] - 52s - loss: 0.4129 - acc: 0.9346 - val_loss: 0.3296 - val_acc: 0.8936
# Epoch 512/2000
# Epoch 00511: val_loss did not improve
# 30/30 [==============================] - 50s - loss: 0.4067 - acc: 0.9243 - val_loss: 0.3295 - val_acc: 0.8913
# Epoch 513/2000
# Epoch 00512: val_loss did not improve
# 30/30 [==============================] - 50s - loss: 0.4821 - acc: 0.9276 - val_loss: 0.3293 - val_acc: 0.8936
# Epoch 514/2000
# Epoch 00513: val_loss improved from 0.32887 to 0.32845, saving model to ./checkpoint/weights.513-0.3285.hdf5
# 30/30 [==============================] - 51s - loss: 0.4118 - acc: 0.9281 - val_loss: 0.3285 - val_acc: 0.8960
# Epoch 515/2000
# Epoch 00514: val_loss improved from 0.32845 to 0.32783, saving model to ./checkpoint/weights.514-0.3278.hdf5
# 30/30 [==============================] - 50s - loss: 0.4111 - acc: 0.9352 - val_loss: 0.3278 - val_acc: 0.8936
# Epoch 516/2000
# Epoch 00515: val_loss did not improve
# 30/30 [==============================] - 50s - loss: 0.4544 - acc: 0.9310 - val_loss: 0.3283 - val_acc: 0.8913
# Epoch 517/2000
# Epoch 00516: val_loss improved from 0.32783 to 0.32681, saving model to ./checkpoint/weights.516-0.3268.hdf5
# 30/30 [==============================] - 51s - loss: 0.4339 - acc: 0.9263 - val_loss: 0.3268 - val_acc: 0.8936
# Epoch 518/2000
# Epoch 00517: val_loss improved from 0.32681 to 0.32623, saving model to ./checkpoint/weights.517-0.3262.hdf5
# 30/30 [==============================] - 50s - loss: 0.4076 - acc: 0.9291 - val_loss: 0.3262 - val_acc: 0.8936
# Epoch 519/2000
# Epoch 00518: val_loss did not improve
# 30/30 [==============================] - 51s - loss: 0.4397 - acc: 0.9359 - val_loss: 0.3277 - val_acc: 0.8936
# Epoch 520/2000
# Epoch 00519: val_loss did not improve
# 30/30 [==============================] - 50s - loss: 0.4151 - acc: 0.9281 - val_loss: 0.3266 - val_acc: 0.8936
# Epoch 521/2000
# Epoch 00520: val_loss did not improve
# 30/30 [==============================] - 50s - loss: 0.4109 - acc: 0.9313 - val_loss: 0.3270 - val_acc: 0.8936
# Epoch 522/2000
# Epoch 00521: val_loss did not improve
# 30/30 [==============================] - 50s - loss: 0.4188 - acc: 0.9302 - val_loss: 0.3264 - val_acc: 0.8913
# Epoch 523/2000
# Epoch 00522: val_loss did not improve
# 30/30 [==============================] - 50s - loss: 0.4413 - acc: 0.9286 - val_loss: 0.3270 - val_acc: 0.8936
# Epoch 524/2000
# Epoch 00523: val_loss did not improve
# 30/30 [==============================] - 50s - loss: 0.4186 - acc: 0.9305 - val_loss: 0.3270 - val_acc: 0.8913
# Epoch 525/2000
# Epoch 00524: val_loss did not improve
# 30/30 [==============================] - 51s - loss: 0.4411 - acc: 0.9302 - val_loss: 0.3273 - val_acc: 0.8913
# Epoch 526/2000
# Epoch 00525: val_loss did not improve
# 30/30 [==============================] - 51s - loss: 0.4110 - acc: 0.9294 - val_loss: 0.3273 - val_acc: 0.8913
# Epoch 527/2000
# Epoch 00526: val_loss did not improve
# 30/30 [==============================] - 50s - loss: 0.4554 - acc: 0.9271 - val_loss: 0.3264 - val_acc: 0.8936
# Epoch 528/2000
# Epoch 00527: val_loss improved from 0.32623 to 0.32611, saving model to ./checkpoint/weights.527-0.3261.hdf5
#
# Epoch 00527: reducing learning rate to 9.99999997475e-08.
# 30/30 [==============================] - 51s - loss: 0.4525 - acc: 0.9185 - val_loss: 0.3261 - val_acc: 0.8913
# Epoch 529/2000
# Epoch 00528: val_loss improved from 0.32611 to 0.32501, saving model to ./checkpoint/weights.528-0.3250.hdf5
# 30/30 [==============================] - 52s - loss: 0.3722 - acc: 0.9354 - val_loss: 0.3250 - val_acc: 0.8960
# Epoch 530/2000
# Epoch 00529: val_loss did not improve
# 30/30 [==============================] - 50s - loss: 0.4456 - acc: 0.9291 - val_loss: 0.3254 - val_acc: 0.8936
# Epoch 531/2000
# Epoch 00530: val_loss did not improve
# 30/30 [==============================] - 50s - loss: 0.4273 - acc: 0.9279 - val_loss: 0.3253 - val_acc: 0.8960
# Epoch 532/2000
# Epoch 00531: val_loss improved from 0.32501 to 0.32470, saving model to ./checkpoint/weights.531-0.3247.hdf5
# 30/30 [==============================] - 51s - loss: 0.4167 - acc: 0.9281 - val_loss: 0.3247 - val_acc: 0.8960
# Epoch 533/2000
# Epoch 00532: val_loss did not improve
# 30/30 [==============================] - 50s - loss: 0.4595 - acc: 0.9302 - val_loss: 0.3253 - val_acc: 0.8936
# Epoch 534/2000
# Epoch 00533: val_loss improved from 0.32470 to 0.32435, saving model to ./checkpoint/weights.533-0.3243.hdf5
# 30/30 [==============================] - 51s - loss: 0.4316 - acc: 0.9221 - val_loss: 0.3243 - val_acc: 0.8960
# Epoch 535/2000
# Epoch 00534: val_loss did not improve
# 30/30 [==============================] - 51s - loss: 0.4011 - acc: 0.9258 - val_loss: 0.3246 - val_acc: 0.8960
# Epoch 536/2000
# Epoch 00535: val_loss did not improve
# 30/30 [==============================] - 50s - loss: 0.4491 - acc: 0.9240 - val_loss: 0.3249 - val_acc: 0.8936
# Epoch 537/2000
# Epoch 00536: val_loss did not improve
# 30/30 [==============================] - 51s - loss: 0.4487 - acc: 0.9250 - val_loss: 0.3249 - val_acc: 0.8936
# Epoch 538/2000
# Epoch 00537: val_loss did not improve
# 30/30 [==============================] - 50s - loss: 0.3850 - acc: 0.9401 - val_loss: 0.3247 - val_acc: 0.8936
# Epoch 539/2000
# Epoch 00538: val_loss improved from 0.32435 to 0.32338, saving model to ./checkpoint/weights.538-0.3234.hdf5
# 30/30 [==============================] - 51s - loss: 0.4287 - acc: 0.9305 - val_loss: 0.3234 - val_acc: 0.8983
# Epoch 540/2000
# Epoch 00539: val_loss improved from 0.32338 to 0.32293, saving model to ./checkpoint/weights.539-0.3229.hdf5
# 30/30 [==============================] - 50s - loss: 0.4140 - acc: 0.9311 - val_loss: 0.3229 - val_acc: 0.8960
# Epoch 541/2000
# Epoch 00540: val_loss did not improve
# 30/30 [==============================] - 50s - loss: 0.4239 - acc: 0.9305 - val_loss: 0.3237 - val_acc: 0.8960
# Epoch 542/2000
# Epoch 00541: val_loss did not improve
# 30/30 [==============================] - 50s - loss: 0.4335 - acc: 0.9245 - val_loss: 0.3232 - val_acc: 0.8960
# Epoch 543/2000
# Epoch 00542: val_loss did not improve
# 30/30 [==============================] - 50s - loss: 0.4659 - acc: 0.9323 - val_loss: 0.3238 - val_acc: 0.8960
# Epoch 544/2000
# Epoch 00543: val_loss did not improve
# 30/30 [==============================] - 51s - loss: 0.4546 - acc: 0.9279 - val_loss: 0.3239 - val_acc: 0.8936
# Epoch 545/2000
# Epoch 00544: val_loss did not improve
# 30/30 [==============================] - 51s - loss: 0.4169 - acc: 0.9208 - val_loss: 0.3243 - val_acc: 0.8936
# Epoch 546/2000
# Epoch 00545: val_loss did not improve
# 30/30 [==============================] - 50s - loss: 0.4367 - acc: 0.9266 - val_loss: 0.3236 - val_acc: 0.8936
# Epoch 547/2000
# Epoch 00546: val_loss did not improve
# 30/30 [==============================] - 51s - loss: 0.4481 - acc: 0.9214 - val_loss: 0.3255 - val_acc: 0.8936
# Epoch 548/2000
# Epoch 00547: val_loss did not improve
# 30/30 [==============================] - 50s - loss: 0.4281 - acc: 0.9281 - val_loss: 0.3245 - val_acc: 0.8936
# Epoch 549/2000
# Epoch 00548: val_loss did not improve
# 30/30 [==============================] - 50s - loss: 0.4145 - acc: 0.9304 - val_loss: 0.3253 - val_acc: 0.8936
# Epoch 550/2000
# Epoch 00549: val_loss did not improve
#
# Epoch 00549: reducing learning rate to 1.00000001169e-08.
# 30/30 [==============================] - 51s - loss: 0.4153 - acc: 0.9328 - val_loss: 0.3247 - val_acc: 0.8936
# Epoch 551/2000
# Epoch 00550: val_loss did not improve
# 30/30 [==============================] - 51s - loss: 0.4157 - acc: 0.9268 - val_loss: 0.3241 - val_acc: 0.8936
# Epoch 552/2000
# Epoch 00551: val_loss did not improve
# 30/30 [==============================] - 50s - loss: 0.3820 - acc: 0.9332 - val_loss: 0.3243 - val_acc: 0.8960
# Epoch 553/2000
# Epoch 00552: val_loss did not improve
# 30/30 [==============================] - 51s - loss: 0.4248 - acc: 0.9258 - val_loss: 0.3241 - val_acc: 0.8960
# Epoch 554/2000
# Epoch 00553: val_loss did not improve
# 30/30 [==============================] - 51s - loss: 0.4525 - acc: 0.9221 - val_loss: 0.3237 - val_acc: 0.8960
# Epoch 555/2000
# Epoch 00554: val_loss did not improve
# 30/30 [==============================] - 50s - loss: 0.4270 - acc: 0.9331 - val_loss: 0.3242 - val_acc: 0.8960
# Epoch 556/2000
# Epoch 00555: val_loss did not improve
# 30/30 [==============================] - 51s - loss: 0.4270 - acc: 0.9250 - val_loss: 0.3234 - val_acc: 0.8960
# Epoch 557/2000
# Epoch 00556: val_loss did not improve
# 30/30 [==============================] - 51s - loss: 0.4318 - acc: 0.9260 - val_loss: 0.3239 - val_acc: 0.8960
# Epoch 558/2000
# Epoch 00557: val_loss did not improve
# 30/30 [==============================] - 50s - loss: 0.4804 - acc: 0.9240 - val_loss: 0.3244 - val_acc: 0.8936
# Epoch 559/2000
# Epoch 00558: val_loss did not improve
# 30/30 [==============================] - 51s - loss: 0.4520 - acc: 0.9260 - val_loss: 0.3251 - val_acc: 0.8936
# Epoch 560/2000
# Epoch 00559: val_loss did not improve
#
# Epoch 00559: reducing learning rate to 9.99999993923e-10.
# 30/30 [==============================] - 51s - loss: 0.4110 - acc: 0.9284 - val_loss: 0.3259 - val_acc: 0.8913
# Epoch 561/2000
# Epoch 00560: val_loss did not improve
# 30/30 [==============================] - 50s - loss: 0.3984 - acc: 0.9347 - val_loss: 0.3248 - val_acc: 0.8936
# Epoch 562/2000
# Epoch 00561: val_loss did not improve
# 30/30 [==============================] - 50s - loss: 0.4109 - acc: 0.9297 - val_loss: 0.3244 - val_acc: 0.8936
# Epoch 563/2000
# Epoch 00562: val_loss did not improve
# 30/30 [==============================] - 50s - loss: 0.4360 - acc: 0.9299 - val_loss: 0.3240 - val_acc: 0.8936
# Epoch 564/2000
# Epoch 00563: val_loss did not improve
# 30/30 [==============================] - 50s - loss: 0.4532 - acc: 0.9256 - val_loss: 0.3254 - val_acc: 0.8936
# Epoch 565/2000
# Epoch 00564: val_loss did not improve
# 30/30 [==============================] - 51s - loss: 0.4511 - acc: 0.9279 - val_loss: 0.3244 - val_acc: 0.8960
# Epoch 566/2000
# Epoch 00565: val_loss did not improve
# 30/30 [==============================] - 51s - loss: 0.4211 - acc: 0.9266 - val_loss: 0.3257 - val_acc: 0.8960
# Epoch 00565: early stopping

# %%
### Resnet50
# fine tuning stg2
# 164 conv5c+top
# 154 conv5b+conv5c+top
# 142 conv5+top
# 80 conv4+conv5+top
# 38 conv3+conv4+conv5+top
# 6 conv2+conv3+conv4+conv5+top
# 2 conv1+conv2+conv3+conv4+conv5+top i.e. FROM SCRATCH
start_layer = 154

# model, model_name = get_best_model()
model = load_model(CHECKPOINT_DIR + 'weights.539-0.3229.hdf5')
model_name = 'weights.539-0.3229.hdf5'
print('model_name', model_name)

for layer in model.layers[:start_layer]:
   layer.trainable = False
for layer in model.layers[start_layer:]:
   layer.trainable = True

# we need to recompile the model for these modifications to take effect
# we use SGD with a low learning rate
optimizer = Adam(lr=1e-5)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

print('BATCHSIZE', BATCHSIZE)
model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=2000, verbose=1, 
                    callbacks=[early_stopping, model_checkpoint, learningrate_schedule, tensorboard], 
                    validation_data=(X_valid_centered, y_valid), 
                    class_weight=class_weight, workers=3, pickle_safe=True, initial_epoch=540)
# Out:
# model_name weights.539-0.3229.hdf5
# BATCHSIZE 128
# Epoch 541/2000
# Epoch 00540: val_loss improved from inf to 0.31048, saving model to ./checkpoint/weights.540-0.3105.hdf5
# 30/30 [==============================] - 62s - loss: 0.4332 - acc: 0.9284 - val_loss: 0.3105 - val_acc: 0.8889
# Epoch 542/2000
# Epoch 00541: val_loss improved from 0.31048 to 0.30506, saving model to ./checkpoint/weights.541-0.3051.hdf5
# 30/30 [==============================] - 54s - loss: 0.4026 - acc: 0.9302 - val_loss: 0.3051 - val_acc: 0.8960
# Epoch 543/2000
# Epoch 00542: val_loss improved from 0.30506 to 0.30145, saving model to ./checkpoint/weights.542-0.3015.hdf5
# 30/30 [==============================] - 55s - loss: 0.4326 - acc: 0.9328 - val_loss: 0.3015 - val_acc: 0.8960
# Epoch 544/2000
# Epoch 00543: val_loss improved from 0.30145 to 0.30142, saving model to ./checkpoint/weights.543-0.3014.hdf5
# 30/30 [==============================] - 55s - loss: 0.4204 - acc: 0.9328 - val_loss: 0.3014 - val_acc: 0.8983
# Epoch 545/2000
# Epoch 00544: val_loss improved from 0.30142 to 0.29732, saving model to ./checkpoint/weights.544-0.2973.hdf5
# 30/30 [==============================] - 55s - loss: 0.3581 - acc: 0.9375 - val_loss: 0.2973 - val_acc: 0.8983
# Epoch 546/2000
# Epoch 00545: val_loss did not improve
# 30/30 [==============================] - 54s - loss: 0.4443 - acc: 0.9318 - val_loss: 0.3022 - val_acc: 0.9007
# Epoch 547/2000
# Epoch 00546: val_loss improved from 0.29732 to 0.29689, saving model to ./checkpoint/weights.546-0.2969.hdf5
# 30/30 [==============================] - 54s - loss: 0.3600 - acc: 0.9349 - val_loss: 0.2969 - val_acc: 0.9007
# Epoch 548/2000
# Epoch 00547: val_loss did not improve
# 30/30 [==============================] - 55s - loss: 0.4041 - acc: 0.9398 - val_loss: 0.3010 - val_acc: 0.8936
# Epoch 549/2000
# Epoch 00548: val_loss did not improve
# 30/30 [==============================] - 54s - loss: 0.4047 - acc: 0.9310 - val_loss: 0.3037 - val_acc: 0.9054
# Epoch 550/2000
# Epoch 00549: val_loss improved from 0.29689 to 0.29480, saving model to ./checkpoint/weights.549-0.2948.hdf5
# 30/30 [==============================] - 54s - loss: 0.3361 - acc: 0.9377 - val_loss: 0.2948 - val_acc: 0.9007
# Epoch 551/2000
# Epoch 00550: val_loss improved from 0.29480 to 0.28788, saving model to ./checkpoint/weights.550-0.2879.hdf5
# 30/30 [==============================] - 55s - loss: 0.3508 - acc: 0.9411 - val_loss: 0.2879 - val_acc: 0.9078
# Epoch 552/2000
# Epoch 00551: val_loss did not improve
# 30/30 [==============================] - 54s - loss: 0.3256 - acc: 0.9503 - val_loss: 0.2966 - val_acc: 0.9078
# Epoch 553/2000
# Epoch 00552: val_loss did not improve
# 30/30 [==============================] - 53s - loss: 0.3233 - acc: 0.9463 - val_loss: 0.2981 - val_acc: 0.9102
# Epoch 554/2000
# Epoch 00553: val_loss improved from 0.28788 to 0.28632, saving model to ./checkpoint/weights.553-0.2863.hdf5
# 30/30 [==============================] - 55s - loss: 0.3392 - acc: 0.9456 - val_loss: 0.2863 - val_acc: 0.9173
# Epoch 555/2000
# Epoch 00554: val_loss did not improve
# 30/30 [==============================] - 54s - loss: 0.3781 - acc: 0.9385 - val_loss: 0.2868 - val_acc: 0.9102
# Epoch 556/2000
# Epoch 00555: val_loss improved from 0.28632 to 0.28560, saving model to ./checkpoint/weights.555-0.2856.hdf5
# 30/30 [==============================] - 54s - loss: 0.3157 - acc: 0.9510 - val_loss: 0.2856 - val_acc: 0.9054
# Epoch 557/2000
# Epoch 00556: val_loss improved from 0.28560 to 0.27880, saving model to ./checkpoint/weights.556-0.2788.hdf5
# 30/30 [==============================] - 56s - loss: 0.3197 - acc: 0.9443 - val_loss: 0.2788 - val_acc: 0.9125
# Epoch 558/2000
# Epoch 00557: val_loss did not improve
# 30/30 [==============================] - 54s - loss: 0.3241 - acc: 0.9453 - val_loss: 0.2825 - val_acc: 0.9125
# Epoch 559/2000
# Epoch 00558: val_loss did not improve
# 30/30 [==============================] - 53s - loss: 0.3342 - acc: 0.9505 - val_loss: 0.2829 - val_acc: 0.9149
# Epoch 560/2000
# Epoch 00559: val_loss improved from 0.27880 to 0.27866, saving model to ./checkpoint/weights.559-0.2787.hdf5
# 30/30 [==============================] - 54s - loss: 0.3270 - acc: 0.9453 - val_loss: 0.2787 - val_acc: 0.9220
# Epoch 561/2000
# Epoch 00560: val_loss did not improve
# 30/30 [==============================] - 54s - loss: 0.3011 - acc: 0.9542 - val_loss: 0.2861 - val_acc: 0.9007
# Epoch 562/2000
# Epoch 00561: val_loss improved from 0.27866 to 0.27777, saving model to ./checkpoint/weights.561-0.2778.hdf5
# 30/30 [==============================] - 54s - loss: 0.2848 - acc: 0.9517 - val_loss: 0.2778 - val_acc: 0.9149
# Epoch 563/2000
# Epoch 00562: val_loss improved from 0.27777 to 0.27347, saving model to ./checkpoint/weights.562-0.2735.hdf5
# 30/30 [==============================] - 54s - loss: 0.2795 - acc: 0.9523 - val_loss: 0.2735 - val_acc: 0.9173
# Epoch 564/2000
# Epoch 00563: val_loss improved from 0.27347 to 0.27315, saving model to ./checkpoint/weights.563-0.2731.hdf5
# 30/30 [==============================] - 54s - loss: 0.2907 - acc: 0.9518 - val_loss: 0.2731 - val_acc: 0.9173
# Epoch 565/2000
# Epoch 00564: val_loss improved from 0.27315 to 0.27249, saving model to ./checkpoint/weights.564-0.2725.hdf5
# 30/30 [==============================] - 58s - loss: 0.2935 - acc: 0.9456 - val_loss: 0.2725 - val_acc: 0.9125
# Epoch 566/2000
# Epoch 00565: val_loss did not improve
# 30/30 [==============================] - 53s - loss: 0.2872 - acc: 0.9510 - val_loss: 0.2761 - val_acc: 0.9031
# Epoch 567/2000
# Epoch 00566: val_loss improved from 0.27249 to 0.26771, saving model to ./checkpoint/weights.566-0.2677.hdf5
# 30/30 [==============================] - 54s - loss: 0.2879 - acc: 0.9552 - val_loss: 0.2677 - val_acc: 0.9125
# Epoch 568/2000
# Epoch 00567: val_loss improved from 0.26771 to 0.26559, saving model to ./checkpoint/weights.567-0.2656.hdf5
# 30/30 [==============================] - 53s - loss: 0.2675 - acc: 0.9527 - val_loss: 0.2656 - val_acc: 0.9149
# Epoch 569/2000
# Epoch 00568: val_loss improved from 0.26559 to 0.26170, saving model to ./checkpoint/weights.568-0.2617.hdf5
# 30/30 [==============================] - 55s - loss: 0.2647 - acc: 0.9547 - val_loss: 0.2617 - val_acc: 0.9196
# Epoch 570/2000
# Epoch 00569: val_loss improved from 0.26170 to 0.26094, saving model to ./checkpoint/weights.569-0.2609.hdf5
# 30/30 [==============================] - 55s - loss: 0.2751 - acc: 0.9555 - val_loss: 0.2609 - val_acc: 0.9267
# Epoch 571/2000
# Epoch 00570: val_loss improved from 0.26094 to 0.25642, saving model to ./checkpoint/weights.570-0.2564.hdf5
# 30/30 [==============================] - 54s - loss: 0.2606 - acc: 0.9552 - val_loss: 0.2564 - val_acc: 0.9173
# Epoch 572/2000
# Epoch 00571: val_loss improved from 0.25642 to 0.25182, saving model to ./checkpoint/weights.571-0.2518.hdf5
# 30/30 [==============================] - 54s - loss: 0.2459 - acc: 0.9596 - val_loss: 0.2518 - val_acc: 0.9196
# Epoch 573/2000
# Epoch 00572: val_loss improved from 0.25182 to 0.24885, saving model to ./checkpoint/weights.572-0.2489.hdf5
# 30/30 [==============================] - 55s - loss: 0.2436 - acc: 0.9591 - val_loss: 0.2489 - val_acc: 0.9220
# Epoch 574/2000
# Epoch 00573: val_loss did not improve
# 30/30 [==============================] - 54s - loss: 0.2253 - acc: 0.9612 - val_loss: 0.2492 - val_acc: 0.9149
# Epoch 575/2000
# Epoch 00574: val_loss did not improve
# 30/30 [==============================] - 53s - loss: 0.2398 - acc: 0.9600 - val_loss: 0.2562 - val_acc: 0.9173
# Epoch 576/2000
# Epoch 00575: val_loss did not improve
# 30/30 [==============================] - 53s - loss: 0.2329 - acc: 0.9552 - val_loss: 0.2522 - val_acc: 0.9220
# Epoch 577/2000
# Epoch 00576: val_loss did not improve
# 30/30 [==============================] - 53s - loss: 0.2475 - acc: 0.9581 - val_loss: 0.2534 - val_acc: 0.9196
# Epoch 578/2000
# Epoch 00577: val_loss did not improve
# 30/30 [==============================] - 53s - loss: 0.2194 - acc: 0.9611 - val_loss: 0.2504 - val_acc: 0.9267
# Epoch 579/2000
# Epoch 00578: val_loss did not improve
# 30/30 [==============================] - 54s - loss: 0.2521 - acc: 0.9563 - val_loss: 0.2500 - val_acc: 0.9267
# Epoch 580/2000
# Epoch 00579: val_loss did not improve
# 30/30 [==============================] - 53s - loss: 0.2170 - acc: 0.9651 - val_loss: 0.2519 - val_acc: 0.9267
# Epoch 581/2000
# Epoch 00580: val_loss did not improve
# 30/30 [==============================] - 53s - loss: 0.1953 - acc: 0.9706 - val_loss: 0.2530 - val_acc: 0.9243
# Epoch 582/2000
# Epoch 00581: val_loss did not improve
# 30/30 [==============================] - 53s - loss: 0.2056 - acc: 0.9641 - val_loss: 0.2532 - val_acc: 0.9314
# Epoch 583/2000
# Epoch 00582: val_loss did not improve
# 30/30 [==============================] - 53s - loss: 0.2154 - acc: 0.9654 - val_loss: 0.2540 - val_acc: 0.9220
# Epoch 584/2000
# Epoch 00583: val_loss did not improve
#
# Epoch 00583: reducing learning rate to 9.99999974738e-07.
# 30/30 [==============================] - 53s - loss: 0.2089 - acc: 0.9610 - val_loss: 0.2495 - val_acc: 0.9291
# Epoch 585/2000
# Epoch 00584: val_loss improved from 0.24885 to 0.24696, saving model to ./checkpoint/weights.584-0.2470.hdf5
# 30/30 [==============================] - 54s - loss: 0.2135 - acc: 0.9596 - val_loss: 0.2470 - val_acc: 0.9243
# Epoch 586/2000
# Epoch 00585: val_loss improved from 0.24696 to 0.24575, saving model to ./checkpoint/weights.585-0.2458.hdf5
# 30/30 [==============================] - 54s - loss: 0.2221 - acc: 0.9654 - val_loss: 0.2458 - val_acc: 0.9291
# Epoch 587/2000
# Epoch 00586: val_loss improved from 0.24575 to 0.24507, saving model to ./checkpoint/weights.586-0.2451.hdf5
# 30/30 [==============================] - 57s - loss: 0.2076 - acc: 0.9647 - val_loss: 0.2451 - val_acc: 0.9267
# Epoch 588/2000
# Epoch 00587: val_loss improved from 0.24507 to 0.24496, saving model to ./checkpoint/weights.587-0.2450.hdf5
# 30/30 [==============================] - 56s - loss: 0.1863 - acc: 0.9669 - val_loss: 0.2450 - val_acc: 0.9267
# Epoch 589/2000
# Epoch 00588: val_loss improved from 0.24496 to 0.24481, saving model to ./checkpoint/weights.588-0.2448.hdf5
# 30/30 [==============================] - 56s - loss: 0.2245 - acc: 0.9661 - val_loss: 0.2448 - val_acc: 0.9291
# Epoch 590/2000
# Epoch 00589: val_loss did not improve
# 30/30 [==============================] - 53s - loss: 0.2021 - acc: 0.9644 - val_loss: 0.2454 - val_acc: 0.9267
# Epoch 591/2000
# Epoch 00590: val_loss did not improve
# 30/30 [==============================] - 53s - loss: 0.1891 - acc: 0.9674 - val_loss: 0.2448 - val_acc: 0.9243
# Epoch 592/2000
# Epoch 00591: val_loss improved from 0.24481 to 0.24424, saving model to ./checkpoint/weights.591-0.2442.hdf5
# 30/30 [==============================] - 54s - loss: 0.2061 - acc: 0.9714 - val_loss: 0.2442 - val_acc: 0.9314
# Epoch 593/2000
# Epoch 00592: val_loss improved from 0.24424 to 0.24392, saving model to ./checkpoint/weights.592-0.2439.hdf5
# 30/30 [==============================] - 53s - loss: 0.2319 - acc: 0.9649 - val_loss: 0.2439 - val_acc: 0.9314
# Epoch 594/2000
# Epoch 00593: val_loss improved from 0.24392 to 0.24385, saving model to ./checkpoint/weights.593-0.2438.hdf5
# 30/30 [==============================] - 54s - loss: 0.2129 - acc: 0.9672 - val_loss: 0.2438 - val_acc: 0.9291
# Epoch 595/2000
# Epoch 00594: val_loss improved from 0.24385 to 0.24326, saving model to ./checkpoint/weights.594-0.2433.hdf5
# 30/30 [==============================] - 54s - loss: 0.2269 - acc: 0.9648 - val_loss: 0.2433 - val_acc: 0.9314
# Epoch 596/2000
# Epoch 00595: val_loss improved from 0.24326 to 0.24302, saving model to ./checkpoint/weights.595-0.2430.hdf5
# 30/30 [==============================] - 53s - loss: 0.1991 - acc: 0.9686 - val_loss: 0.2430 - val_acc: 0.9338
# Epoch 597/2000
# Epoch 00596: val_loss improved from 0.24302 to 0.24275, saving model to ./checkpoint/weights.596-0.2428.hdf5
# 30/30 [==============================] - 54s - loss: 0.1860 - acc: 0.9729 - val_loss: 0.2428 - val_acc: 0.9338
# Epoch 598/2000
# Epoch 00597: val_loss did not improve
# 30/30 [==============================] - 53s - loss: 0.2302 - acc: 0.9581 - val_loss: 0.2442 - val_acc: 0.9291
# Epoch 599/2000
# Epoch 00598: val_loss did not improve
# 30/30 [==============================] - 52s - loss: 0.2299 - acc: 0.9641 - val_loss: 0.2442 - val_acc: 0.9314
# Epoch 600/2000
# Epoch 00599: val_loss did not improve
# 30/30 [==============================] - 53s - loss: 0.2005 - acc: 0.9685 - val_loss: 0.2444 - val_acc: 0.9338
# Epoch 601/2000
# Epoch 00600: val_loss did not improve
# 30/30 [==============================] - 53s - loss: 0.2092 - acc: 0.9651 - val_loss: 0.2451 - val_acc: 0.9362
# Epoch 602/2000
# Epoch 00601: val_loss did not improve
# 30/30 [==============================] - 53s - loss: 0.2027 - acc: 0.9633 - val_loss: 0.2454 - val_acc: 0.9338
# Epoch 603/2000
# Epoch 00602: val_loss did not improve
# 30/30 [==============================] - 53s - loss: 0.2180 - acc: 0.9586 - val_loss: 0.2448 - val_acc: 0.9362
# Epoch 604/2000
# Epoch 00603: val_loss did not improve
# 30/30 [==============================] - 53s - loss: 0.2043 - acc: 0.9633 - val_loss: 0.2439 - val_acc: 0.9362
# Epoch 605/2000
# Epoch 00604: val_loss did not improve
# 30/30 [==============================] - 53s - loss: 0.1992 - acc: 0.9646 - val_loss: 0.2434 - val_acc: 0.9385
# Epoch 606/2000
# Epoch 00605: val_loss improved from 0.24275 to 0.24225, saving model to ./checkpoint/weights.605-0.2422.hdf5
# 30/30 [==============================] - 53s - loss: 0.1917 - acc: 0.9701 - val_loss: 0.2422 - val_acc: 0.9385
# Epoch 607/2000
# Epoch 00606: val_loss improved from 0.24225 to 0.24202, saving model to ./checkpoint/weights.606-0.2420.hdf5
#
# Epoch 00606: reducing learning rate to 9.99999997475e-08.
# 30/30 [==============================] - 54s - loss: 0.2083 - acc: 0.9690 - val_loss: 0.2420 - val_acc: 0.9385
# Epoch 608/2000
# Epoch 00607: val_loss did not improve
# 30/30 [==============================] - 53s - loss: 0.1958 - acc: 0.9685 - val_loss: 0.2429 - val_acc: 0.9362
# Epoch 609/2000
# Epoch 00608: val_loss did not improve
# 30/30 [==============================] - 52s - loss: 0.1819 - acc: 0.9674 - val_loss: 0.2428 - val_acc: 0.9385
# Epoch 610/2000
# Epoch 00609: val_loss did not improve
# 30/30 [==============================] - 53s - loss: 0.1938 - acc: 0.9711 - val_loss: 0.2428 - val_acc: 0.9385
# Epoch 611/2000
# Epoch 00610: val_loss did not improve
# 30/30 [==============================] - 53s - loss: 0.2138 - acc: 0.9641 - val_loss: 0.2420 - val_acc: 0.9362
# Epoch 612/2000
# Epoch 00611: val_loss did not improve
# 30/30 [==============================] - 52s - loss: 0.1782 - acc: 0.9684 - val_loss: 0.2425 - val_acc: 0.9362
# Epoch 613/2000
# Epoch 00612: val_loss did not improve
# 30/30 [==============================] - 53s - loss: 0.1945 - acc: 0.9693 - val_loss: 0.2427 - val_acc: 0.9385
# Epoch 614/2000
# Epoch 00613: val_loss did not improve
# 30/30 [==============================] - 53s - loss: 0.2065 - acc: 0.9633 - val_loss: 0.2433 - val_acc: 0.9362
# Epoch 615/2000
# Epoch 00614: val_loss did not improve
# 30/30 [==============================] - 53s - loss: 0.2129 - acc: 0.9651 - val_loss: 0.2433 - val_acc: 0.9362
# Epoch 616/2000
# Epoch 00615: val_loss did not improve
# 30/30 [==============================] - 54s - loss: 0.2256 - acc: 0.9617 - val_loss: 0.2436 - val_acc: 0.9362
# Epoch 617/2000
# Epoch 00616: val_loss did not improve
#
# Epoch 00616: reducing learning rate to 1.00000001169e-08.
# 30/30 [==============================] - 53s - loss: 0.1945 - acc: 0.9698 - val_loss: 0.2434 - val_acc: 0.9362
# Epoch 618/2000
# Epoch 00617: val_loss did not improve
# 30/30 [==============================] - 53s - loss: 0.2083 - acc: 0.9646 - val_loss: 0.2432 - val_acc: 0.9362
# Epoch 619/2000
# Epoch 00618: val_loss did not improve
# 30/30 [==============================] - 53s - loss: 0.2170 - acc: 0.9620 - val_loss: 0.2426 - val_acc: 0.9362
# Epoch 620/2000
# Epoch 00619: val_loss did not improve
# 30/30 [==============================] - 53s - loss: 0.1837 - acc: 0.9693 - val_loss: 0.2423 - val_acc: 0.9362
# Epoch 621/2000
# Epoch 00620: val_loss improved from 0.24202 to 0.24200, saving model to ./checkpoint/weights.620-0.2420.hdf5
# 30/30 [==============================] - 53s - loss: 0.1884 - acc: 0.9709 - val_loss: 0.2420 - val_acc: 0.9338
# Epoch 622/2000
# Epoch 00621: val_loss did not improve
# 30/30 [==============================] - 53s - loss: 0.2118 - acc: 0.9638 - val_loss: 0.2422 - val_acc: 0.9362
# Epoch 623/2000
# Epoch 00622: val_loss improved from 0.24200 to 0.24169, saving model to ./checkpoint/weights.622-0.2417.hdf5
# 30/30 [==============================] - 54s - loss: 0.2053 - acc: 0.9690 - val_loss: 0.2417 - val_acc: 0.9362
# Epoch 624/2000
# Epoch 00623: val_loss improved from 0.24169 to 0.24122, saving model to ./checkpoint/weights.623-0.2412.hdf5
# 30/30 [==============================] - 53s - loss: 0.2225 - acc: 0.9658 - val_loss: 0.2412 - val_acc: 0.9338
# Epoch 625/2000
# Epoch 00624: val_loss did not improve
# 30/30 [==============================] - 53s - loss: 0.1918 - acc: 0.9685 - val_loss: 0.2417 - val_acc: 0.9362
# Epoch 626/2000
# Epoch 00625: val_loss did not improve
# 30/30 [==============================] - 58s - loss: 0.2049 - acc: 0.9674 - val_loss: 0.2423 - val_acc: 0.9362
# Epoch 627/2000
# Epoch 00626: val_loss did not improve
# 30/30 [==============================] - 53s - loss: 0.2130 - acc: 0.9690 - val_loss: 0.2419 - val_acc: 0.9362
# Epoch 628/2000
# Epoch 00627: val_loss did not improve
# 30/30 [==============================] - 53s - loss: 0.1920 - acc: 0.9693 - val_loss: 0.2421 - val_acc: 0.9385
# Epoch 629/2000
# Epoch 00628: val_loss did not improve
# 30/30 [==============================] - 53s - loss: 0.2024 - acc: 0.9604 - val_loss: 0.2416 - val_acc: 0.9385
# Epoch 630/2000
# Epoch 00629: val_loss did not improve
# 30/30 [==============================] - 53s - loss: 0.2041 - acc: 0.9640 - val_loss: 0.2414 - val_acc: 0.9362
# Epoch 631/2000
# Epoch 00630: val_loss improved from 0.24122 to 0.24067, saving model to ./checkpoint/weights.630-0.2407.hdf5
# 30/30 [==============================] - 53s - loss: 0.2103 - acc: 0.9638 - val_loss: 0.2407 - val_acc: 0.9362
# Epoch 632/2000
# Epoch 00631: val_loss did not improve
# 30/30 [==============================] - 53s - loss: 0.2062 - acc: 0.9672 - val_loss: 0.2415 - val_acc: 0.9338
# Epoch 633/2000
# Epoch 00632: val_loss did not improve
# 30/30 [==============================] - 52s - loss: 0.1976 - acc: 0.9614 - val_loss: 0.2418 - val_acc: 0.9338
# Epoch 634/2000
# Epoch 00633: val_loss did not improve
# 30/30 [==============================] - 53s - loss: 0.1902 - acc: 0.9708 - val_loss: 0.2424 - val_acc: 0.9385
# Epoch 635/2000
# Epoch 00634: val_loss did not improve
# 30/30 [==============================] - 53s - loss: 0.1936 - acc: 0.9690 - val_loss: 0.2428 - val_acc: 0.9338
# Epoch 636/2000
# Epoch 00635: val_loss did not improve
# 30/30 [==============================] - 53s - loss: 0.1980 - acc: 0.9677 - val_loss: 0.2424 - val_acc: 0.9362
# Epoch 637/2000
# Epoch 00636: val_loss did not improve
# 30/30 [==============================] - 52s - loss: 0.1906 - acc: 0.9688 - val_loss: 0.2422 - val_acc: 0.9362
# Epoch 638/2000
# Epoch 00637: val_loss did not improve
# 30/30 [==============================] - 53s - loss: 0.2095 - acc: 0.9615 - val_loss: 0.2426 - val_acc: 0.9362
# Epoch 639/2000
# Epoch 00638: val_loss did not improve
# 30/30 [==============================] - 53s - loss: 0.2053 - acc: 0.9661 - val_loss: 0.2421 - val_acc: 0.9385
# Epoch 640/2000
# Epoch 00639: val_loss did not improve
# 30/30 [==============================] - 52s - loss: 0.1731 - acc: 0.9739 - val_loss: 0.2421 - val_acc: 0.9385
# Epoch 641/2000
# Epoch 00640: val_loss did not improve
# 30/30 [==============================] - 53s - loss: 0.1906 - acc: 0.9643 - val_loss: 0.2432 - val_acc: 0.9362
# Epoch 642/2000
# Epoch 00641: val_loss did not improve
#
# Epoch 00641: reducing learning rate to 9.99999993923e-10.
# 30/30 [==============================] - 53s - loss: 0.2066 - acc: 0.9602 - val_loss: 0.2422 - val_acc: 0.9385
# Epoch 643/2000
# Epoch 00642: val_loss did not improve
# 30/30 [==============================] - 53s - loss: 0.2021 - acc: 0.9661 - val_loss: 0.2425 - val_acc: 0.9385
# Epoch 644/2000
# Epoch 00643: val_loss did not improve
# 30/30 [==============================] - 53s - loss: 0.1738 - acc: 0.9706 - val_loss: 0.2422 - val_acc: 0.9362
# Epoch 645/2000
# Epoch 00644: val_loss did not improve
# 30/30 [==============================] - 53s - loss: 0.2150 - acc: 0.9607 - val_loss: 0.2424 - val_acc: 0.9338
# Epoch 646/2000
# Epoch 00645: val_loss did not improve
# 30/30 [==============================] - 53s - loss: 0.2298 - acc: 0.9639 - val_loss: 0.2415 - val_acc: 0.9362
# Epoch 647/2000
# Epoch 00646: val_loss did not improve
# 30/30 [==============================] - 53s - loss: 0.1925 - acc: 0.9677 - val_loss: 0.2418 - val_acc: 0.9362
# Epoch 648/2000
# Epoch 00647: val_loss did not improve
# 30/30 [==============================] - 53s - loss: 0.1899 - acc: 0.9695 - val_loss: 0.2420 - val_acc: 0.9338
# Epoch 649/2000
# Epoch 00648: val_loss did not improve
# 30/30 [==============================] - 52s - loss: 0.2017 - acc: 0.9653 - val_loss: 0.2423 - val_acc: 0.9362
# Epoch 650/2000
# Epoch 00649: val_loss did not improve
# 30/30 [==============================] - 53s - loss: 0.2104 - acc: 0.9651 - val_loss: 0.2419 - val_acc: 0.9362
# Epoch 651/2000
# Epoch 00650: val_loss did not improve
# 30/30 [==============================] - 53s - loss: 0.1892 - acc: 0.9667 - val_loss: 0.2416 - val_acc: 0.9338
# Epoch 652/2000
# Epoch 00651: val_loss did not improve
#
# Epoch 00651: reducing learning rate to 9.99999971718e-11.
# 30/30 [==============================] - 52s - loss: 0.1963 - acc: 0.9677 - val_loss: 0.2409 - val_acc: 0.9362
# Epoch 653/2000
# Epoch 00652: val_loss did not improve
# 30/30 [==============================] - 53s - loss: 0.1998 - acc: 0.9669 - val_loss: 0.2414 - val_acc: 0.9338
# Epoch 654/2000
# Epoch 00653: val_loss did not improve
# 30/30 [==============================] - 53s - loss: 0.2131 - acc: 0.9643 - val_loss: 0.2417 - val_acc: 0.9362
# Epoch 655/2000
# Epoch 00654: val_loss did not improve
# 30/30 [==============================] - 52s - loss: 0.1803 - acc: 0.9644 - val_loss: 0.2424 - val_acc: 0.9362
# Epoch 656/2000
# Epoch 00655: val_loss did not improve
# 30/30 [==============================] - 53s - loss: 0.2129 - acc: 0.9661 - val_loss: 0.2420 - val_acc: 0.9362
# Epoch 657/2000
# Epoch 00656: val_loss did not improve
# 30/30 [==============================] - 53s - loss: 0.2027 - acc: 0.9664 - val_loss: 0.2418 - val_acc: 0.9362
# Epoch 00656: early stopping

# %%
### Resnet50
# fine tuning stg3
# 164 conv5c+top
# 154 conv5b+conv5c+top
# 142 conv5+top i.e. conv5a+conv5b+conv5c+top
# 80 conv4+conv5+top
# 38 conv3+conv4+conv5+top
# 6 conv2+conv3+conv4+conv5+top
# 2 conv1+conv2+conv3+conv4+conv5+top i.e. FROM SCRATCH
start_layer = 142

model, model_name = get_best_model()
# model = load_model(CHECKPOINT_DIR + 'weights.539-0.3229.hdf5')
# model_name = 'weights.539-0.3229.hdf5'
# print('model_name', model_name)

for layer in model.layers[:start_layer]:
   layer.trainable = False
for layer in model.layers[start_layer:]:
   layer.trainable = True

# we need to recompile the model for these modifications to take effect
# we use SGD with a low learning rate
optimizer = Adam(lr=1e-5)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

print('BATCHSIZE', BATCHSIZE)
model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=2000, verbose=1, 
                    callbacks=[early_stopping, model_checkpoint, learningrate_schedule, tensorboard], 
                    validation_data=(X_valid_centered, y_valid), 
                    class_weight=class_weight, workers=3, pickle_safe=True, initial_epoch=631)
# Out:
# Loading model from checkpoint file ./checkpoint/weights.630-0.2407.hdf5
# Loading model Done!
# BATCHSIZE 128
# Epoch 632/2000
# Epoch 00631: val_loss improved from 0.24067 to 0.24018, saving model to ./checkpoint/weights.631-0.2402.hdf5
# 30/30 [==============================] - 65s - loss: 0.1780 - acc: 0.9716 - val_loss: 0.2402 - val_acc: 0.9196
# Epoch 633/2000
# Epoch 00632: val_loss did not improve
# 30/30 [==============================] - 55s - loss: 0.2034 - acc: 0.9701 - val_loss: 0.2449 - val_acc: 0.9196
# Epoch 634/2000
# Epoch 00633: val_loss improved from 0.24018 to 0.23929, saving model to ./checkpoint/weights.633-0.2393.hdf5
# 30/30 [==============================] - 56s - loss: 0.1929 - acc: 0.9656 - val_loss: 0.2393 - val_acc: 0.9220
# Epoch 635/2000
# Epoch 00634: val_loss improved from 0.23929 to 0.23574, saving model to ./checkpoint/weights.634-0.2357.hdf5
# 30/30 [==============================] - 55s - loss: 0.1905 - acc: 0.9675 - val_loss: 0.2357 - val_acc: 0.9243
# Epoch 636/2000
# Epoch 00635: val_loss did not improve
# 30/30 [==============================] - 55s - loss: 0.1876 - acc: 0.9685 - val_loss: 0.2370 - val_acc: 0.9314
# Epoch 637/2000
# Epoch 00636: val_loss improved from 0.23574 to 0.22549, saving model to ./checkpoint/weights.636-0.2255.hdf5
# 30/30 [==============================] - 56s - loss: 0.1896 - acc: 0.9665 - val_loss: 0.2255 - val_acc: 0.9338
# Epoch 638/2000
# Epoch 00637: val_loss did not improve
# 30/30 [==============================] - 55s - loss: 0.1759 - acc: 0.9740 - val_loss: 0.2270 - val_acc: 0.9338
# Epoch 639/2000
# Epoch 00638: val_loss improved from 0.22549 to 0.22326, saving model to ./checkpoint/weights.638-0.2233.hdf5
# 30/30 [==============================] - 56s - loss: 0.1667 - acc: 0.9667 - val_loss: 0.2233 - val_acc: 0.9338
# Epoch 640/2000
# Epoch 00639: val_loss improved from 0.22326 to 0.22039, saving model to ./checkpoint/weights.639-0.2204.hdf5
# 30/30 [==============================] - 56s - loss: 0.1703 - acc: 0.9723 - val_loss: 0.2204 - val_acc: 0.9314
# Epoch 641/2000
# Epoch 00640: val_loss did not improve
# 30/30 [==============================] - 55s - loss: 0.1634 - acc: 0.9749 - val_loss: 0.2211 - val_acc: 0.9385
# Epoch 642/2000
# Epoch 00641: val_loss improved from 0.22039 to 0.21721, saving model to ./checkpoint/weights.641-0.2172.hdf5
# 30/30 [==============================] - 56s - loss: 0.1614 - acc: 0.9721 - val_loss: 0.2172 - val_acc: 0.9433
# Epoch 643/2000
# Epoch 00642: val_loss improved from 0.21721 to 0.21614, saving model to ./checkpoint/weights.642-0.2161.hdf5
# 30/30 [==============================] - 59s - loss: 0.1538 - acc: 0.9737 - val_loss: 0.2161 - val_acc: 0.9385
# Epoch 644/2000
# Epoch 00643: val_loss did not improve
# 30/30 [==============================] - 55s - loss: 0.1662 - acc: 0.9740 - val_loss: 0.2376 - val_acc: 0.9243
# Epoch 645/2000
# Epoch 00644: val_loss did not improve
# 30/30 [==============================] - 56s - loss: 0.1468 - acc: 0.9773 - val_loss: 0.2302 - val_acc: 0.9314
# Epoch 646/2000
# Epoch 00645: val_loss improved from 0.21614 to 0.21308, saving model to ./checkpoint/weights.645-0.2131.hdf5
# 30/30 [==============================] - 56s - loss: 0.1489 - acc: 0.9779 - val_loss: 0.2131 - val_acc: 0.9433
# Epoch 647/2000
# Epoch 00646: val_loss improved from 0.21308 to 0.20111, saving model to ./checkpoint/weights.646-0.2011.hdf5
# 30/30 [==============================] - 56s - loss: 0.1566 - acc: 0.9757 - val_loss: 0.2011 - val_acc: 0.9433
# Epoch 648/2000
# Epoch 00647: val_loss improved from 0.20111 to 0.19423, saving model to ./checkpoint/weights.647-0.1942.hdf5
# 30/30 [==============================] - 58s - loss: 0.1443 - acc: 0.9771 - val_loss: 0.1942 - val_acc: 0.9480
# Epoch 649/2000
# Epoch 00648: val_loss did not improve
# 30/30 [==============================] - 55s - loss: 0.1211 - acc: 0.9794 - val_loss: 0.1950 - val_acc: 0.9504
# Epoch 650/2000
# Epoch 00649: val_loss did not improve
# 30/30 [==============================] - 54s - loss: 0.1223 - acc: 0.9822 - val_loss: 0.1984 - val_acc: 0.9504
# Epoch 651/2000
# Epoch 00650: val_loss did not improve
# 30/30 [==============================] - 55s - loss: 0.1217 - acc: 0.9794 - val_loss: 0.1953 - val_acc: 0.9527
# Epoch 652/2000
# Epoch 00651: val_loss did not improve
# 30/30 [==============================] - 55s - loss: 0.1406 - acc: 0.9784 - val_loss: 0.1944 - val_acc: 0.9551
# Epoch 653/2000
# Epoch 00652: val_loss did not improve
# 30/30 [==============================] - 55s - loss: 0.1348 - acc: 0.9784 - val_loss: 0.1947 - val_acc: 0.9456
# Epoch 654/2000
# Epoch 00653: val_loss did not improve
# 30/30 [==============================] - 55s - loss: 0.1098 - acc: 0.9823 - val_loss: 0.1945 - val_acc: 0.9504
# Epoch 655/2000
# Epoch 00654: val_loss improved from 0.19423 to 0.19340, saving model to ./checkpoint/weights.654-0.1934.hdf5
# 30/30 [==============================] - 56s - loss: 0.1155 - acc: 0.9805 - val_loss: 0.1934 - val_acc: 0.9456
# Epoch 656/2000
# Epoch 00655: val_loss improved from 0.19340 to 0.18857, saving model to ./checkpoint/weights.655-0.1886.hdf5
# 30/30 [==============================] - 55s - loss: 0.1233 - acc: 0.9763 - val_loss: 0.1886 - val_acc: 0.9456
# Epoch 657/2000
# Epoch 00656: val_loss did not improve
# 30/30 [==============================] - 55s - loss: 0.1067 - acc: 0.9815 - val_loss: 0.1924 - val_acc: 0.9551
# Epoch 658/2000
# Epoch 00657: val_loss did not improve
# 30/30 [==============================] - 55s - loss: 0.1205 - acc: 0.9828 - val_loss: 0.1959 - val_acc: 0.9456
# Epoch 659/2000
# Epoch 00658: val_loss did not improve
# 30/30 [==============================] - 55s - loss: 0.1012 - acc: 0.9871 - val_loss: 0.2080 - val_acc: 0.9456
# Epoch 660/2000
# Epoch 00659: val_loss did not improve
# 30/30 [==============================] - 55s - loss: 0.0936 - acc: 0.9827 - val_loss: 0.1921 - val_acc: 0.9527
# Epoch 661/2000
# Epoch 00660: val_loss improved from 0.18857 to 0.18302, saving model to ./checkpoint/weights.660-0.1830.hdf5
# 30/30 [==============================] - 56s - loss: 0.1214 - acc: 0.9812 - val_loss: 0.1830 - val_acc: 0.9574
# Epoch 662/2000
# Epoch 00661: val_loss did not improve
# 30/30 [==============================] - 55s - loss: 0.1074 - acc: 0.9819 - val_loss: 0.1832 - val_acc: 0.9480
# Epoch 663/2000
# Epoch 00662: val_loss improved from 0.18302 to 0.18063, saving model to ./checkpoint/weights.662-0.1806.hdf5
# 30/30 [==============================] - 56s - loss: 0.0971 - acc: 0.9851 - val_loss: 0.1806 - val_acc: 0.9551
# Epoch 664/2000
# Epoch 00663: val_loss did not improve
# 30/30 [==============================] - 55s - loss: 0.1084 - acc: 0.9812 - val_loss: 0.1874 - val_acc: 0.9504
# Epoch 665/2000
# Epoch 00664: val_loss did not improve
# 30/30 [==============================] - 55s - loss: 0.0875 - acc: 0.9868 - val_loss: 0.1857 - val_acc: 0.9527
# Epoch 666/2000
# Epoch 00665: val_loss did not improve
# 30/30 [==============================] - 55s - loss: 0.0918 - acc: 0.9857 - val_loss: 0.1871 - val_acc: 0.9480
# Epoch 667/2000
# Epoch 00666: val_loss improved from 0.18063 to 0.17997, saving model to ./checkpoint/weights.666-0.1800.hdf5
# 30/30 [==============================] - 56s - loss: 0.0902 - acc: 0.9880 - val_loss: 0.1800 - val_acc: 0.9527
# Epoch 668/2000
# Epoch 00667: val_loss improved from 0.17997 to 0.17310, saving model to ./checkpoint/weights.667-0.1731.hdf5
# 30/30 [==============================] - 58s - loss: 0.1066 - acc: 0.9848 - val_loss: 0.1731 - val_acc: 0.9527
# Epoch 669/2000
# Epoch 00668: val_loss did not improve
# 30/30 [==============================] - 55s - loss: 0.0965 - acc: 0.9851 - val_loss: 0.1783 - val_acc: 0.9551
# Epoch 670/2000
# Epoch 00669: val_loss did not improve
# 30/30 [==============================] - 55s - loss: 0.0951 - acc: 0.9846 - val_loss: 0.1828 - val_acc: 0.9527
# Epoch 671/2000
# Epoch 00670: val_loss did not improve
# 30/30 [==============================] - 55s - loss: 0.0871 - acc: 0.9872 - val_loss: 0.1811 - val_acc: 0.9551
# Epoch 672/2000
# Epoch 00671: val_loss did not improve
# 30/30 [==============================] - 55s - loss: 0.0832 - acc: 0.9852 - val_loss: 0.1811 - val_acc: 0.9574
# Epoch 673/2000
# Epoch 00672: val_loss did not improve
# 30/30 [==============================] - 55s - loss: 0.0876 - acc: 0.9872 - val_loss: 0.1784 - val_acc: 0.9504
# Epoch 674/2000
# Epoch 00673: val_loss did not improve
# 30/30 [==============================] - 55s - loss: 0.0913 - acc: 0.9859 - val_loss: 0.1762 - val_acc: 0.9551
# Epoch 675/2000
# Epoch 00674: val_loss did not improve
# 30/30 [==============================] - 55s - loss: 0.1010 - acc: 0.9886 - val_loss: 0.1814 - val_acc: 0.9480
# Epoch 676/2000
# Epoch 00675: val_loss did not improve
# 30/30 [==============================] - 55s - loss: 0.0841 - acc: 0.9846 - val_loss: 0.1821 - val_acc: 0.9456
# Epoch 677/2000
# Epoch 00676: val_loss did not improve
# 30/30 [==============================] - 55s - loss: 0.0772 - acc: 0.9865 - val_loss: 0.1750 - val_acc: 0.9504
# Epoch 678/2000
# Epoch 00677: val_loss improved from 0.17310 to 0.17050, saving model to ./checkpoint/weights.677-0.1705.hdf5
# 30/30 [==============================] - 55s - loss: 0.0759 - acc: 0.9865 - val_loss: 0.1705 - val_acc: 0.9527
# Epoch 679/2000
# Epoch 00678: val_loss improved from 0.17050 to 0.16863, saving model to ./checkpoint/weights.678-0.1686.hdf5
# 30/30 [==============================] - 56s - loss: 0.0775 - acc: 0.9883 - val_loss: 0.1686 - val_acc: 0.9551
# Epoch 680/2000
# Epoch 00679: val_loss improved from 0.16863 to 0.16560, saving model to ./checkpoint/weights.679-0.1656.hdf5
# 30/30 [==============================] - 56s - loss: 0.0741 - acc: 0.9883 - val_loss: 0.1656 - val_acc: 0.9527
# Epoch 681/2000
# Epoch 00680: val_loss did not improve
# 30/30 [==============================] - 55s - loss: 0.0645 - acc: 0.9895 - val_loss: 0.1683 - val_acc: 0.9527
# Epoch 682/2000
# Epoch 00681: val_loss improved from 0.16560 to 0.16548, saving model to ./checkpoint/weights.681-0.1655.hdf5
# 30/30 [==============================] - 56s - loss: 0.0671 - acc: 0.9909 - val_loss: 0.1655 - val_acc: 0.9645
# Epoch 683/2000
# Epoch 00682: val_loss improved from 0.16548 to 0.16406, saving model to ./checkpoint/weights.682-0.1641.hdf5
# 30/30 [==============================] - 59s - loss: 0.0713 - acc: 0.9891 - val_loss: 0.1641 - val_acc: 0.9527
# Epoch 684/2000
# Epoch 00683: val_loss improved from 0.16406 to 0.15870, saving model to ./checkpoint/weights.683-0.1587.hdf5
# 30/30 [==============================] - 58s - loss: 0.0684 - acc: 0.9927 - val_loss: 0.1587 - val_acc: 0.9527
# Epoch 685/2000
# Epoch 00684: val_loss did not improve
# 30/30 [==============================] - 58s - loss: 0.0691 - acc: 0.9891 - val_loss: 0.1625 - val_acc: 0.9574
# Epoch 686/2000
# Epoch 00685: val_loss did not improve
# 30/30 [==============================] - 55s - loss: 0.0764 - acc: 0.9906 - val_loss: 0.1621 - val_acc: 0.9622
# Epoch 687/2000
# Epoch 00686: val_loss did not improve
# 30/30 [==============================] - 55s - loss: 0.0709 - acc: 0.9911 - val_loss: 0.1662 - val_acc: 0.9645
# Epoch 688/2000
# Epoch 00687: val_loss did not improve
# 30/30 [==============================] - 55s - loss: 0.0640 - acc: 0.9903 - val_loss: 0.1685 - val_acc: 0.9645
# Epoch 689/2000
# Epoch 00688: val_loss did not improve
# 30/30 [==============================] - 55s - loss: 0.0581 - acc: 0.9922 - val_loss: 0.1710 - val_acc: 0.9551
# Epoch 690/2000
# Epoch 00689: val_loss did not improve
# 30/30 [==============================] - 55s - loss: 0.0585 - acc: 0.9919 - val_loss: 0.1703 - val_acc: 0.9551
# Epoch 691/2000
# Epoch 00690: val_loss did not improve
# 30/30 [==============================] - 55s - loss: 0.0585 - acc: 0.9904 - val_loss: 0.1662 - val_acc: 0.9574
# Epoch 692/2000
# Epoch 00691: val_loss did not improve
# 30/30 [==============================] - 55s - loss: 0.0605 - acc: 0.9911 - val_loss: 0.1622 - val_acc: 0.9598
# Epoch 693/2000
# Epoch 00692: val_loss did not improve
# 30/30 [==============================] - 55s - loss: 0.0631 - acc: 0.9890 - val_loss: 0.1655 - val_acc: 0.9504
# Epoch 694/2000
# Epoch 00693: val_loss did not improve
# 30/30 [==============================] - 55s - loss: 0.0627 - acc: 0.9878 - val_loss: 0.1636 - val_acc: 0.9574
# Epoch 695/2000
# Epoch 00694: val_loss did not improve
#
# Epoch 00694: reducing learning rate to 9.99999974738e-07.
# 30/30 [==============================] - 56s - loss: 0.0661 - acc: 0.9906 - val_loss: 0.1633 - val_acc: 0.9622
# Epoch 696/2000
# Epoch 00695: val_loss did not improve
# 30/30 [==============================] - 57s - loss: 0.0543 - acc: 0.9911 - val_loss: 0.1627 - val_acc: 0.9622
# Epoch 697/2000
# Epoch 00696: val_loss did not improve
# 30/30 [==============================] - 57s - loss: 0.0604 - acc: 0.9911 - val_loss: 0.1625 - val_acc: 0.9622
# Epoch 698/2000
# Epoch 00697: val_loss did not improve
# 30/30 [==============================] - 57s - loss: 0.0491 - acc: 0.9930 - val_loss: 0.1622 - val_acc: 0.9645
# Epoch 699/2000
# Epoch 00698: val_loss did not improve
# 30/30 [==============================] - 57s - loss: 0.0540 - acc: 0.9915 - val_loss: 0.1615 - val_acc: 0.9598
# Epoch 700/2000
# Epoch 00699: val_loss did not improve
# 30/30 [==============================] - 56s - loss: 0.0523 - acc: 0.9921 - val_loss: 0.1613 - val_acc: 0.9622
# Epoch 701/2000
# Epoch 00700: val_loss did not improve
# 30/30 [==============================] - 57s - loss: 0.0523 - acc: 0.9930 - val_loss: 0.1606 - val_acc: 0.9598
# Epoch 702/2000
# Epoch 00701: val_loss did not improve
# 30/30 [==============================] - 57s - loss: 0.0573 - acc: 0.9927 - val_loss: 0.1608 - val_acc: 0.9598
# Epoch 703/2000
# Epoch 00702: val_loss did not improve
# 30/30 [==============================] - 56s - loss: 0.0534 - acc: 0.9932 - val_loss: 0.1602 - val_acc: 0.9598
# Epoch 704/2000
# Epoch 00703: val_loss did not improve
# 30/30 [==============================] - 57s - loss: 0.0653 - acc: 0.9904 - val_loss: 0.1603 - val_acc: 0.9598
# Epoch 705/2000
# Epoch 00704: val_loss did not improve
#
# Epoch 00704: reducing learning rate to 9.99999997475e-08.
# 30/30 [==============================] - 57s - loss: 0.0521 - acc: 0.9922 - val_loss: 0.1598 - val_acc: 0.9622
# Epoch 706/2000
# Epoch 00705: val_loss did not improve
# 30/30 [==============================] - 56s - loss: 0.0498 - acc: 0.9907 - val_loss: 0.1595 - val_acc: 0.9598
# Epoch 707/2000
# Epoch 00706: val_loss did not improve
# 30/30 [==============================] - 57s - loss: 0.0649 - acc: 0.9924 - val_loss: 0.1595 - val_acc: 0.9622
# Epoch 708/2000
# Epoch 00707: val_loss did not improve
# 30/30 [==============================] - 57s - loss: 0.0569 - acc: 0.9914 - val_loss: 0.1591 - val_acc: 0.9598
# Epoch 709/2000
# Epoch 00708: val_loss did not improve
# 30/30 [==============================] - 56s - loss: 0.0548 - acc: 0.9917 - val_loss: 0.1588 - val_acc: 0.9622
# Epoch 710/2000
# Epoch 00709: val_loss did not improve
# 30/30 [==============================] - 57s - loss: 0.0515 - acc: 0.9911 - val_loss: 0.1593 - val_acc: 0.9622
# Epoch 00709: early stopping

# %%
### Resnet50
# fine tuning stg4
# 164 conv5c+top
# 154 conv5b+conv5c+top
# 142 conv5+top i.e. conv5a+conv5b+conv5c+top
# 132 conv4f+conv5+top
# 80 conv4+conv5+top
# 38 conv3+conv4+conv5+top
# 6 conv2+conv3+conv4+conv5+top
# 2 conv1+conv2+conv3+conv4+conv5+top i.e. FROM SCRATCH
start_layer = 132

model, model_name = get_best_model()
# model = load_model(CHECKPOINT_DIR + 'weights.539-0.3229.hdf5')
# model_name = 'weights.539-0.3229.hdf5'
# print('model_name', model_name)

for layer in model.layers[:start_layer]:
   layer.trainable = False
for layer in model.layers[start_layer:]:
   layer.trainable = True

# we need to recompile the model for these modifications to take effect
# we use SGD with a low learning rate
optimizer = Adam(lr=1e-5)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

print('BATCHSIZE', BATCHSIZE)
model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=2000, verbose=1, 
                    callbacks=[early_stopping, model_checkpoint, learningrate_schedule, tensorboard], 
                    validation_data=(X_valid_centered, y_valid), 
                    class_weight=class_weight, workers=3, pickle_safe=True, initial_epoch=684)
# Out:
# Loading model from checkpoint file ./checkpoint/weights.683-0.1587.hdf5
# Loading model Done!
# BATCHSIZE 128
# Epoch 685/2000
# Epoch 00684: val_loss did not improve
# 30/30 [==============================] - 60s - loss: 0.0609 - acc: 0.9935 - val_loss: 0.1755 - val_acc: 0.9574
# Epoch 686/2000
# Epoch 00685: val_loss did not improve
# 30/30 [==============================] - 57s - loss: 0.0651 - acc: 0.9901 - val_loss: 0.1737 - val_acc: 0.9622
# Epoch 687/2000
# Epoch 00686: val_loss did not improve
# 30/30 [==============================] - 57s - loss: 0.0654 - acc: 0.9918 - val_loss: 0.1710 - val_acc: 0.9645
# Epoch 688/2000
# Epoch 00687: val_loss did not improve
# 30/30 [==============================] - 57s - loss: 0.0706 - acc: 0.9908 - val_loss: 0.1687 - val_acc: 0.9622
# Epoch 689/2000
# Epoch 00688: val_loss did not improve
# 30/30 [==============================] - 58s - loss: 0.0612 - acc: 0.9891 - val_loss: 0.1703 - val_acc: 0.9622
# Epoch 690/2000
# Epoch 00689: val_loss did not improve
# 30/30 [==============================] - 58s - loss: 0.0598 - acc: 0.9909 - val_loss: 0.1718 - val_acc: 0.9598
# Epoch 691/2000
# Epoch 00690: val_loss did not improve
# 30/30 [==============================] - 57s - loss: 0.0531 - acc: 0.9897 - val_loss: 0.1729 - val_acc: 0.9574
# Epoch 692/2000
# Epoch 00691: val_loss did not improve
# 30/30 [==============================] - 58s - loss: 0.0660 - acc: 0.9906 - val_loss: 0.1665 - val_acc: 0.9598
# Epoch 693/2000
# Epoch 00692: val_loss did not improve
# 30/30 [==============================] - 57s - loss: 0.0686 - acc: 0.9903 - val_loss: 0.1652 - val_acc: 0.9574
# Epoch 694/2000
# Epoch 00693: val_loss did not improve
# 30/30 [==============================] - 57s - loss: 0.0661 - acc: 0.9910 - val_loss: 0.1599 - val_acc: 0.9645
# Epoch 695/2000
# Epoch 00694: val_loss improved from 0.15870 to 0.15403, saving model to ./checkpoint/weights.694-0.1540.hdf5
# 30/30 [==============================] - 71s - loss: 0.0592 - acc: 0.9911 - val_loss: 0.1540 - val_acc: 0.9645
# Epoch 696/2000
# Epoch 00695: val_loss improved from 0.15403 to 0.15146, saving model to ./checkpoint/weights.695-0.1515.hdf5
# 30/30 [==============================] - 58s - loss: 0.0509 - acc: 0.9937 - val_loss: 0.1515 - val_acc: 0.9622
# Epoch 697/2000
# Epoch 00696: val_loss did not improve
# 30/30 [==============================] - 57s - loss: 0.0580 - acc: 0.9931 - val_loss: 0.1618 - val_acc: 0.9622
# Epoch 698/2000
# Epoch 00697: val_loss did not improve
# 30/30 [==============================] - 58s - loss: 0.0544 - acc: 0.9906 - val_loss: 0.1543 - val_acc: 0.9622
# Epoch 699/2000
# Epoch 00698: val_loss improved from 0.15146 to 0.14887, saving model to ./checkpoint/weights.698-0.1489.hdf5
# 30/30 [==============================] - 58s - loss: 0.0518 - acc: 0.9943 - val_loss: 0.1489 - val_acc: 0.9669
# Epoch 700/2000
# Epoch 00699: val_loss improved from 0.14887 to 0.14737, saving model to ./checkpoint/weights.699-0.1474.hdf5
# 30/30 [==============================] - 57s - loss: 0.0468 - acc: 0.9945 - val_loss: 0.1474 - val_acc: 0.9645
# Epoch 701/2000
# Epoch 00700: val_loss improved from 0.14737 to 0.14660, saving model to ./checkpoint/weights.700-0.1466.hdf5
# 30/30 [==============================] - 58s - loss: 0.0448 - acc: 0.9945 - val_loss: 0.1466 - val_acc: 0.9693
# Epoch 702/2000
# Epoch 00701: val_loss did not improve
# 30/30 [==============================] - 58s - loss: 0.0468 - acc: 0.9932 - val_loss: 0.1478 - val_acc: 0.9716
# Epoch 703/2000
# Epoch 00702: val_loss improved from 0.14660 to 0.14582, saving model to ./checkpoint/weights.702-0.1458.hdf5
# 30/30 [==============================] - 57s - loss: 0.0430 - acc: 0.9955 - val_loss: 0.1458 - val_acc: 0.9716
# Epoch 704/2000
# Epoch 00703: val_loss improved from 0.14582 to 0.14468, saving model to ./checkpoint/weights.703-0.1447.hdf5
# 30/30 [==============================] - 58s - loss: 0.0538 - acc: 0.9914 - val_loss: 0.1447 - val_acc: 0.9716
# Epoch 705/2000
# Epoch 00704: val_loss did not improve
# 30/30 [==============================] - 58s - loss: 0.0368 - acc: 0.9924 - val_loss: 0.1503 - val_acc: 0.9622
# Epoch 706/2000
# Epoch 00705: val_loss did not improve
# 30/30 [==============================] - 57s - loss: 0.0440 - acc: 0.9937 - val_loss: 0.1549 - val_acc: 0.9622
# Epoch 707/2000
# Epoch 00706: val_loss did not improve
# 30/30 [==============================] - 57s - loss: 0.0554 - acc: 0.9929 - val_loss: 0.1520 - val_acc: 0.9669
# Epoch 708/2000
# Epoch 00707: val_loss did not improve
# 30/30 [==============================] - 58s - loss: 0.0476 - acc: 0.9917 - val_loss: 0.1508 - val_acc: 0.9645
# Epoch 709/2000
# Epoch 00708: val_loss did not improve
# 30/30 [==============================] - 57s - loss: 0.0504 - acc: 0.9930 - val_loss: 0.1499 - val_acc: 0.9622
# Epoch 710/2000
# Epoch 00709: val_loss improved from 0.14468 to 0.14414, saving model to ./checkpoint/weights.709-0.1441.hdf5
# 30/30 [==============================] - 58s - loss: 0.0513 - acc: 0.9956 - val_loss: 0.1441 - val_acc: 0.9645
# Epoch 711/2000
# Epoch 00710: val_loss did not improve
# 30/30 [==============================] - 58s - loss: 0.0418 - acc: 0.9927 - val_loss: 0.1447 - val_acc: 0.9716
# Epoch 712/2000
# Epoch 00711: val_loss did not improve
# 30/30 [==============================] - 57s - loss: 0.0412 - acc: 0.9960 - val_loss: 0.1487 - val_acc: 0.9693
# Epoch 713/2000
# Epoch 00712: val_loss did not improve
# 30/30 [==============================] - 57s - loss: 0.0425 - acc: 0.9921 - val_loss: 0.1458 - val_acc: 0.9645
# Epoch 714/2000
# Epoch 00713: val_loss improved from 0.14414 to 0.14087, saving model to ./checkpoint/weights.713-0.1409.hdf5
# 30/30 [==============================] - 58s - loss: 0.0371 - acc: 0.9948 - val_loss: 0.1409 - val_acc: 0.9716
# Epoch 715/2000
# Epoch 00714: val_loss did not improve
# 30/30 [==============================] - 57s - loss: 0.0463 - acc: 0.9929 - val_loss: 0.1417 - val_acc: 0.9764
# Epoch 716/2000
# Epoch 00715: val_loss did not improve
# 30/30 [==============================] - 57s - loss: 0.0446 - acc: 0.9953 - val_loss: 0.1448 - val_acc: 0.9716
# Epoch 717/2000
# Epoch 00716: val_loss improved from 0.14087 to 0.13944, saving model to ./checkpoint/weights.716-0.1394.hdf5
# 30/30 [==============================] - 58s - loss: 0.0467 - acc: 0.9937 - val_loss: 0.1394 - val_acc: 0.9716
# Epoch 718/2000
# Epoch 00717: val_loss did not improve
# 30/30 [==============================] - 57s - loss: 0.0353 - acc: 0.9942 - val_loss: 0.1421 - val_acc: 0.9716
# Epoch 719/2000
# Epoch 00718: val_loss did not improve
# 30/30 [==============================] - 57s - loss: 0.0364 - acc: 0.9958 - val_loss: 0.1394 - val_acc: 0.9764
# Epoch 720/2000
# Epoch 00719: val_loss did not improve
# 30/30 [==============================] - 58s - loss: 0.0364 - acc: 0.9948 - val_loss: 0.1440 - val_acc: 0.9716
# Epoch 721/2000
# Epoch 00720: val_loss did not improve
# 30/30 [==============================] - 58s - loss: 0.0359 - acc: 0.9969 - val_loss: 0.1424 - val_acc: 0.9740
# Epoch 722/2000
# Epoch 00721: val_loss did not improve
# 30/30 [==============================] - 57s - loss: 0.0338 - acc: 0.9947 - val_loss: 0.1413 - val_acc: 0.9693
# Epoch 723/2000
# Epoch 00722: val_loss did not improve
# 30/30 [==============================] - 58s - loss: 0.0338 - acc: 0.9945 - val_loss: 0.1409 - val_acc: 0.9693
# Epoch 724/2000
# Epoch 00723: val_loss improved from 0.13944 to 0.13746, saving model to ./checkpoint/weights.723-0.1375.hdf5
# 30/30 [==============================] - 58s - loss: 0.0296 - acc: 0.9966 - val_loss: 0.1375 - val_acc: 0.9716
# Epoch 725/2000
# Epoch 00724: val_loss improved from 0.13746 to 0.13553, saving model to ./checkpoint/weights.724-0.1355.hdf5
# 30/30 [==============================] - 58s - loss: 0.0411 - acc: 0.9946 - val_loss: 0.1355 - val_acc: 0.9764
# Epoch 726/2000
# Epoch 00725: val_loss did not improve
# 30/30 [==============================] - 58s - loss: 0.0289 - acc: 0.9964 - val_loss: 0.1374 - val_acc: 0.9693
# Epoch 727/2000
# Epoch 00726: val_loss did not improve
# 30/30 [==============================] - 58s - loss: 0.0500 - acc: 0.9958 - val_loss: 0.1362 - val_acc: 0.9693
# Epoch 728/2000
# Epoch 00727: val_loss did not improve
# 30/30 [==============================] - 57s - loss: 0.0312 - acc: 0.9950 - val_loss: 0.1504 - val_acc: 0.9622
# Epoch 729/2000
# Epoch 00728: val_loss did not improve
# 30/30 [==============================] - 59s - loss: 0.0475 - acc: 0.9961 - val_loss: 0.1527 - val_acc: 0.9645
# Epoch 730/2000
# Epoch 00729: val_loss did not improve
# 30/30 [==============================] - 58s - loss: 0.0413 - acc: 0.9924 - val_loss: 0.1547 - val_acc: 0.9598
# Epoch 731/2000
# Epoch 00730: val_loss did not improve
# 30/30 [==============================] - 57s - loss: 0.0352 - acc: 0.9958 - val_loss: 0.1541 - val_acc: 0.9645
# Epoch 732/2000
# Epoch 00731: val_loss did not improve
# 30/30 [==============================] - 58s - loss: 0.0302 - acc: 0.9940 - val_loss: 0.1556 - val_acc: 0.9669
# Epoch 733/2000
# Epoch 00732: val_loss did not improve
# 30/30 [==============================] - 58s - loss: 0.0255 - acc: 0.9961 - val_loss: 0.1548 - val_acc: 0.9645
# Epoch 734/2000
# Epoch 00733: val_loss did not improve
# 30/30 [==============================] - 57s - loss: 0.0302 - acc: 0.9968 - val_loss: 0.1554 - val_acc: 0.9645
# Epoch 735/2000
# Epoch 00734: val_loss did not improve
# 30/30 [==============================] - 58s - loss: 0.0320 - acc: 0.9961 - val_loss: 0.1460 - val_acc: 0.9716
# Epoch 736/2000
# Epoch 00735: val_loss did not improve
#
# Epoch 00735: reducing learning rate to 9.99999974738e-07.
# 30/30 [==============================] - 59s - loss: 0.0400 - acc: 0.9964 - val_loss: 0.1444 - val_acc: 0.9669
# Epoch 737/2000
# Epoch 00736: val_loss did not improve
# 30/30 [==============================] - 59s - loss: 0.0267 - acc: 0.9950 - val_loss: 0.1437 - val_acc: 0.9669
# Epoch 738/2000
# Epoch 00737: val_loss did not improve
# 30/30 [==============================] - 60s - loss: 0.0263 - acc: 0.9958 - val_loss: 0.1437 - val_acc: 0.9693
# Epoch 739/2000
# Epoch 00738: val_loss did not improve
# 30/30 [==============================] - 59s - loss: 0.0274 - acc: 0.9961 - val_loss: 0.1435 - val_acc: 0.9693
# Epoch 740/2000
# Epoch 00739: val_loss did not improve
# 30/30 [==============================] - 59s - loss: 0.0195 - acc: 0.9979 - val_loss: 0.1432 - val_acc: 0.9693
# Epoch 741/2000
# Epoch 00740: val_loss did not improve
# 30/30 [==============================] - 59s - loss: 0.0356 - acc: 0.9945 - val_loss: 0.1422 - val_acc: 0.9669
# Epoch 742/2000
# Epoch 00741: val_loss did not improve
# 30/30 [==============================] - 60s - loss: 0.0251 - acc: 0.9958 - val_loss: 0.1426 - val_acc: 0.9669
# Epoch 743/2000
# Epoch 00742: val_loss did not improve
# 30/30 [==============================] - 59s - loss: 0.0262 - acc: 0.9971 - val_loss: 0.1430 - val_acc: 0.9669
# Epoch 744/2000
# Epoch 00743: val_loss did not improve
# 30/30 [==============================] - 59s - loss: 0.0250 - acc: 0.9960 - val_loss: 0.1433 - val_acc: 0.9669
# Epoch 745/2000
# Epoch 00744: val_loss did not improve
# 30/30 [==============================] - 59s - loss: 0.0259 - acc: 0.9971 - val_loss: 0.1421 - val_acc: 0.9669
# Epoch 746/2000
# Epoch 00745: val_loss did not improve
#
# Epoch 00745: reducing learning rate to 9.99999997475e-08.
# 30/30 [==============================] - 59s - loss: 0.0198 - acc: 0.9976 - val_loss: 0.1427 - val_acc: 0.9669
# Epoch 747/2000
# Epoch 00746: val_loss did not improve
# 30/30 [==============================] - 59s - loss: 0.0283 - acc: 0.9961 - val_loss: 0.1424 - val_acc: 0.9669
# Epoch 748/2000
# Epoch 00747: val_loss did not improve
# 30/30 [==============================] - 60s - loss: 0.0277 - acc: 0.9953 - val_loss: 0.1424 - val_acc: 0.9669
# Epoch 749/2000
# Epoch 00748: val_loss did not improve
# 30/30 [==============================] - 59s - loss: 0.0253 - acc: 0.9971 - val_loss: 0.1423 - val_acc: 0.9669
# Epoch 750/2000
# Epoch 00749: val_loss did not improve
# 30/30 [==============================] - 59s - loss: 0.0412 - acc: 0.9948 - val_loss: 0.1421 - val_acc: 0.9669
# Epoch 751/2000
# Epoch 00750: val_loss did not improve
# 30/30 [==============================] - 59s - loss: 0.0228 - acc: 0.9982 - val_loss: 0.1423 - val_acc: 0.9669
# Epoch 00750: early stopping

# %%
### Resnet50
# fine tuning stg5
# 164 conv5c+top
# 154 conv5b+conv5c+top
# 142 conv5+top i.e. conv5a+conv5b+conv5c+top
# 132 conv4f+conv5+top
# 122 conv4e+conv4f+conv5+top
# 80 conv4+conv5+top
# 38 conv3+conv4+conv5+top
# 6 conv2+conv3+conv4+conv5+top
# 2 conv1+conv2+conv3+conv4+conv5+top i.e. FROM SCRATCH
start_layer = 80

model, model_name = get_best_model()
# model = load_model(CHECKPOINT_DIR + 'weights.539-0.3229.hdf5')
# model_name = 'weights.539-0.3229.hdf5'
# print('model_name', model_name)

for layer in model.layers[:start_layer]:
   layer.trainable = False
for layer in model.layers[start_layer:]:
   layer.trainable = True

# we need to recompile the model for these modifications to take effect
# we use SGD with a low learning rate
optimizer = Adam(lr=1e-5)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

print('BATCHSIZE', BATCHSIZE)
model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=2000, verbose=1, 
                    callbacks=[early_stopping, model_checkpoint, learningrate_schedule, tensorboard], 
                    validation_data=(X_valid_centered, y_valid), 
                    class_weight=class_weight, workers=3, pickle_safe=True, initial_epoch=725)
# Out:
# Loading model from checkpoint file ./checkpoint/weights.724-0.1355.hdf5
# Loading model Done!
# BATCHSIZE 128
# Epoch 726/2000
# Epoch 00725: val_loss did not improve
# 30/30 [==============================] - 78s - loss: 0.0306 - acc: 0.9964 - val_loss: 0.1675 - val_acc: 0.9669
# Epoch 727/2000
# Epoch 00726: val_loss did not improve
# 30/30 [==============================] - 74s - loss: 0.0340 - acc: 0.9982 - val_loss: 0.1710 - val_acc: 0.9622
# Epoch 728/2000
# Epoch 00727: val_loss did not improve
# 30/30 [==============================] - 75s - loss: 0.0325 - acc: 0.9953 - val_loss: 0.1621 - val_acc: 0.9645
# Epoch 729/2000
# Epoch 00728: val_loss did not improve
# 30/30 [==============================] - 73s - loss: 0.0287 - acc: 0.9973 - val_loss: 0.1508 - val_acc: 0.9693
# Epoch 730/2000
# Epoch 00729: val_loss did not improve
# 30/30 [==============================] - 75s - loss: 0.0216 - acc: 0.9964 - val_loss: 0.1520 - val_acc: 0.9669
# Epoch 731/2000
# Epoch 00730: val_loss did not improve
# 30/30 [==============================] - 75s - loss: 0.0240 - acc: 0.9969 - val_loss: 0.1528 - val_acc: 0.9669
# Epoch 732/2000
# Epoch 00731: val_loss did not improve
# 30/30 [==============================] - 73s - loss: 0.0426 - acc: 0.9971 - val_loss: 0.1484 - val_acc: 0.9716
# Epoch 733/2000
# Epoch 00732: val_loss did not improve
# 30/30 [==============================] - 75s - loss: 0.0324 - acc: 0.9945 - val_loss: 0.1538 - val_acc: 0.9693
# Epoch 734/2000
# Epoch 00733: val_loss did not improve
# 30/30 [==============================] - 74s - loss: 0.0244 - acc: 0.9977 - val_loss: 0.1533 - val_acc: 0.9669
# Epoch 735/2000
# Epoch 00734: val_loss did not improve
# 30/30 [==============================] - 73s - loss: 0.0267 - acc: 0.9960 - val_loss: 0.1493 - val_acc: 0.9622
# Epoch 736/2000
# Epoch 00735: val_loss did not improve
# 30/30 [==============================] - 74s - loss: 0.0217 - acc: 0.9961 - val_loss: 0.1510 - val_acc: 0.9622
# Epoch 737/2000
# Epoch 00736: val_loss did not improve
# 30/30 [==============================] - 74s - loss: 0.0293 - acc: 0.9958 - val_loss: 0.1528 - val_acc: 0.9645
# Epoch 738/2000
# Epoch 00737: val_loss did not improve
# 30/30 [==============================] - 73s - loss: 0.0216 - acc: 0.9966 - val_loss: 0.1547 - val_acc: 0.9669
# Epoch 739/2000
# Epoch 00738: val_loss did not improve
# 30/30 [==============================] - 75s - loss: 0.0300 - acc: 0.9961 - val_loss: 0.1510 - val_acc: 0.9669
# Epoch 740/2000
# Epoch 00739: val_loss did not improve
# 30/30 [==============================] - 74s - loss: 0.0226 - acc: 0.9966 - val_loss: 0.1559 - val_acc: 0.9622
# Epoch 741/2000
# Epoch 00740: val_loss did not improve
# 30/30 [==============================] - 73s - loss: 0.0260 - acc: 0.9955 - val_loss: 0.1521 - val_acc: 0.9645
# Epoch 742/2000
# Epoch 00741: val_loss did not improve
# 30/30 [==============================] - 74s - loss: 0.0253 - acc: 0.9956 - val_loss: 0.1482 - val_acc: 0.9693
# Epoch 743/2000
# Epoch 00742: val_loss did not improve
# 30/30 [==============================] - 75s - loss: 0.0171 - acc: 0.9984 - val_loss: 0.1452 - val_acc: 0.9693
# Epoch 744/2000
# Epoch 00743: val_loss did not improve
# 30/30 [==============================] - 73s - loss: 0.0186 - acc: 0.9977 - val_loss: 0.1424 - val_acc: 0.9669
# Epoch 745/2000
# Epoch 00744: val_loss did not improve
# 30/30 [==============================] - 75s - loss: 0.0210 - acc: 0.9966 - val_loss: 0.1410 - val_acc: 0.9669
# Epoch 746/2000
# Epoch 00745: val_loss did not improve
# 30/30 [==============================] - 75s - loss: 0.0162 - acc: 0.9971 - val_loss: 0.1472 - val_acc: 0.9669
# Epoch 747/2000
# Epoch 00746: val_loss did not improve
# 30/30 [==============================] - 73s - loss: 0.0199 - acc: 0.9981 - val_loss: 0.1424 - val_acc: 0.9669
# Epoch 748/2000
# Epoch 00747: val_loss improved from 0.13553 to 0.13336, saving model to ./checkpoint/weights.747-0.1334.hdf5
# 30/30 [==============================] - 109s - loss: 0.0166 - acc: 0.9971 - val_loss: 0.1334 - val_acc: 0.9716
# Epoch 749/2000
# Epoch 00748: val_loss did not improve
# 30/30 [==============================] - 74s - loss: 0.0238 - acc: 0.9969 - val_loss: 0.1351 - val_acc: 0.9693
# Epoch 750/2000
# Epoch 00749: val_loss did not improve
# 30/30 [==============================] - 73s - loss: 0.0173 - acc: 0.9973 - val_loss: 0.1350 - val_acc: 0.9716
# Epoch 751/2000
# Epoch 00750: val_loss improved from 0.13336 to 0.13187, saving model to ./checkpoint/weights.750-0.1319.hdf5
# 30/30 [==============================] - 76s - loss: 0.0157 - acc: 0.9984 - val_loss: 0.1319 - val_acc: 0.9693
# Epoch 752/2000
# Epoch 00751: val_loss improved from 0.13187 to 0.13141, saving model to ./checkpoint/weights.751-0.1314.hdf5
# 30/30 [==============================] - 75s - loss: 0.0135 - acc: 0.9982 - val_loss: 0.1314 - val_acc: 0.9669
# Epoch 753/2000
# Epoch 00752: val_loss did not improve
# 30/30 [==============================] - 73s - loss: 0.0181 - acc: 0.9973 - val_loss: 0.1354 - val_acc: 0.9740
# Epoch 754/2000
# Epoch 00753: val_loss did not improve
# 30/30 [==============================] - 75s - loss: 0.0184 - acc: 0.9984 - val_loss: 0.1326 - val_acc: 0.9716
# Epoch 755/2000
# Epoch 00754: val_loss did not improve
# 30/30 [==============================] - 75s - loss: 0.0213 - acc: 0.9969 - val_loss: 0.1540 - val_acc: 0.9622
# Epoch 756/2000
# Epoch 00755: val_loss did not improve
# 30/30 [==============================] - 74s - loss: 0.0265 - acc: 0.9969 - val_loss: 0.1453 - val_acc: 0.9716
# Epoch 757/2000
# Epoch 00756: val_loss did not improve
# 30/30 [==============================] - 74s - loss: 0.0124 - acc: 0.9992 - val_loss: 0.1441 - val_acc: 0.9716
# Epoch 758/2000
# Epoch 00757: val_loss did not improve
# 30/30 [==============================] - 75s - loss: 0.0139 - acc: 0.9979 - val_loss: 0.1407 - val_acc: 0.9740
# Epoch 759/2000
# Epoch 00758: val_loss improved from 0.13141 to 0.12926, saving model to ./checkpoint/weights.758-0.1293.hdf5
# 30/30 [==============================] - 75s - loss: 0.0167 - acc: 0.9984 - val_loss: 0.1293 - val_acc: 0.9764
# Epoch 760/2000
# Epoch 00759: val_loss improved from 0.12926 to 0.12309, saving model to ./checkpoint/weights.759-0.1231.hdf5
# 30/30 [==============================] - 74s - loss: 0.0141 - acc: 0.9974 - val_loss: 0.1231 - val_acc: 0.9693
# Epoch 761/2000
# Epoch 00760: val_loss did not improve
# 30/30 [==============================] - 74s - loss: 0.0189 - acc: 0.9974 - val_loss: 0.1259 - val_acc: 0.9693
# Epoch 762/2000
# Epoch 00761: val_loss did not improve
# 30/30 [==============================] - 75s - loss: 0.0201 - acc: 0.9971 - val_loss: 0.1267 - val_acc: 0.9716
# Epoch 763/2000
# Epoch 00762: val_loss did not improve
# 30/30 [==============================] - 73s - loss: 0.0184 - acc: 0.9963 - val_loss: 0.1345 - val_acc: 0.9693
# Epoch 764/2000
# Epoch 00763: val_loss did not improve
# 30/30 [==============================] - 75s - loss: 0.0133 - acc: 0.9979 - val_loss: 0.1387 - val_acc: 0.9669
# Epoch 765/2000
# Epoch 00764: val_loss did not improve
# 30/30 [==============================] - 75s - loss: 0.0152 - acc: 0.9977 - val_loss: 0.1298 - val_acc: 0.9645
# Epoch 766/2000
# Epoch 00765: val_loss did not improve
# 30/30 [==============================] - 74s - loss: 0.0234 - acc: 0.9978 - val_loss: 0.1306 - val_acc: 0.9669
# Epoch 767/2000
# Epoch 00766: val_loss did not improve
# 30/30 [==============================] - 75s - loss: 0.0173 - acc: 0.9979 - val_loss: 0.1305 - val_acc: 0.9716
# Epoch 768/2000
# Epoch 00767: val_loss did not improve
# 30/30 [==============================] - 75s - loss: 0.0121 - acc: 0.9987 - val_loss: 0.1318 - val_acc: 0.9716
# Epoch 769/2000
# Epoch 00768: val_loss did not improve
# 30/30 [==============================] - 73s - loss: 0.0115 - acc: 0.9995 - val_loss: 0.1383 - val_acc: 0.9669
# Epoch 770/2000
# Epoch 00769: val_loss did not improve
# 30/30 [==============================] - 75s - loss: 0.0108 - acc: 0.9982 - val_loss: 0.1343 - val_acc: 0.9669
# Epoch 771/2000
# Epoch 00771: val_loss did not improve
# 30/30 [==============================] - 73s - loss: 0.0108 - acc: 0.9992 - val_loss: 0.1302 - val_acc: 0.9716
# Epoch 773/2000
# Epoch 00772: val_loss did not improve
# 30/30 [==============================] - 75s - loss: 0.0130 - acc: 0.9990 - val_loss: 0.1286 - val_acc: 0.9716
# Epoch 774/2000
# Epoch 00773: val_loss did not improve
# 30/30 [==============================] - 74s - loss: 0.0168 - acc: 0.9987 - val_loss: 0.1276 - val_acc: 0.9716
# Epoch 775/2000
# Epoch 00774: val_loss did not improve
# 30/30 [==============================] - 74s - loss: 0.0134 - acc: 0.9981 - val_loss: 0.1274 - val_acc: 0.9740
# Epoch 776/2000
# Epoch 00775: val_loss did not improve
# 30/30 [==============================] - 74s - loss: 0.0121 - acc: 0.9992 - val_loss: 0.1273 - val_acc: 0.9716
# Epoch 777/2000
# Epoch 00776: val_loss did not improve
# 30/30 [==============================] - 74s - loss: 0.0185 - acc: 0.9982 - val_loss: 0.1255 - val_acc: 0.9740
# Epoch 778/2000
# Epoch 00777: val_loss did not improve
# 30/30 [==============================] - 74s - loss: 0.0112 - acc: 0.9989 - val_loss: 0.1243 - val_acc: 0.9740
# Epoch 779/2000
# Epoch 00778: val_loss did not improve
# 30/30 [==============================] - 74s - loss: 0.0145 - acc: 0.9987 - val_loss: 0.1244 - val_acc: 0.9764
# Epoch 780/2000
# Epoch 00779: val_loss did not improve
# 30/30 [==============================] - 74s - loss: 0.0114 - acc: 0.9984 - val_loss: 0.1239 - val_acc: 0.9764
# Epoch 781/2000
# Epoch 00780: val_loss did not improve
#
# Epoch 00780: reducing learning rate to 9.99999997475e-08.
# 30/30 [==============================] - 73s - loss: 0.0119 - acc: 0.9984 - val_loss: 0.1236 - val_acc: 0.9740
# Epoch 782/2000
# Epoch 00781: val_loss did not improve
# 30/30 [==============================] - 75s - loss: 0.0157 - acc: 0.9984 - val_loss: 0.1242 - val_acc: 0.9740
# Epoch 783/2000
# Epoch 00782: val_loss did not improve
# 30/30 [==============================] - 75s - loss: 0.0135 - acc: 0.9990 - val_loss: 0.1234 - val_acc: 0.9787
# Epoch 784/2000
# Epoch 00783: val_loss did not improve
# 30/30 [==============================] - 73s - loss: 0.0126 - acc: 0.9976 - val_loss: 0.1235 - val_acc: 0.9787
# Epoch 785/2000
# Epoch 00784: val_loss did not improve
# 30/30 [==============================] - 75s - loss: 0.0092 - acc: 0.9995 - val_loss: 0.1236 - val_acc: 0.9787
# Epoch 786/2000
# Epoch 00785: val_loss did not improve
# 30/30 [==============================] - 74s - loss: 0.0121 - acc: 0.9984 - val_loss: 0.1237 - val_acc: 0.9764
# Epoch 00785: early stopping

# %%
### Resnet50
# fine tuning stg5
# 164 conv5c+top
# 154 conv5b+conv5c+top
# 142 conv5+top i.e. conv5a+conv5b+conv5c+top
# 132 conv4f+conv5+top
# 122 conv4e+conv4f+conv5+top
# 80 conv4+conv5+top
# 38 conv3+conv4+conv5+top
# 6 conv2+conv3+conv4+conv5+top
# 2 conv1+conv2+conv3+conv4+conv5+top i.e. FROM SCRATCH
start_layer = 38

model, model_name = get_best_model()
# model = load_model(CHECKPOINT_DIR + 'weights.539-0.3229.hdf5')
# model_name = 'weights.539-0.3229.hdf5'
# print('model_name', model_name)

for layer in model.layers[:start_layer]:
   layer.trainable = False
for layer in model.layers[start_layer:]:
   layer.trainable = True

# we need to recompile the model for these modifications to take effect
# we use SGD with a low learning rate
optimizer = Adam(lr=1e-5)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

print('BATCHSIZE', BATCHSIZE)
model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=2000, verbose=1, 
                    callbacks=[early_stopping, model_checkpoint, learningrate_schedule, tensorboard], 
                    validation_data=(X_valid_centered, y_valid), 
                    class_weight=class_weight, workers=3, pickle_safe=True, initial_epoch=760)

# %%
#resume training

model, model_name = get_best_model()
# print('Loading model from weights.004-0.0565.hdf5')
# model = load_model(CHECKPOINT_DIR + 'weights.011-1.7062.hdf5')

# optimizer = Adam(lr=1e-4)
# model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=2000, verbose=1, 
                    callbacks=[early_stopping, model_checkpoint, learningrate_schedule, tensorboard], 
                    validation_data=(X_valid_centered,y_valid),
                    class_weight=class_weight, workers=3, pickle_safe=True, initial_epoch=350)

# %%
for i, layer in enumerate(model.layers):
    print(i,layer.name)
# Out:
# 0 input_1
# 1 zero_padding2d_1
# 2 conv1
# 3 bn_conv1
# 4 activation_1
# 5 max_pooling2d_1
# 6 res2a_branch2a
# 7 bn2a_branch2a
# 8 activation_2
# 9 res2a_branch2b
# 10 bn2a_branch2b
# 11 activation_3
# 12 res2a_branch2c
# 13 res2a_branch1
# 14 bn2a_branch2c
# 15 bn2a_branch1
# 16 add_1
# 17 activation_4
# 18 res2b_branch2a
# 19 bn2b_branch2a
# 20 activation_5
# 21 res2b_branch2b
# 22 bn2b_branch2b
# 23 activation_6
# 24 res2b_branch2c
# 25 bn2b_branch2c
# 26 add_2
# 27 activation_7
# 28 res2c_branch2a
# 29 bn2c_branch2a
# 30 activation_8
# 31 res2c_branch2b
# 32 bn2c_branch2b
# 33 activation_9
# 34 res2c_branch2c
# 35 bn2c_branch2c
# 36 add_3
# 37 activation_10
# 38 res3a_branch2a
# 39 bn3a_branch2a
# 40 activation_11
# 41 res3a_branch2b
# 42 bn3a_branch2b
# 43 activation_12
# 44 res3a_branch2c
# 45 res3a_branch1
# 46 bn3a_branch2c
# 47 bn3a_branch1
# 48 add_4
# 49 activation_13
# 50 res3b_branch2a
# 51 bn3b_branch2a
# 52 activation_14
# 53 res3b_branch2b
# 54 bn3b_branch2b
# 55 activation_15
# 56 res3b_branch2c
# 57 bn3b_branch2c
# 58 add_5
# 59 activation_16
# 60 res3c_branch2a
# 61 bn3c_branch2a
# 62 activation_17
# 63 res3c_branch2b
# 64 bn3c_branch2b
# 65 activation_18
# 66 res3c_branch2c
# 67 bn3c_branch2c
# 68 add_6
# 69 activation_19
# 70 res3d_branch2a
# 71 bn3d_branch2a
# 72 activation_20
# 73 res3d_branch2b
# 74 bn3d_branch2b
# 75 activation_21
# 76 res3d_branch2c
# 77 bn3d_branch2c
# 78 add_7
# 79 activation_22
# 80 res4a_branch2a
# 81 bn4a_branch2a
# 82 activation_23
# 83 res4a_branch2b
# 84 bn4a_branch2b
# 85 activation_24
# 86 res4a_branch2c
# 87 res4a_branch1
# 88 bn4a_branch2c
# 89 bn4a_branch1
# 90 add_8
# 91 activation_25
# 92 res4b_branch2a
# 93 bn4b_branch2a
# 94 activation_26
# 95 res4b_branch2b
# 96 bn4b_branch2b
# 97 activation_27
# 98 res4b_branch2c
# 99 bn4b_branch2c
# 100 add_9
# 101 activation_28
# 102 res4c_branch2a
# 103 bn4c_branch2a
# 104 activation_29
# 105 res4c_branch2b
# 106 bn4c_branch2b
# 107 activation_30
# 108 res4c_branch2c
# 109 bn4c_branch2c
# 110 add_10
# 111 activation_31
# 112 res4d_branch2a
# 113 bn4d_branch2a
# 114 activation_32
# 115 res4d_branch2b
# 116 bn4d_branch2b
# 117 activation_33
# 118 res4d_branch2c
# 119 bn4d_branch2c
# 120 add_11
# 121 activation_34
# 122 res4e_branch2a
# 123 bn4e_branch2a
# 124 activation_35
# 125 res4e_branch2b
# 126 bn4e_branch2b
# 127 activation_36
# 128 res4e_branch2c
# 129 bn4e_branch2c
# 130 add_12
# 131 activation_37
# 132 res4f_branch2a
# 133 bn4f_branch2a
# 134 activation_38
# 135 res4f_branch2b
# 136 bn4f_branch2b
# 137 activation_39
# 138 res4f_branch2c
# 139 bn4f_branch2c
# 140 add_13
# 141 activation_40
# 142 res5a_branch2a
# 143 bn5a_branch2a
# 144 activation_41
# 145 res5a_branch2b
# 146 bn5a_branch2b
# 147 activation_42
# 148 res5a_branch2c
# 149 res5a_branch1
# 150 bn5a_branch2c
# 151 bn5a_branch1
# 152 add_14
# 153 activation_43
# 154 res5b_branch2a
# 155 bn5b_branch2a
# 156 activation_44
# 157 res5b_branch2b
# 158 bn5b_branch2b
# 159 activation_45
# 160 res5b_branch2c
# 161 bn5b_branch2c
# 162 add_15
# 163 activation_46
# 164 res5c_branch2a
# 165 bn5c_branch2a
# 166 activation_47
# 167 res5c_branch2b
# 168 bn5c_branch2b
# 169 activation_48
# 170 res5c_branch2c
# 171 bn5c_branch2c
# 172 add_16
# 173 activation_49
# 174 avg_pool
# 175 global_average_pooling2d_1
# 176 dense_1

# %%
#test prepare

test_model, test_model_name = get_best_model()
# print('Loading model from weights.004-0.0565.hdf5')
# test_model = load_model('./checkpoints/checkpoint2/weights.004-0.0565.hdf5')

def test_generator(df, mean, datagen = None, batch_size = BATCHSIZE):
    n = df.shape[0]
    batch_index = 0
    while 1:
        current_index = batch_index * batch_size
        if n >= current_index + batch_size:
            current_batch_size = batch_size
            batch_index += 1    
        else:
            current_batch_size = n - current_index
            batch_index = 0        
        batch_df = df[current_index:current_index+current_batch_size]
        batch_x = np.zeros((batch_df.shape[0], ROWS, COLS, 3), dtype=K.floatx())
        i = 0
        for index,row in batch_df.iterrows():
            image_file = row['image_file']
            bbox = [row['xmin'],row['ymin'],row['xmax'],row['ymax']]
            cropped = load_img(TEST_DIR+image_file,bbox,target_size=(ROWS,COLS))
            x = np.asarray(cropped, dtype=K.floatx())
            x /= 255.
            if datagen is not None: x = datagen.random_transform(x)            
            x = preprocess_featurewise(x, mean)
            batch_x[i] = x
            i += 1
        if batch_index%50 == 0: print('batch_index', batch_index)
        yield(batch_x)
        
test_aug_datagen = ImageDataGenerator(
    rotation_range=180,
    shear_range=0.2,
    zoom_range=0.1,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    vertical_flip=True)
# Out:
# Loading model from checkpoint file ./checkpoint/weights.316-0.1940.hdf5
# Loading model Done!

# %%
# train_mean = [0.37698776,  0.41491762,  0.38681713]
all_mean = featurewise_mean(X_all)
print('all_mean:', all_mean)
# Out:
# all_mean: [ 0.40696082  0.43766695  0.3947188 ]

# %%
#GTbbox_CROPpred_df = ['image_file','crop_index','crop_class','xmin','ymin','xmax','ymax','split'
#                      'ALB', 'BET', 'DOL', 'LAG', 'OTHER', 'SHARK', 'YFT', 'logloss']

file_name = 'GTbbox_CROPpred_df_'+test_model_name+'_.pickle'
if os.path.exists(OUTPUT_DIR+file_name):
    print ('Loading from file '+file_name)
    GTbbox_CROPpred_df = pd.read_pickle(OUTPUT_DIR+file_name)
else:
    print ('Generating file '+file_name) 
    nb_augmentation = 1
    if nb_augmentation ==1:
        test_preds = test_model.predict_generator(test_generator(df=GTbbox_df, mean=all_mean), 
                                                  steps=int(math.ceil(GTbbox_df.shape[0]/BATCHSIZE)), workers=1, pickle_safe=False)
    else:
        test_preds = np.zeros((GTbbox_df.shape[0], len(FISH_CLASSES)), dtype=K.floatx())
        for idx in range(nb_augmentation):
            print('{}th augmentation for testing ...'.format(idx+1))
            test_preds += test_model.predict_generator(test_generator(df=GTbbox_df, mean=all_mean, datagen=test_aug_datagen), 
                                                       steps=int(math.ceil(GTbbox_df.shape[0]/BATCHSIZE)), workers=1, pickle_safe=False)
        test_preds /= nb_augmentation

    CROPpred_df = pd.DataFrame(test_preds, columns=['ALB', 'BET', 'DOL', 'LAG', 'OTHER', 'SHARK', 'YFT'])
    GTbbox_CROPpred_df = pd.concat([GTbbox_df,CROPpred_df], axis=1)
    GTbbox_CROPpred_df['logloss'] = GTbbox_CROPpred_df.apply(lambda row: -math.log(row[row['crop_class']]), axis=1)
    GTbbox_CROPpred_df.to_pickle(OUTPUT_DIR+file_name) 

crop_valid_loss = GTbbox_CROPpred_df.loc[GTbbox_CROPpred_df['split']=='valid', 'logloss'].mean()
print('crop_valid_loss:', crop_valid_loss)
crop_all_loss = GTbbox_CROPpred_df['logloss'].mean()
print('crop_all_loss:', crop_all_loss)
# Out:
# Generating file GTbbox_CROPpred_df_weights.316-0.1940.hdf5_.pickle
# batch_index 0
# crop_valid_loss: 0.193993760436
# crop_all_loss: 0.054481258386

# %%
print('all crop loss:', GTbbox_CROPpred_df['logloss'].mean())
print(GTbbox_CROPpred_df.groupby(['crop_class'])['logloss'].mean())

train_CROPpred_df = GTbbox_CROPpred_df[GTbbox_CROPpred_df['split']=='train']
print('train crop loss:', train_CROPpred_df['logloss'].mean())
print(train_CROPpred_df.groupby(['crop_class'])['logloss'].mean())

valid_CROPpred_df = GTbbox_CROPpred_df[GTbbox_CROPpred_df['split']=='valid']
print('valid crop loss:', valid_CROPpred_df['logloss'].mean())
print(valid_CROPpred_df.groupby(['crop_class'])['logloss'].mean())
# Out:
# all crop loss: 0.054481258386
# crop_class
# ALB      0.068493
# BET      0.047069
# DOL      0.000758
# LAG      0.000098
# OTHER    0.012689
# SHARK    0.000090
# YFT      0.059154
# Name: logloss, dtype: float64
# train crop loss: 0.0395334903092
# crop_class
# ALB      0.060490
# BET      0.003700
# DOL      0.000741
# LAG      0.000056
# OTHER    0.001819
# SHARK    0.000082
# YFT      0.023868
# Name: logloss, dtype: float64
# valid crop loss: 0.193993760436
# crop_class
# ALB      0.142912
# BET      0.514118
# DOL      0.000915
# LAG      0.000449
# OTHER    0.118579
# SHARK    0.000159
# YFT      0.371939
# Name: logloss, dtype: float64

# %%
# RFCNbbox_RFCNpred_df = ['image_class','image_file','crop_index','xmin','ymin','xmax','ymax',
#                          'NoF_RFCN', 'ALB_RFCN', 'BET_RFCN', 'DOL_RFCN',
#                          'LAG_RFCN', 'OTHER_RFCN', 'SHARK_RFCN', 'YFT_RFCN']
# select fish_conf >= CONF_THRESH

file_name = 'RFCNbbox_RFCNpred_df_conf{:.2f}.pickle'.format(CONF_THRESH)
if os.path.exists(OUTPUT_DIR+file_name):
    print ('Loading from file '+file_name)
    RFCNbbox_RFCNpred_df = pd.read_pickle(OUTPUT_DIR+file_name)
else:
    print ('Generating file '+file_name)        
    RFCNbbox_RFCNpred_df = pd.DataFrame(columns=['image_class','image_file','crop_index','xmin','ymin','xmax','ymax',
                                                  'NoF_RFCN', 'ALB_RFCN', 'BET_RFCN', 'DOL_RFCN',
                                                  'LAG_RFCN', 'OTHER_RFCN', 'SHARK_RFCN', 'YFT_RFCN']) 

    with open('../data/RFCN_detections/detections_full_AGNOSTICnms_'+RFCN_MODEL+'.pkl','rb') as f:
        detections_full_AGNOSTICnms = pickle.load(f) 
    with open("../RFCN/ImageSets/Main/test.txt","r") as f:
        test_files = f.readlines()
    with open("../RFCN/ImageSets/Main/train_test.txt","r") as f:
        train_file_labels = f.readlines()
    assert len(detections_full_AGNOSTICnms) == len(test_files)
    
    count = np.zeros(len(detections_full_AGNOSTICnms))
    
    for im in range(len(detections_full_AGNOSTICnms)):
        if im%1000 == 0: print(im)
        basename = test_files[im][:9]
        if im<1000:
            image_class = '--'
        else:
            for i in range(len(train_file_labels)):
                if train_file_labels[i][:9] == basename:
                    image_class = train_file_labels[i][10:-1]
                    break
        image = Image.open(TEST_DIR+'/'+basename+'.jpg')
        width_image, height_image = image.size
        
        bboxes = []
        detects_im = detections_full_AGNOSTICnms[im]
        for i in range(len(detects_im)):
            if np.sum(detects_im[i,5:]) >= CONF_THRESH:
                bboxes.append(detects_im[i,:]) 
        count[im] = len(bboxes)
        if len(bboxes) == 0:
            ind = np.argmax(np.sum(detects_im[:,5:], axis=1))
            bboxes.append(detects_im[ind,:])
        bboxes = np.asarray(bboxes)

        for j in range(len(bboxes)):    
            bbox = bboxes[j]
            xmin = bbox[0]
            ymin = bbox[1]
            xmax = bbox[2]
            ymax = bbox[3]
            assert max(xmin,0)<min(xmax,width_image)
            assert max(ymin,0)<min(ymax,height_image)
            RFCNbbox_RFCNpred_df.loc[len(RFCNbbox_RFCNpred_df)]=[image_class,basename+'.jpg',j,max(xmin,0),max(ymin,0),
                                                                   min(xmax,width_image),min(ymax,height_image),
                                                                   bbox[4],bbox[5],bbox[6],bbox[7],bbox[8],bbox[9],bbox[10],bbox[11]]   
    
    RFCNbbox_RFCNpred_df.to_pickle(OUTPUT_DIR+file_name)
# Out:
# Generating file RFCNbbox_RFCNpred_df_conf0.80.pickle
# 0
# 1000
# 2000
# 3000
# 4000

# %%
# RFCNbbox_RFCNpred_CROPpred_HYBRIDpred_df = ['image_class', 'image_file','crop_index','xmin','ymin','xmax','ymax',
#                                    'NoF_RFCN', 'ALB_RFCN', 'BET_RFCN', 'DOL_RFCN',
#                                    'LAG_RFCN', 'OTHER_RFCN', 'SHARK_RFCN', 'YFT_RFCN',
#                                    'ALB_CROP', 'BET_CROP', 'DOL_CROP',
#                                    'LAG_CROP', 'OTHER_CROP', 'SHARK_CROP', 'YFT_CROP',
#                                    'NoF', 'ALB', 'BET', 'DOL', 'LAG', 'OTHER', 'SHARK', 'YFT']

file_name = 'RFCNbbox_RFCNpred_CROPpred_HYBRIDpred_df_'+test_model_name+'_.pickle'
if os.path.exists(OUTPUT_DIR+file_name):
    print ('Loading from file '+file_name)
    RFCNbbox_RFCNpred_CROPpred_HYBRIDpred_df = pd.read_pickle(OUTPUT_DIR+file_name)
else:
    print ('Generating file '+file_name)  
    nb_augmentation = 1
    if nb_augmentation ==1:
        test_preds = test_model.predict_generator(test_generator(df=RFCNbbox_RFCNpred_df, mean=all_mean), 
                                                  steps=int(math.ceil(RFCNbbox_RFCNpred_df.shape[0]/BATCHSIZE)), workers=1, pickle_safe=False)
    else:
        test_preds = np.zeros((RFCNbbox_RFCNpred_df.shape[0], len(CROP_CLASSES)), dtype=K.floatx())
        for idx in range(nb_augmentation):
            print('{}th augmentation for testing ...'.format(idx+1))
            test_preds += test_model.predict_generator(test_generator(df=RFCNbbox_RFCNpred_df, mean=all_mean, datagen=test_aug_datagen), 
                                                       steps=int(math.ceil(RFCNbbox_RFCNpred_df.shape[0]/BATCHSIZE)), workers=1, pickle_safe=False)
        test_preds /= nb_augmentation

    CROPpred_df = pd.DataFrame(test_preds, columns=['ALB_CROP', 'BET_CROP', 'DOL_CROP', 'LAG_CROP', 'OTHER_CROP', 'SHARK_CROP', 'YFT_CROP'])
    RFCNbbox_RFCNpred_CROPpred_HYBRIDpred_df = pd.concat([RFCNbbox_RFCNpred_df,CROPpred_df], axis=1)
    
    RFCNbbox_RFCNpred_CROPpred_HYBRIDpred_df['NoF'] = RFCNbbox_RFCNpred_CROPpred_HYBRIDpred_df['NoF_RFCN']
    for fish in ['ALB', 'BET', 'DOL', 'LAG', 'OTHER', 'SHARK', 'YFT']:
        RFCNbbox_RFCNpred_CROPpred_HYBRIDpred_df[fish] = RFCNbbox_RFCNpred_CROPpred_HYBRIDpred_df.apply(lambda row: (1-row['NoF_RFCN'])*row[[fish+'_CROP']], axis=1)

    RFCNbbox_RFCNpred_CROPpred_HYBRIDpred_df.to_pickle(OUTPUT_DIR+file_name)
# Out:
# Generating file RFCNbbox_RFCNpred_CROPpred_HYBRIDpred_df_weights.316-0.1940.hdf5_.pickle
# batch_index 0

# %%
# clsMaxAve and hybrid RFCNpred&CROPpred such that RFCNpred for NoF and CROPpred for fish
# test_pred_df = ['logloss','image_class','image_file','NoF', 'ALB', 'BET', 'DOL', 'LAG', 'OTHER', 'SHARK', 'YFT', 'split']
# RFCNbbox_RFCNpred_CROPpred_HYBRIDpred_df = ['image_class', 'image_file','crop_index','xmin','ymin','xmax','ymax',
#                                    'NoF_RFCN', 'ALB_RFCN', 'BET_RFCN', 'DOL_RFCN',
#                                    'LAG_RFCN', 'OTHER_RFCN', 'SHARK_RFCN', 'YFT_RFCN',
#                                    'ALB_CROP', 'BET_CROP', 'DOL_CROP',
#                                    'LAG_CROP', 'OTHER_CROP', 'SHARK_CROP', 'YFT_CROP',
#                                    'NoF', 'ALB', 'BET', 'DOL', 'LAG', 'OTHER', 'SHARK', 'YFT']

file_name = 'test_pred_df_Hybrid_'+test_model_name+'_.pickle'
if os.path.exists(OUTPUT_DIR+file_name):
    print ('Loading from file '+file_name)
    test_pred_df = pd.read_pickle(OUTPUT_DIR+file_name)
else:
    print ('Generating file '+file_name)  
    with open("../RFCN/ImageSets/Main/test.txt","r") as f:
        test_files = f.readlines()
    
    test_pred_df = pd.DataFrame(columns=['logloss','image_class','image_file','NoF', 'ALB', 'BET', 'DOL', 'LAG', 'OTHER', 'SHARK', 'YFT'])  
    for j in range(len(test_files)): 
        image_file = test_files[j][:-1]+'.jpg'
        test_pred_im_df = RFCNbbox_RFCNpred_CROPpred_HYBRIDpred_df.loc[RFCNbbox_RFCNpred_CROPpred_HYBRIDpred_df['image_file'] == image_file,
                                                                       ['image_class', 'NoF', 'ALB', 'BET', 'DOL', 'LAG', 'OTHER', 'SHARK', 'YFT']]
        image_class = test_pred_im_df.iloc[0]['image_class']
        test_pred_im_df.drop('image_class', axis=1, inplace=True)
        max_score = test_pred_im_df.max(axis=1)
        max_cls = test_pred_im_df.idxmax(axis=1)
        test_pred_im_df['max_score'] = max_score
        test_pred_im_df['max_cls'] = max_cls
        test_pred_im_df['Count'] = test_pred_im_df.groupby(['max_cls'])['max_cls'].transform('count')
        idx = test_pred_im_df.groupby(['max_cls'])['max_score'].transform(max) == test_pred_im_df['max_score']
        test_pred_im_clsMax_df = test_pred_im_df.loc[idx,['NoF', 'ALB', 'BET', 'DOL', 'LAG', 'OTHER', 'SHARK', 'YFT', 'Count']]
        test_pred_im_clsMax_array = test_pred_im_clsMax_df.values
        pred = np.average(test_pred_im_clsMax_array[:,:-1], axis=0, weights=test_pred_im_clsMax_array[:,-1], returned=False).tolist()
        if image_class!='--':
            ind = FISH_CLASSES.index(image_class)
            logloss = -math.log(pred[ind]) 
        else:
            logloss = np.nan
        test_pred_im_clsMaxAve = [logloss,image_class,image_file]
        test_pred_im_clsMaxAve.extend(pred)
        test_pred_df.loc[len(test_pred_df)]=test_pred_im_clsMaxAve
    
    image_split_df = GTbbox_df[['image_file','split']]
    image_split_df.drop_duplicates(inplace = True)
    test_pred_df = pd.merge(test_pred_df, image_split_df, how='outer', on='image_file')

    test_pred_df.to_pickle(OUTPUT_DIR+file_name) 

image_valid_loss = test_pred_df.loc[(test_pred_df['image_class']!='--') & (test_pred_df['split']=='valid'), 'logloss'].mean()
print('image_valid_loss:', image_valid_loss)
image_all_loss = test_pred_df.loc[test_pred_df['image_class']!='--', 'logloss'].mean()
print('image_all_loss:', image_all_loss)
# Out:
# Generating file test_pred_df_Hybrid_weights.316-0.1940.hdf5_.pickle
# image_valid_loss: 0.176932356387
# image_all_loss: 0.0717103426776

# %%
all_IMAGEpred_df = test_pred_df[test_pred_df['image_class']!='--']
print('all image loss:', all_IMAGEpred_df['logloss'].mean())
print(all_IMAGEpred_df.groupby(['image_class'])['logloss'].mean())

train_IMAGEpred_df = all_IMAGEpred_df[all_IMAGEpred_df['split']=='train']
print('train image loss:', train_IMAGEpred_df['logloss'].mean())
print(train_IMAGEpred_df.groupby(['image_class'])['logloss'].mean())

valid_IMAGEpred_df = all_IMAGEpred_df[all_IMAGEpred_df['split']=='valid']
print('valid image loss:', valid_IMAGEpred_df['logloss'].mean())
print(valid_IMAGEpred_df.groupby(['image_class'])['logloss'].mean())
# Out:
# all image loss: 0.0717103426776
# image_class
# ALB      0.079827
# BET      0.058833
# DOL      0.008619
# LAG      0.000772
# NoF      0.126442
# OTHER    0.015035
# SHARK    0.106109
# YFT      0.052908
# Name: logloss, dtype: float64
# train image loss: 0.0449345139463
# image_class
# ALB      0.060760
# BET      0.006116
# DOL      0.009431
# LAG      0.000753
# OTHER    0.003747
# SHARK    0.117218
# YFT      0.027541
# Name: logloss, dtype: float64
# valid image loss: 0.176932356387
# image_class
# ALB      0.137899
# BET      0.533292
# DOL      0.001516
# LAG      0.000930
# OTHER    0.116252
# SHARK    0.002207
# YFT      0.282609
# Name: logloss, dtype: float64

# %%
#### visualization
# RFCNbbox_RFCNpred_CROPpred_df = ['image_class', 'image_file','crop_index','x_min','y_min','x_max','ymax',
#                                    'NoF_RFCN', 'ALB_RFCN', 'BET_RFCN', 'DOL_RFCN',
#                                    'LAG_RFCN', 'OTHER_RFCN', 'SHARK_RFCN', 'YFT_RFCN'
#                                    'NoF_CROP', 'ALB_CROP', 'BET_CROP', 'DOL_CROP',
#                                    'LAG_CROP', 'OTHER_CROP', 'SHARK_CROP', 'YFT_CROP']
#GTbbox_CROPpred_df = ['image_file','crop_index','crop_class','xmin','ymin','xmax','ymax',
#                      'NoF', 'ALB', 'BET', 'DOL', 'LAG', 'OTHER', 'SHARK', 'YFT', 'logloss']
# test_pred_df = ['logloss','image_class','image_file','NoF', 'ALB', 'BET', 'DOL', 'LAG', 'OTHER', 'SHARK', 'YFT']

for j in range(test_pred_df.shape[0]):
    image_logloss = test_pred_df.iat[j,0]
    image_class = test_pred_df.iat[j,1]
    image_file = test_pred_df.iat[j,2]
    if j<1000 and j%30== 0:
        pass
    else: 
        continue
    im = Image.open('../RFCN/JPEGImages/'+image_file)
    im = np.asarray(im)
    fig, ax = plt.subplots(figsize=(10, 8))
    ax.imshow(im, aspect='equal')
    RFCN_dets = RFCNbbox_RFCNpred_CROPpred_HYBRIDpred_df.loc[RFCNbbox_RFCNpred_CROPpred_HYBRIDpred_df['image_file']==image_file]
    for index,row in RFCN_dets.iterrows():
        bbox = [row['xmin'],row['ymin'],row['xmax'],row['ymax']]
        RFCN = [row['NoF_RFCN'],row['ALB_RFCN'],row['BET_RFCN'],row['DOL_RFCN'],row['LAG_RFCN'],row['OTHER_RFCN'],row['SHARK_RFCN'],row['YFT_RFCN']]
        CROP = [row['NoF'],row['ALB'],row['BET'],row['DOL'],row['LAG'],row['OTHER'],row['SHARK'],row['YFT']]
        score_RFCN = max(RFCN)
        score_CROP = max(CROP)
        index_RFCN = RFCN.index(score_RFCN)
        index_CROP = CROP.index(score_CROP)
        class_RFCN = FISH_CLASSES[index_RFCN]
        class_CROP = FISH_CLASSES[index_CROP]
        ax.add_patch(plt.Rectangle((bbox[0], bbox[1]), bbox[2] - bbox[0], bbox[3] - bbox[1], fill=False, edgecolor='red', linewidth=2))
        ax.text(bbox[0], bbox[1] - 2, 'RFCN_{:s} {:.3f} \nHYBRID_{:s} {:.3f}'.format(class_RFCN, score_RFCN, class_CROP, score_CROP), bbox=dict(facecolor='red', alpha=0.5), fontsize=8, color='white')       
    GT_dets = GTbbox_CROPpred_df.loc[GTbbox_CROPpred_df['image_file']==image_file]
    for index,row in GT_dets.iterrows():
        bbox = [row['xmin'],row['ymin'],row['xmax'],row['ymax']]
        CROP = [row['NoF'],row['ALB'],row['BET'],row['DOL'],row['LAG'],row['OTHER'],row['SHARK'],row['YFT']]
        score_CROP = max(CROP)
        index_CROP = CROP.index(score_CROP)
        class_CROP = FISH_CLASSES[index_CROP]
        ax.add_patch(plt.Rectangle((bbox[0], bbox[1]), bbox[2] - bbox[0], bbox[3] - bbox[1], fill=False, edgecolor='green', linewidth=2))
        ax.text(bbox[0], bbox[3] + 40, 'GT_{:s} \nCROP_{:s} {:.3f}'.format(row['crop_class'], class_CROP, score_CROP), bbox=dict(facecolor='green', alpha=0.5), fontsize=8, color='white')
    ax.set_title(('Image {:s}    FISH {:s}    logloss {}').format(image_file, image_class, image_logloss), fontsize=10) 
    plt.axis('off')
    plt.tight_layout()
    plt.draw()

# %%
#temperature
T = 2.5
test_pred_array = test_pred_df[FISH_CLASSES].values
test_pred_T_array = np.exp(np.log(test_pred_array)/T)
test_pred_T_array = test_pred_T_array/np.sum(test_pred_T_array, axis=1, keepdims=True)
test_pred_T_df = pd.DataFrame(test_pred_T_array, columns=FISH_CLASSES)
test_pred_T_df = pd.concat([test_pred_df[['image_class','image_file']],test_pred_T_df], axis=1)

#test submission
submission = test_pred_T_df.loc[:999,['image_file','NoF', 'ALB', 'BET', 'DOL', 'LAG', 'OTHER', 'SHARK', 'YFT']]
submission.rename(columns={'image_file':'image'}, inplace=True)
sub_file = 'RFCN_AGONOSTICnms_'+RFCN_MODEL+'_'+CROP_MODEL+'_'+test_model_name+ \
'_clsMaxAve_conf{:.2f}_cropvalidloss{:.4f}_cropallloss{:.4f}_imagevalidloss{:.4f}_imageallloss{:.4f}_T{}.csv' \
.format(CONF_THRESH, crop_valid_loss, crop_all_loss, image_valid_loss, image_all_loss, T)
submission.to_csv(OUTPUT_DIR + sub_file, index=False)
print('Done!'+sub_file)
# Out:
# Done!RFCN_AGONOSTICnms_resnet101_rfcn_ohem_iter_30000_resnet55ss4_Hybrid_woNoF_weights.316-0.1940.hdf5_clsMaxAve_conf0.80_cropvalidloss0.1940_cropallloss0.0545_imagevalidloss0.1769_imageallloss0.0717_T2.5.csv
