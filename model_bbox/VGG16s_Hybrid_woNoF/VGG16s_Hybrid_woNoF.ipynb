# %% [raw]
# no centered data
#
# weights.342-0.2377.hdf5
# loss: 0.1356 - acc: 0.9750 - val_loss: 0.2377 - val_acc: 0.9318
# valid loss: class
# ALB      0.177104
# BET      0.811169
# DOL      0.373588
# LAG      0.000418
# OTHER    0.183211
# SHARK    0.481116
# YFT      0.197708
# Name: logloss, dtype: float64
# 0.24065890214
#
# train loss: class
# ALB      0.060359
# BET      0.002202
# DOL      0.000074
# LAG      0.000014
# OTHER    0.000880
# SHARK    0.000044
# YFT      0.009852
# Name: logloss, dtype: float64
# 0.0367313227023

# %%
import os, random, glob, pickle, collections, math, json
import numpy as np
import pandas as pd
from __future__ import division
from __future__ import print_function
from PIL import Image
from sklearn.model_selection import train_test_split
from sklearn.metrics import log_loss
from sklearn.preprocessing import LabelEncoder

import matplotlib.pyplot as plt
# %matplotlib inline 

from keras.models import Sequential, Model, load_model, model_from_json
from keras.layers import GlobalAveragePooling2D, Flatten, Dropout, Dense, LeakyReLU, Conv2D, Input, BatchNormalization
from keras.optimizers import Adam, RMSprop
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, TensorBoard
from keras.preprocessing.image import ImageDataGenerator
from keras.utils import np_utils
from keras.preprocessing import image
from keras import backend as K
K.set_image_dim_ordering('tf')
# Out:
# Using TensorFlow backend.

# %%
TRAIN_DIR = '../data/train/'
TEST_DIR = '../RFCN/JPEGImages/'
TRAIN_CROP_DIR = '../data/train_crop/'
TEST_CROP_DIR = '../data/test_stg1_crop/'
RFCN_MODEL = 'resnet101_rfcn_ohem_iter_30000'
CROP_MODEL = 'VGG16s_Hybrid_woNoF'
if not os.path.exists('./' + CROP_MODEL):
    os.mkdir('./' + CROP_MODEL)
CHECKPOINT_DIR = './' + CROP_MODEL + '/checkpoint/'
if not os.path.exists(CHECKPOINT_DIR):
    os.mkdir(CHECKPOINT_DIR)
LOG_DIR = './' + CROP_MODEL + '/log/'
if not os.path.exists(LOG_DIR):
    os.mkdir(LOG_DIR)
OUTPUT_DIR = './' + CROP_MODEL + '/output/'
if not os.path.exists(OUTPUT_DIR):
    os.mkdir(OUTPUT_DIR)
FISH_CLASSES = ['NoF', 'ALB', 'BET', 'DOL', 'LAG', 'OTHER', 'SHARK', 'YFT']
CROP_CLASSES=FISH_CLASSES[:]
CROP_CLASSES.remove('NoF')
CONF_THRESH = 0.8
ROWS = 224
COLS = 224
BATCHSIZE = 64
LEARNINGRATE = 1e-4
def featurewise_center(x):
    mean = np.mean(x, axis=0, keepdims=True)
    mean = np.mean(mean, axis=(1,2), keepdims=True)
    x_centered = x - mean
    return x_centered

def mean(x):
    mean = np.mean(x, axis=0)
    mean = np.mean(mean, axis=(0,1))
    return mean

def load_img(path, bbox, target_size=None):
    img = Image.open(path)
#     img = img.convert('RGB')
    cropped = img.crop((bbox[0],bbox[1],bbox[2],bbox[3]))
    width_cropped, height_cropped = cropped.size
    if height_cropped > width_cropped: cropped = cropped.transpose(method=2)  
    if target_size:
        cropped = cropped.resize((target_size[1], target_size[0]), Image.BILINEAR)
    return cropped

def preprocess_input(x, mean):
    #resnet50 image preprocessing
#     'RGB'->'BGR'
#     x = x[:, :, ::-1]
#     x /= 255.
    x[:, :, 0] -= mean[0]
    x[:, :, 1] -= mean[1]
    x[:, :, 2] -= mean[2]
    return x

def get_best_model(checkpoint_dir = CHECKPOINT_DIR):
    files = glob.glob(checkpoint_dir+'*')
    val_losses = [float(f.split('-')[-1][:-5]) for f in files]
    index = val_losses.index(min(val_losses))
    print('Loading model from checkpoint file ' + files[index])
    model = load_model(files[index])
    model_name = files[index].split('/')[-1]
    print('Loading model Done!')
    return (model, model_name)

# %%
# GTbbox_df = ['image_file','crop_index','crop_class','xmin',''ymin','xmax','ymax']

file_name = 'GTbbox_df.pickle'
if os.path.exists(OUTPUT_DIR+file_name):
    print ('Loading from file '+file_name)
    GTbbox_df = pd.read_pickle(OUTPUT_DIR+file_name)
else:
    print ('Generating file '+file_name)       
    GTbbox_df = pd.DataFrame(columns=['image_file','crop_index','crop_class','xmin','ymin','xmax','ymax'])  
    
    for c in CROP_CLASSES:
        print(c)
        j = json.load(open('../data/BBannotations/{}.json'.format(c), 'r'))
        for l in j: 
            filename = l["filename"]
            head, image_file = os.path.split(filename)
            basename, file_extension = os.path.splitext(image_file) 
            image = Image.open(TEST_DIR+image_file)
            width_image, height_image = image.size
            for i in range(len(l["annotations"])):
                a = l["annotations"][i]
                xmin = (a["x"])
                ymin = (a["y"])
                width = (a["width"])
                height = (a["height"])
                xmax = xmin + width
                ymax = ymin + height
                assert max(xmin,0)<min(xmax,width_image)
                assert max(ymin,0)<min(ymax,height_image)
                GTbbox_df.loc[len(GTbbox_df)]=[image_file,i,a["class"],max(xmin,0),max(ymin,0),min(xmax,width_image),min(ymax,height_image)]
                if a["class"] != c: print(GTbbox_df.tail(1))  
    
    test_size = GTbbox_df.shape[0]-int(math.ceil(GTbbox_df.shape[0]*0.8/BATCHSIZE)*BATCHSIZE)
    train_ind, valid_ind = train_test_split(range(GTbbox_df.shape[0]), test_size=test_size, random_state=1986, stratify=GTbbox_df['crop_class'])
    GTbbox_df['split'] = ['train' if i in train_ind else 'valid' for i in range(GTbbox_df.shape[0])]
    GTbbox_df.to_pickle(OUTPUT_DIR+file_name)
# Out:
# Loading from file GTbbox_df.pickle

# %%
#Load data

def data_from_df(df):
    X = np.ndarray((df.shape[0], ROWS, COLS, 3), dtype=np.uint8)
    y = np.zeros((df.shape[0], len(CROP_CLASSES)), dtype=K.floatx())
    i = 0
    for index,row in df.iterrows():
        image_file = row['image_file']
        fish = row['crop_class']
        bbox = [row['xmin'],row['ymin'],row['xmax'],row['ymax']]
        cropped = load_img(TEST_DIR+image_file,bbox,target_size=(ROWS,COLS))
        X[i] = np.asarray(cropped)
        y[i,CROP_CLASSES.index(fish)] = 1
        i += 1
    return (X, y)

def data_load(name):
    file_name = 'data_'+name+'_{}_{}.pickle'.format(ROWS, COLS)
    if os.path.exists(OUTPUT_DIR+file_name):
        print ('Loading from file '+file_name)
        with open(OUTPUT_DIR+file_name, 'rb') as f:
            data = pickle.load(f)
        X = data['X']
        y = data['y']
    else:
        print ('Generating file '+file_name)
        
        if name=='train' or name=='valid': 
            df = GTbbox_df[GTbbox_df['split']==name]
        elif name=='all':
            df = GTbbox_df
        else:
            print('Invalid name '+name)
    
        X, y = data_from_df(df)

        data = {'X': X,'y': y}
        with open(OUTPUT_DIR+file_name, 'wb') as f:
            pickle.dump(data, f)
    return (X, y)
X_train, y_train = data_load('train')
X_valid, y_valid = data_load('valid')
       
print('Loading data done.')
print('train sample ', X_train.shape[0])
print('valid sample ', X_valid.shape[0])
X_train = X_train.astype(np.float32)
X_valid = X_valid.astype(np.float32)
print('Convert to float32 done.')
X_train /= 255.
X_valid /= 255.
print('Rescale by 255 done.')
X_train_centered = featurewise_center(X_train)
print('mean of X_train is ', mean(X_train))
X_valid_centered = featurewise_center(X_valid)
print('mean of X_valid is ', mean(X_valid))
print('Featurewise centered done.')
# Out:
# Loading from file data_train_224_224.pickle
# Loading from file data_valid_224_224.pickle
# Loading data done.
# train sample  3520
# valid sample  851
# Convert to float32 done.
# Rescale by 255 done.
# mean of X_train is  [ 0.40691164  0.4380351   0.39487419]
# mean of X_valid is  [ 0.40715367  0.43613413  0.39407834]
# Featurewise centered done.

# %%
# #class weight = n_samples / (n_classes * np.bincount(y))
# class_weight_fish = dict(GTbbox_df.groupby('crop_class').size())
# class_weight = {}
# n_samples = GTbbox_df.shape[0]
# for key,value in class_weight_fish.items():
#         class_weight[CROP_CLASSES.index(key)] = n_samples / (len(CROP_CLASSES)*value)
# class_weight

class_weight_fish = dict(GTbbox_df.groupby('crop_class').size())
class_weight = {}
ref = max(class_weight_fish.values())
for key,value in class_weight_fish.items():
    class_weight[CROP_CLASSES.index(key)] = ref/value
class_weight
# Out:
# {0: 1.0,
#  1: 8.212418300653594,
#  2: 19.944444444444443,
#  3: 23.933333333333334,
#  4: 7.5465465465465469,
#  5: 13.296296296296296,
#  6: 3.1451814768460578}

# %%
#data preprocessing

train_datagen = ImageDataGenerator(
    rotation_range=180,
    shear_range=0.2,
    zoom_range=0.1,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    vertical_flip=True)
train_generator = train_datagen.flow(X_train, y_train, batch_size=BATCHSIZE, shuffle=True, seed=None)
assert X_train.shape[0]%BATCHSIZE==0
steps_per_epoch = int(X_train.shape[0]/BATCHSIZE)

# %%
#callbacks

early_stopping = EarlyStopping(monitor='val_loss', min_delta=0, patience=80, verbose=1, mode='auto')        

model_checkpoint = ModelCheckpoint(filepath=CHECKPOINT_DIR+'weights.{epoch:03d}-{val_loss:.4f}.hdf5', monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False, mode='auto')
        
learningrate_schedule = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=30, verbose=1, mode='auto', epsilon=0.001, cooldown=0, min_lr=0)

tensorboard = TensorBoard(log_dir=LOG_DIR, histogram_freq=0, write_graph=False, write_images=True)

# %%
def create_model_VGG16s():
    model = Sequential()

    model.add(Conv2D(32, (3, 3), padding='same', name='block1_conv1', input_shape=(ROWS, COLS, 3)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.33))
    model.add(Conv2D(32, (3, 3), strides=(2, 2), padding='same', name='block1_conv2'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.33))
    
    model.add(Conv2D(64, (3, 3), padding='same', name='block2_conv1'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.33))
    model.add(Conv2D(64, (3, 3), strides=(2, 2), padding='same', name='block2_conv2'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.33))
    
    model.add(Conv2D(128, (3, 3), padding='same', name='block3_conv1'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.33))
    model.add(Conv2D(128, (3, 3), padding='same', name='block3_conv2'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.33))
    model.add(Conv2D(128, (3, 3), padding='same', name='block3_conv3'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.33))
    model.add(Conv2D(128, (3, 3), strides=(2, 2), padding='same', name='block3_conv4'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.33))
    
    model.add(Conv2D(256, (3, 3), padding='same', name='block4_conv1'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.33))
    model.add(Conv2D(256, (3, 3), padding='same', name='block4_conv2'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.33))
    model.add(Conv2D(256, (3, 3), padding='same', name='block4_conv3'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.33))
    model.add(Conv2D(256, (3, 3), strides=(2, 2), padding='same', name='block4_conv4'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.33))
    
    model.add(Conv2D(256, (3, 3), padding='same', name='block5_conv1'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.33))
    model.add(Conv2D(256, (3, 3), padding='same', name='block5_conv2'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.33))
    model.add(Conv2D(256, (3, 3), padding='same', name='block5_conv3'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.33))
    model.add(Conv2D(256, (3, 3), strides=(2, 2), padding='same', name='block5_conv4'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.33))
    
    model.add(Flatten())
#     model.add(GlobalAveragePooling2D())
#     model.add(Dense(256, activation='relu'))
#     model.add(Dropout(0.8))
    model.add(Dense(len(CROP_CLASSES), activation='softmax'))

    return model

# %%
#train from scratch

model = create_model_VGG16s()

# compile the model (should be done *after* setting layers to non-trainable)
optimizer = Adam(lr=1e-4)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# train the model on the new data for a few epochs
model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=300, verbose=1, 
                    callbacks=[model_checkpoint, tensorboard], 
                    validation_data=(X_valid,y_valid), class_weight=class_weight, workers=3, pickle_safe=True)
# Out:
# Epoch 1/300
# Epoch 00000: val_loss improved from inf to 1.81691, saving model to ./VGG16s_Hybrid_woNoF/checkpoint/weights.000-1.8169.hdf5
# 55/55 [==============================] - 109s - loss: 6.3043 - acc: 0.2676 - val_loss: 1.8169 - val_acc: 0.3067
# Epoch 2/300
# Epoch 00001: val_loss improved from 1.81691 to 1.71860, saving model to ./VGG16s_Hybrid_woNoF/checkpoint/weights.001-1.7186.hdf5
# 55/55 [==============================] - 103s - loss: 4.7506 - acc: 0.3670 - val_loss: 1.7186 - val_acc: 0.0881
# Epoch 3/300
# Epoch 00002: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 4.4450 - acc: 0.3940 - val_loss: 1.8818 - val_acc: 0.0952
# Epoch 4/300
# Epoch 00003: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 3.9109 - acc: 0.4244 - val_loss: 1.9653 - val_acc: 0.2350
# Epoch 5/300
# Epoch 00004: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 3.7978 - acc: 0.4310 - val_loss: 2.1625 - val_acc: 0.1398
# Epoch 6/300
# Epoch 00005: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 3.6168 - acc: 0.4520 - val_loss: 4.2812 - val_acc: 0.0458
# Epoch 7/300
# Epoch 00006: val_loss did not improve
# 55/55 [==============================] - 104s - loss: 3.4733 - acc: 0.4821 - val_loss: 2.4160 - val_acc: 0.3561
# Epoch 8/300
# Epoch 00007: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 3.6818 - acc: 0.4724 - val_loss: 4.1946 - val_acc: 0.1128
# Epoch 9/300
# Epoch 00008: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 3.2183 - acc: 0.4884 - val_loss: 1.9525 - val_acc: 0.2820
# Epoch 10/300
# Epoch 00009: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 3.0737 - acc: 0.5224 - val_loss: 2.2684 - val_acc: 0.3267
# Epoch 11/300
# Epoch 00010: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 2.9565 - acc: 0.5290 - val_loss: 2.0403 - val_acc: 0.4747
# Epoch 12/300
# Epoch 00011: val_loss improved from 1.71860 to 1.53078, saving model to ./VGG16s_Hybrid_woNoF/checkpoint/weights.011-1.5308.hdf5
# 55/55 [==============================] - 103s - loss: 3.0214 - acc: 0.5349 - val_loss: 1.5308 - val_acc: 0.4559
# Epoch 13/300
# Epoch 00012: val_loss improved from 1.53078 to 0.99488, saving model to ./VGG16s_Hybrid_woNoF/checkpoint/weights.012-0.9949.hdf5
# 55/55 [==============================] - 103s - loss: 2.8037 - acc: 0.5466 - val_loss: 0.9949 - val_acc: 0.6016
# Epoch 14/300
# Epoch 00013: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 3.0024 - acc: 0.5472 - val_loss: 1.2434 - val_acc: 0.4947
# Epoch 15/300
# Epoch 00014: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 2.6720 - acc: 0.5483 - val_loss: 1.2410 - val_acc: 0.5711
# Epoch 16/300
# Epoch 00015: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 2.7388 - acc: 0.5801 - val_loss: 1.3498 - val_acc: 0.4501
# Epoch 17/300
# Epoch 00016: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 2.8461 - acc: 0.5625 - val_loss: 1.9588 - val_acc: 0.3995
# Epoch 18/300
# Epoch 00017: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 2.6532 - acc: 0.5892 - val_loss: 1.0181 - val_acc: 0.6416
# Epoch 19/300
# Epoch 00018: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 2.4909 - acc: 0.5889 - val_loss: 1.5076 - val_acc: 0.4536
# Epoch 20/300
# Epoch 00019: val_loss improved from 0.99488 to 0.94686, saving model to ./VGG16s_Hybrid_woNoF/checkpoint/weights.019-0.9469.hdf5
# 55/55 [==============================] - 103s - loss: 2.6758 - acc: 0.5886 - val_loss: 0.9469 - val_acc: 0.6157
# Epoch 21/300
# Epoch 00020: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 2.3606 - acc: 0.6122 - val_loss: 1.1149 - val_acc: 0.5934
# Epoch 22/300
# Epoch 00021: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 2.4328 - acc: 0.6205 - val_loss: 1.6920 - val_acc: 0.4078
# Epoch 23/300
# Epoch 00022: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 2.3441 - acc: 0.6185 - val_loss: 1.1111 - val_acc: 0.5864
# Epoch 24/300
# Epoch 00023: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 2.0784 - acc: 0.6588 - val_loss: 1.1199 - val_acc: 0.6404
# Epoch 25/300
# Epoch 00024: val_loss did not improve
# 55/55 [==============================] - 104s - loss: 2.2162 - acc: 0.6253 - val_loss: 1.2917 - val_acc: 0.5053
# Epoch 26/300
# Epoch 00025: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 2.2152 - acc: 0.6372 - val_loss: 0.9614 - val_acc: 0.6310
# Epoch 27/300
# Epoch 00026: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 2.3542 - acc: 0.6239 - val_loss: 1.9127 - val_acc: 0.4195
# Epoch 28/300
# Epoch 00027: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 2.2383 - acc: 0.6250 - val_loss: 0.9528 - val_acc: 0.6616
# Epoch 29/300
# Epoch 00028: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 2.1703 - acc: 0.6278 - val_loss: 1.7315 - val_acc: 0.4501
# Epoch 30/300
# Epoch 00029: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 2.3582 - acc: 0.6097 - val_loss: 1.2218 - val_acc: 0.6275
# Epoch 31/300
# Epoch 00030: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 2.1291 - acc: 0.6301 - val_loss: 1.1807 - val_acc: 0.5781
# Epoch 32/300
# Epoch 00031: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 2.3912 - acc: 0.6293 - val_loss: 1.3594 - val_acc: 0.5770
# Epoch 33/300
# Epoch 00032: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 2.2803 - acc: 0.6403 - val_loss: 1.7206 - val_acc: 0.5417
# Epoch 34/300
# Epoch 00033: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 2.3289 - acc: 0.6358 - val_loss: 4.1164 - val_acc: 0.3090
# Epoch 35/300
# Epoch 00034: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 2.5114 - acc: 0.6162 - val_loss: 1.3352 - val_acc: 0.5170
# Epoch 36/300
# Epoch 00035: val_loss improved from 0.94686 to 0.87727, saving model to ./VGG16s_Hybrid_woNoF/checkpoint/weights.035-0.8773.hdf5
# 55/55 [==============================] - 104s - loss: 2.2376 - acc: 0.6307 - val_loss: 0.8773 - val_acc: 0.6569
# Epoch 37/300
# Epoch 00036: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 2.0082 - acc: 0.6599 - val_loss: 1.2855 - val_acc: 0.4982
# Epoch 38/300
# Epoch 00037: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 2.1199 - acc: 0.6523 - val_loss: 0.9911 - val_acc: 0.6663
# Epoch 39/300
# Epoch 00038: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 2.1231 - acc: 0.6628 - val_loss: 1.3039 - val_acc: 0.4736
# Epoch 40/300
# Epoch 00039: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.9444 - acc: 0.6605 - val_loss: 1.0764 - val_acc: 0.5864
# Epoch 41/300
# Epoch 00040: val_loss did not improve
# 55/55 [==============================] - 104s - loss: 1.9890 - acc: 0.6847 - val_loss: 1.0117 - val_acc: 0.5828
# Epoch 42/300
# Epoch 00041: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.8413 - acc: 0.6918 - val_loss: 1.0338 - val_acc: 0.6028
# Epoch 43/300
# Epoch 00042: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.9470 - acc: 0.6832 - val_loss: 1.0009 - val_acc: 0.6522
# Epoch 44/300
# Epoch 00043: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 2.0868 - acc: 0.6619 - val_loss: 1.9722 - val_acc: 0.4454
# Epoch 45/300
# Epoch 00044: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 2.0373 - acc: 0.6764 - val_loss: 1.4884 - val_acc: 0.5358
# Epoch 46/300
# Epoch 00045: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 2.0724 - acc: 0.6489 - val_loss: 1.3119 - val_acc: 0.5347
# Epoch 47/300
# Epoch 00046: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.8099 - acc: 0.6764 - val_loss: 0.9347 - val_acc: 0.6651
# Epoch 48/300
# Epoch 00047: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.7346 - acc: 0.6986 - val_loss: 1.1533 - val_acc: 0.5511
# Epoch 49/300
# Epoch 00048: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.5844 - acc: 0.6966 - val_loss: 1.0393 - val_acc: 0.5969
# Epoch 50/300
# Epoch 00049: val_loss improved from 0.87727 to 0.85557, saving model to ./VGG16s_Hybrid_woNoF/checkpoint/weights.049-0.8556.hdf5
# 55/55 [==============================] - 104s - loss: 1.7288 - acc: 0.6955 - val_loss: 0.8556 - val_acc: 0.6733
# Epoch 51/300
# Epoch 00050: val_loss improved from 0.85557 to 0.79976, saving model to ./VGG16s_Hybrid_woNoF/checkpoint/weights.050-0.7998.hdf5
# 55/55 [==============================] - 103s - loss: 1.7259 - acc: 0.7091 - val_loss: 0.7998 - val_acc: 0.7098
# Epoch 52/300
# Epoch 00051: val_loss improved from 0.79976 to 0.71338, saving model to ./VGG16s_Hybrid_woNoF/checkpoint/weights.051-0.7134.hdf5
# 55/55 [==============================] - 103s - loss: 1.5972 - acc: 0.7287 - val_loss: 0.7134 - val_acc: 0.7227
# Epoch 53/300
# Epoch 00052: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.6926 - acc: 0.7034 - val_loss: 1.1226 - val_acc: 0.5887
# Epoch 54/300
# Epoch 00053: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.6024 - acc: 0.7097 - val_loss: 0.9320 - val_acc: 0.6381
# Epoch 55/300
# Epoch 00054: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.5975 - acc: 0.7256 - val_loss: 1.3977 - val_acc: 0.5276
# Epoch 56/300
# Epoch 00055: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.9373 - acc: 0.6795 - val_loss: 1.1878 - val_acc: 0.5817
# Epoch 57/300
# Epoch 00056: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.9552 - acc: 0.6881 - val_loss: 2.8551 - val_acc: 0.4230
# Epoch 58/300
# Epoch 00057: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 2.1680 - acc: 0.6645 - val_loss: 1.4038 - val_acc: 0.5523
# Epoch 59/300
# Epoch 00058: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.7109 - acc: 0.7077 - val_loss: 1.3376 - val_acc: 0.5746
# Epoch 60/300
# Epoch 00059: val_loss improved from 0.71338 to 0.67328, saving model to ./VGG16s_Hybrid_woNoF/checkpoint/weights.059-0.6733.hdf5
# 55/55 [==============================] - 103s - loss: 1.8219 - acc: 0.7014 - val_loss: 0.6733 - val_acc: 0.7521
# Epoch 61/300
# Epoch 00060: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.6073 - acc: 0.7227 - val_loss: 0.8495 - val_acc: 0.6874
# Epoch 62/300
# Epoch 00061: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.5760 - acc: 0.7207 - val_loss: 0.9492 - val_acc: 0.6839
# Epoch 63/300
# Epoch 00062: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.4952 - acc: 0.7250 - val_loss: 0.9830 - val_acc: 0.6369
# Epoch 64/300
# Epoch 00063: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.6430 - acc: 0.7193 - val_loss: 0.9156 - val_acc: 0.6616
# Epoch 65/300
# Epoch 00064: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.8718 - acc: 0.7074 - val_loss: 1.1966 - val_acc: 0.6063
# Epoch 66/300
# Epoch 00065: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.7232 - acc: 0.7176 - val_loss: 1.0791 - val_acc: 0.6475
# Epoch 67/300
# Epoch 00066: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.5044 - acc: 0.7256 - val_loss: 0.9013 - val_acc: 0.6863
# Epoch 68/300
# Epoch 00067: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.6079 - acc: 0.7247 - val_loss: 1.3266 - val_acc: 0.5535
# Epoch 69/300
# Epoch 00068: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.5428 - acc: 0.7324 - val_loss: 1.1198 - val_acc: 0.6216
# Epoch 70/300
# Epoch 00069: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.3846 - acc: 0.7526 - val_loss: 0.7133 - val_acc: 0.7485
# Epoch 71/300
# Epoch 00070: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.3650 - acc: 0.7716 - val_loss: 0.8698 - val_acc: 0.7344
# Epoch 72/300
# Epoch 00071: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.5137 - acc: 0.7420 - val_loss: 1.1088 - val_acc: 0.6275
# Epoch 73/300
# Epoch 00072: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.5155 - acc: 0.7281 - val_loss: 1.3998 - val_acc: 0.5558
# Epoch 74/300
# Epoch 00073: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.6073 - acc: 0.7139 - val_loss: 0.9333 - val_acc: 0.6816
# Epoch 75/300
# Epoch 00074: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.4139 - acc: 0.7469 - val_loss: 0.8342 - val_acc: 0.6945
# Epoch 76/300
# Epoch 00075: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.3791 - acc: 0.7491 - val_loss: 0.8152 - val_acc: 0.6957
# Epoch 77/300
# Epoch 00076: val_loss improved from 0.67328 to 0.61812, saving model to ./VGG16s_Hybrid_woNoF/checkpoint/weights.076-0.6181.hdf5
# 55/55 [==============================] - 104s - loss: 1.3689 - acc: 0.7460 - val_loss: 0.6181 - val_acc: 0.7897
# Epoch 78/300
# Epoch 00077: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.3285 - acc: 0.7739 - val_loss: 0.8571 - val_acc: 0.7133
# Epoch 79/300
# Epoch 00078: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.3162 - acc: 0.7520 - val_loss: 0.6931 - val_acc: 0.7603
# Epoch 80/300
# Epoch 00079: val_loss did not improve
# 55/55 [==============================] - 104s - loss: 1.1154 - acc: 0.7869 - val_loss: 0.9507 - val_acc: 0.6816
# Epoch 81/300
# Epoch 00080: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.4917 - acc: 0.7466 - val_loss: 2.2143 - val_acc: 0.4677
# Epoch 82/300
# Epoch 00081: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 2.8069 - acc: 0.6733 - val_loss: 2.2522 - val_acc: 0.5676
# Epoch 83/300
# Epoch 00082: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 2.2068 - acc: 0.6651 - val_loss: 1.7465 - val_acc: 0.5112
# Epoch 84/300
# Epoch 00083: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.8124 - acc: 0.7003 - val_loss: 1.1939 - val_acc: 0.5746
# Epoch 85/300
# Epoch 00084: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.5626 - acc: 0.7273 - val_loss: 1.0554 - val_acc: 0.6157
# Epoch 86/300
# Epoch 00085: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.3553 - acc: 0.7670 - val_loss: 0.9680 - val_acc: 0.6698
# Epoch 87/300
# Epoch 00086: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.3206 - acc: 0.7662 - val_loss: 0.8702 - val_acc: 0.7391
# Epoch 88/300
# Epoch 00087: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.2797 - acc: 0.7631 - val_loss: 0.6914 - val_acc: 0.7650
# Epoch 89/300
# Epoch 00088: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.3844 - acc: 0.7625 - val_loss: 1.1499 - val_acc: 0.6228
# Epoch 90/300
# Epoch 00089: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.5844 - acc: 0.7477 - val_loss: 1.2910 - val_acc: 0.5781
# Epoch 91/300
# Epoch 00090: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.3713 - acc: 0.7557 - val_loss: 0.8350 - val_acc: 0.7262
# Epoch 92/300
# Epoch 00091: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.2177 - acc: 0.7696 - val_loss: 0.7474 - val_acc: 0.7121
# Epoch 93/300
# Epoch 00092: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.2623 - acc: 0.7798 - val_loss: 0.8460 - val_acc: 0.6968
# Epoch 94/300
# Epoch 00093: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.1958 - acc: 0.7909 - val_loss: 0.8214 - val_acc: 0.7215
# Epoch 95/300
# Epoch 00094: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.1076 - acc: 0.7932 - val_loss: 0.7483 - val_acc: 0.7215
# Epoch 96/300
# Epoch 00095: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.1253 - acc: 0.8085 - val_loss: 0.8724 - val_acc: 0.6780
# Epoch 97/300
# Epoch 00096: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.1348 - acc: 0.7901 - val_loss: 0.9350 - val_acc: 0.6910
# Epoch 98/300
# Epoch 00097: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.2080 - acc: 0.7923 - val_loss: 0.9361 - val_acc: 0.7192
# Epoch 99/300
# Epoch 00098: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 2.3670 - acc: 0.6881 - val_loss: 5.6255 - val_acc: 0.2761
# Epoch 100/300
# Epoch 00099: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.9342 - acc: 0.6974 - val_loss: 1.1069 - val_acc: 0.6439
# Epoch 101/300
# Epoch 00100: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.1966 - acc: 0.7764 - val_loss: 0.8003 - val_acc: 0.7098
# Epoch 102/300
# Epoch 00101: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.2765 - acc: 0.7634 - val_loss: 0.7255 - val_acc: 0.7356
# Epoch 103/300
# Epoch 00102: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.0637 - acc: 0.7969 - val_loss: 0.7374 - val_acc: 0.7532
# Epoch 104/300
# Epoch 00103: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.1305 - acc: 0.7864 - val_loss: 0.6949 - val_acc: 0.7321
# Epoch 105/300
# Epoch 00104: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.2017 - acc: 0.7909 - val_loss: 0.9851 - val_acc: 0.6780
# Epoch 106/300
# Epoch 00105: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.2106 - acc: 0.7949 - val_loss: 0.6731 - val_acc: 0.7568
# Epoch 107/300
# Epoch 00106: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.1643 - acc: 0.7716 - val_loss: 0.8327 - val_acc: 0.7286
# Epoch 108/300
# Epoch 00107: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.0531 - acc: 0.7943 - val_loss: 0.8230 - val_acc: 0.7415
# Epoch 109/300
# Epoch 00108: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.0044 - acc: 0.8128 - val_loss: 0.7401 - val_acc: 0.7086
# Epoch 110/300
# Epoch 00109: val_loss improved from 0.61812 to 0.60273, saving model to ./VGG16s_Hybrid_woNoF/checkpoint/weights.109-0.6027.hdf5
# 55/55 [==============================] - 104s - loss: 1.2223 - acc: 0.7932 - val_loss: 0.6027 - val_acc: 0.8073
# Epoch 111/300
# Epoch 00110: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.2259 - acc: 0.7886 - val_loss: 0.8496 - val_acc: 0.7239
# Epoch 112/300
# Epoch 00111: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.9550 - acc: 0.8142 - val_loss: 0.8422 - val_acc: 0.7004
# Epoch 113/300
# Epoch 00112: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.0195 - acc: 0.8099 - val_loss: 0.7807 - val_acc: 0.7297
# Epoch 114/300
# Epoch 00113: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.1957 - acc: 0.7943 - val_loss: 0.7701 - val_acc: 0.7380
# Epoch 115/300
# Epoch 00114: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.0002 - acc: 0.8159 - val_loss: 0.7873 - val_acc: 0.7262
# Epoch 116/300
# Epoch 00115: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.9265 - acc: 0.8253 - val_loss: 0.6493 - val_acc: 0.7732
# Epoch 117/300
# Epoch 00116: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.8121 - acc: 0.7418 - val_loss: 1.5415 - val_acc: 0.6016
# Epoch 118/300
# Epoch 00117: val_loss improved from 0.60273 to 0.58771, saving model to ./VGG16s_Hybrid_woNoF/checkpoint/weights.117-0.5877.hdf5
# 55/55 [==============================] - 103s - loss: 1.1824 - acc: 0.7827 - val_loss: 0.5877 - val_acc: 0.8014
# Epoch 119/300
# Epoch 00118: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.1016 - acc: 0.8017 - val_loss: 0.6918 - val_acc: 0.7427
# Epoch 120/300
# Epoch 00119: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.9754 - acc: 0.8162 - val_loss: 0.6538 - val_acc: 0.7838
# Epoch 121/300
# Epoch 00120: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.1260 - acc: 0.7898 - val_loss: 0.7119 - val_acc: 0.7603
# Epoch 122/300
# Epoch 00121: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.1600 - acc: 0.8020 - val_loss: 0.7170 - val_acc: 0.7485
# Epoch 123/300
# Epoch 00122: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.1746 - acc: 0.7898 - val_loss: 1.2053 - val_acc: 0.6334
# Epoch 124/300
# Epoch 00123: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.0503 - acc: 0.8063 - val_loss: 1.0312 - val_acc: 0.6675
# Epoch 125/300
# Epoch 00124: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.9330 - acc: 0.8074 - val_loss: 0.7059 - val_acc: 0.7591
# Epoch 126/300
# Epoch 00125: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.8323 - acc: 0.8412 - val_loss: 0.6605 - val_acc: 0.7944
# Epoch 127/300
# Epoch 00126: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.9388 - acc: 0.8219 - val_loss: 0.6878 - val_acc: 0.7685
# Epoch 128/300
# Epoch 00127: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.0256 - acc: 0.8131 - val_loss: 1.3485 - val_acc: 0.6040
# Epoch 129/300
# Epoch 00128: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.9189 - acc: 0.8230 - val_loss: 0.7656 - val_acc: 0.7497
# Epoch 130/300
# Epoch 00129: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.0594 - acc: 0.8099 - val_loss: 0.9825 - val_acc: 0.7086
# Epoch 131/300
# Epoch 00130: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.0335 - acc: 0.8122 - val_loss: 0.8148 - val_acc: 0.7215
# Epoch 132/300
# Epoch 00131: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.3439 - acc: 0.7841 - val_loss: 0.7825 - val_acc: 0.7450
# Epoch 133/300
# Epoch 00132: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.2671 - acc: 0.8011 - val_loss: 1.4619 - val_acc: 0.6439
# Epoch 134/300
# Epoch 00133: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.1695 - acc: 0.7949 - val_loss: 0.8742 - val_acc: 0.7274
# Epoch 135/300
# Epoch 00134: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.9850 - acc: 0.8264 - val_loss: 0.7415 - val_acc: 0.7603
# Epoch 136/300
# Epoch 00135: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.9211 - acc: 0.8287 - val_loss: 0.6663 - val_acc: 0.7626
# Epoch 137/300
# Epoch 00136: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.9095 - acc: 0.8304 - val_loss: 0.8007 - val_acc: 0.7579
# Epoch 138/300
# Epoch 00137: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.9015 - acc: 0.8182 - val_loss: 0.8597 - val_acc: 0.7168
# Epoch 139/300
# Epoch 00138: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.8766 - acc: 0.8318 - val_loss: 0.6085 - val_acc: 0.7979
# Epoch 140/300
# Epoch 00139: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.9320 - acc: 0.8193 - val_loss: 0.7160 - val_acc: 0.7532
# Epoch 141/300
# Epoch 00140: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.8779 - acc: 0.8330 - val_loss: 0.7262 - val_acc: 0.7356
# Epoch 142/300
# Epoch 00141: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.8510 - acc: 0.8276 - val_loss: 0.6139 - val_acc: 0.7885
# Epoch 143/300
# Epoch 00142: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.0115 - acc: 0.8301 - val_loss: 0.7009 - val_acc: 0.7861
# Epoch 144/300
# Epoch 00143: val_loss improved from 0.58771 to 0.57880, saving model to ./VGG16s_Hybrid_woNoF/checkpoint/weights.143-0.5788.hdf5
# 55/55 [==============================] - 103s - loss: 0.9293 - acc: 0.8230 - val_loss: 0.5788 - val_acc: 0.8096
# Epoch 145/300
# Epoch 00144: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.8375 - acc: 0.8406 - val_loss: 0.7261 - val_acc: 0.7615
# Epoch 146/300
# Epoch 00145: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.9948 - acc: 0.8199 - val_loss: 0.9435 - val_acc: 0.7203
# Epoch 147/300
# Epoch 00146: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.8134 - acc: 0.8378 - val_loss: 0.7698 - val_acc: 0.7403
# Epoch 148/300
# Epoch 00147: val_loss improved from 0.57880 to 0.56049, saving model to ./VGG16s_Hybrid_woNoF/checkpoint/weights.147-0.5605.hdf5
# 55/55 [==============================] - 103s - loss: 0.9169 - acc: 0.8241 - val_loss: 0.5605 - val_acc: 0.8049
# Epoch 149/300
# Epoch 00148: val_loss improved from 0.56049 to 0.53402, saving model to ./VGG16s_Hybrid_woNoF/checkpoint/weights.148-0.5340.hdf5
# 55/55 [==============================] - 104s - loss: 0.8854 - acc: 0.8432 - val_loss: 0.5340 - val_acc: 0.8249
# Epoch 150/300
# Epoch 00149: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.8398 - acc: 0.8460 - val_loss: 0.8147 - val_acc: 0.7568
# Epoch 151/300
# Epoch 00150: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.1317 - acc: 0.8122 - val_loss: 1.2064 - val_acc: 0.6898
# Epoch 152/300
# Epoch 00151: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.1193 - acc: 0.8068 - val_loss: 1.3940 - val_acc: 0.6169
# Epoch 153/300
# Epoch 00152: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.6201 - acc: 0.7480 - val_loss: 3.7579 - val_acc: 0.4219
# Epoch 154/300
# Epoch 00153: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.2933 - acc: 0.7832 - val_loss: 0.8622 - val_acc: 0.7626
# Epoch 155/300
# Epoch 00154: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.0017 - acc: 0.8202 - val_loss: 0.8987 - val_acc: 0.7321
# Epoch 156/300
# Epoch 00155: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.8450 - acc: 0.8486 - val_loss: 0.5445 - val_acc: 0.8296
# Epoch 157/300
# Epoch 00156: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.8662 - acc: 0.8278 - val_loss: 1.8852 - val_acc: 0.6110
# Epoch 158/300
# Epoch 00157: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.9428 - acc: 0.8398 - val_loss: 1.0564 - val_acc: 0.6475
# Epoch 159/300
# Epoch 00158: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.9363 - acc: 0.8341 - val_loss: 0.6742 - val_acc: 0.7732
# Epoch 160/300
# Epoch 00159: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.7832 - acc: 0.8557 - val_loss: 0.6789 - val_acc: 0.7568
# Epoch 161/300
# Epoch 00160: val_loss improved from 0.53402 to 0.51085, saving model to ./VGG16s_Hybrid_woNoF/checkpoint/weights.160-0.5108.hdf5
# 55/55 [==============================] - 103s - loss: 0.7780 - acc: 0.8472 - val_loss: 0.5108 - val_acc: 0.8390
# Epoch 162/300
# Epoch 00161: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.8690 - acc: 0.8372 - val_loss: 0.8303 - val_acc: 0.7215
# Epoch 163/300
# Epoch 00162: val_loss improved from 0.51085 to 0.45514, saving model to ./VGG16s_Hybrid_woNoF/checkpoint/weights.162-0.4551.hdf5
# 55/55 [==============================] - 103s - loss: 0.7965 - acc: 0.8520 - val_loss: 0.4551 - val_acc: 0.8590
# Epoch 164/300
# Epoch 00163: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.7740 - acc: 0.8685 - val_loss: 0.5880 - val_acc: 0.7955
# Epoch 165/300
# Epoch 00164: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.6382 - acc: 0.8750 - val_loss: 1.5654 - val_acc: 0.6675
# Epoch 166/300
# Epoch 00165: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.7325 - acc: 0.8642 - val_loss: 0.5176 - val_acc: 0.8355
# Epoch 167/300
# Epoch 00166: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.7686 - acc: 0.8636 - val_loss: 0.7468 - val_acc: 0.7626
# Epoch 168/300
# Epoch 00167: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.7128 - acc: 0.8605 - val_loss: 0.6520 - val_acc: 0.7779
# Epoch 169/300
# Epoch 00168: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.8212 - acc: 0.8423 - val_loss: 1.4202 - val_acc: 0.5958
# Epoch 170/300
# Epoch 00169: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.1492 - acc: 0.8017 - val_loss: 3.2802 - val_acc: 0.4865
# Epoch 171/300
# Epoch 00170: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.7743 - acc: 0.7506 - val_loss: 1.1468 - val_acc: 0.6733
# Epoch 172/300
# Epoch 00171: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.0250 - acc: 0.8196 - val_loss: 0.7042 - val_acc: 0.7485
# Epoch 173/300
# Epoch 00172: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.7277 - acc: 0.8571 - val_loss: 0.7464 - val_acc: 0.7450
# Epoch 174/300
# Epoch 00173: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.5951 - acc: 0.8852 - val_loss: 0.4871 - val_acc: 0.8449
# Epoch 175/300
# Epoch 00174: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.7573 - acc: 0.8577 - val_loss: 0.4893 - val_acc: 0.8472
# Epoch 176/300
# Epoch 00175: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.5910 - acc: 0.8801 - val_loss: 0.4648 - val_acc: 0.8496
# Epoch 177/300
# Epoch 00176: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.8378 - acc: 0.8517 - val_loss: 0.6922 - val_acc: 0.7955
# Epoch 178/300
# Epoch 00177: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.7792 - acc: 0.8528 - val_loss: 0.5630 - val_acc: 0.8214
# Epoch 179/300
# Epoch 00178: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.6381 - acc: 0.8753 - val_loss: 0.7867 - val_acc: 0.7709
# Epoch 180/300
# Epoch 00179: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.8286 - acc: 0.8560 - val_loss: 0.9569 - val_acc: 0.7098
# Epoch 181/300
# Epoch 00180: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.0581 - acc: 0.8187 - val_loss: 1.1253 - val_acc: 0.6933
# Epoch 182/300
# Epoch 00181: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.1528 - acc: 0.8148 - val_loss: 0.7085 - val_acc: 0.7556
# Epoch 183/300
# Epoch 00182: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.7852 - acc: 0.8452 - val_loss: 0.5968 - val_acc: 0.8143
# Epoch 184/300
# Epoch 00183: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.7270 - acc: 0.8713 - val_loss: 0.6561 - val_acc: 0.8073
# Epoch 185/300
# Epoch 00184: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.6606 - acc: 0.8679 - val_loss: 0.6815 - val_acc: 0.7814
# Epoch 186/300
# Epoch 00185: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.7355 - acc: 0.8585 - val_loss: 0.5154 - val_acc: 0.8331
# Epoch 187/300
# Epoch 00186: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.7699 - acc: 0.8702 - val_loss: 0.7338 - val_acc: 0.7568
# Epoch 188/300
# Epoch 00187: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.4100 - acc: 0.8006 - val_loss: 0.9415 - val_acc: 0.6968
# Epoch 189/300
# Epoch 00188: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 1.1082 - acc: 0.8043 - val_loss: 1.1614 - val_acc: 0.6592
# Epoch 190/300
# Epoch 00189: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.8170 - acc: 0.8480 - val_loss: 0.7028 - val_acc: 0.7591
# Epoch 191/300
# Epoch 00190: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.6806 - acc: 0.8582 - val_loss: 0.4997 - val_acc: 0.8249
# Epoch 192/300
# Epoch 00191: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.6963 - acc: 0.8770 - val_loss: 1.9846 - val_acc: 0.6240
# Epoch 193/300
# Epoch 00192: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.8002 - acc: 0.8537 - val_loss: 0.7648 - val_acc: 0.7497
# Epoch 194/300
# Epoch 00193: val_loss improved from 0.45514 to 0.43026, saving model to ./VGG16s_Hybrid_woNoF/checkpoint/weights.193-0.4303.hdf5
# 55/55 [==============================] - 103s - loss: 0.6907 - acc: 0.8665 - val_loss: 0.4303 - val_acc: 0.8766
# Epoch 195/300
# Epoch 00194: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.5928 - acc: 0.8827 - val_loss: 0.4662 - val_acc: 0.8402
# Epoch 196/300
# Epoch 00195: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.5542 - acc: 0.8912 - val_loss: 0.5293 - val_acc: 0.8390
# Epoch 197/300
# Epoch 00196: val_loss did not improve
# 55/55 [==============================] - 104s - loss: 0.6267 - acc: 0.8807 - val_loss: 0.4574 - val_acc: 0.8508
# Epoch 198/300
# Epoch 00197: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.6496 - acc: 0.8852 - val_loss: 0.5945 - val_acc: 0.8096
# Epoch 199/300
# Epoch 00198: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.6606 - acc: 0.8778 - val_loss: 0.4727 - val_acc: 0.8449
# Epoch 200/300
# Epoch 00199: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.4559 - acc: 0.9003 - val_loss: 0.5465 - val_acc: 0.8355
# Epoch 201/300
# Epoch 00200: val_loss did not improve
# 55/55 [==============================] - 104s - loss: 0.6273 - acc: 0.8892 - val_loss: 0.5782 - val_acc: 0.8120
# Epoch 202/300
# Epoch 00201: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.5643 - acc: 0.8881 - val_loss: 0.6023 - val_acc: 0.8226
# Epoch 203/300
# Epoch 00202: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.7715 - acc: 0.8651 - val_loss: 0.6224 - val_acc: 0.8155
# Epoch 204/300
# Epoch 00203: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.7854 - acc: 0.8503 - val_loss: 0.7709 - val_acc: 0.7673
# Epoch 205/300
# Epoch 00204: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.7174 - acc: 0.8599 - val_loss: 0.5868 - val_acc: 0.8132
# Epoch 206/300
# Epoch 00205: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.7116 - acc: 0.8597 - val_loss: 0.8424 - val_acc: 0.7344
# Epoch 207/300
# Epoch 00206: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.6208 - acc: 0.8781 - val_loss: 0.4583 - val_acc: 0.8672
# Epoch 208/300
# Epoch 00207: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.5113 - acc: 0.9003 - val_loss: 0.6573 - val_acc: 0.8061
# Epoch 209/300
# Epoch 00208: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.8172 - acc: 0.8543 - val_loss: 0.9254 - val_acc: 0.7203
# Epoch 210/300
# Epoch 00209: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.6464 - acc: 0.8741 - val_loss: 0.6701 - val_acc: 0.7885
# Epoch 211/300
# Epoch 00210: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.5976 - acc: 0.8858 - val_loss: 0.9863 - val_acc: 0.7333
# Epoch 212/300
# Epoch 00211: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.7480 - acc: 0.8679 - val_loss: 1.0312 - val_acc: 0.7039
# Epoch 213/300
# Epoch 00212: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 3.3038 - acc: 0.7233 - val_loss: 7.8349 - val_acc: 0.2985
# Epoch 214/300
# Epoch 00213: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 2.2056 - acc: 0.6830 - val_loss: 2.2316 - val_acc: 0.5958
# Epoch 215/300
# Epoch 00214: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.9916 - acc: 0.8173 - val_loss: 0.9354 - val_acc: 0.6910
# Epoch 216/300
# Epoch 00215: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.8113 - acc: 0.8551 - val_loss: 0.4558 - val_acc: 0.8555
# Epoch 217/300
# Epoch 00216: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.7027 - acc: 0.8730 - val_loss: 0.5792 - val_acc: 0.7826
# Epoch 218/300
# Epoch 00217: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.6277 - acc: 0.8824 - val_loss: 0.5522 - val_acc: 0.8237
# Epoch 219/300
# Epoch 00218: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.5717 - acc: 0.8903 - val_loss: 0.4749 - val_acc: 0.8578
# Epoch 220/300
# Epoch 00219: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.5531 - acc: 0.8915 - val_loss: 0.5021 - val_acc: 0.8308
# Epoch 221/300
# Epoch 00220: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.7025 - acc: 0.8688 - val_loss: 0.5006 - val_acc: 0.8378
# Epoch 222/300
# Epoch 00221: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.6037 - acc: 0.8776 - val_loss: 0.6782 - val_acc: 0.7850
# Epoch 223/300
# Epoch 00222: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.5306 - acc: 0.8827 - val_loss: 0.7748 - val_acc: 0.7861
# Epoch 224/300
# Epoch 00223: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.5643 - acc: 0.8997 - val_loss: 0.5197 - val_acc: 0.8390
# Epoch 225/300
# Epoch 00224: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.6192 - acc: 0.8739 - val_loss: 0.5167 - val_acc: 0.8367
# Epoch 226/300
# Epoch 00225: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.5136 - acc: 0.9023 - val_loss: 0.5812 - val_acc: 0.8167
# Epoch 227/300
# Epoch 00226: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.4937 - acc: 0.9034 - val_loss: 0.5653 - val_acc: 0.8202
# Epoch 228/300
# Epoch 00227: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.6608 - acc: 0.8767 - val_loss: 0.6504 - val_acc: 0.7991
# Epoch 229/300
# Epoch 00228: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.6567 - acc: 0.8770 - val_loss: 0.7816 - val_acc: 0.7579
# Epoch 230/300
# Epoch 00229: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.7988 - acc: 0.8682 - val_loss: 0.9406 - val_acc: 0.7286
# Epoch 231/300
# 12/55 [=====>........................] - ETA: 74s - loss: 0.9189 - acc: 0.8581
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-f3e7b7da0ed3> in <module>()
#      10 model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=300, verbose=1,
#      11                     callbacks=[model_checkpoint, tensorboard],
# ---> 12                     validation_data=(X_valid,y_valid), class_weight=class_weight, workers=3, pickle_safe=True)
#
# /usr/local/lib64/python2.7/site-packages/keras/legacy/interfaces.pyc in wrapper(*args, **kwargs)
#      86                 warnings.warn('Update your `' + object_name +
#      87                               '` call to the Keras 2 API: ' + signature, stacklevel=2)
# ---> 88             return func(*args, **kwargs)
#      89         wrapper._legacy_support_signature = inspect.getargspec(func)
#      90         return wrapper
#
# /usr/local/lib64/python2.7/site-packages/keras/models.pyc in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_q_size, workers, pickle_safe, initial_epoch)
#    1095                                         workers=workers,
#    1096                                         pickle_safe=pickle_safe,
# -> 1097                                         initial_epoch=initial_epoch)
#    1098
#    1099     @interfaces.legacy_generator_methods_support
#
# /usr/local/lib64/python2.7/site-packages/keras/legacy/interfaces.pyc in wrapper(*args, **kwargs)
#      86                 warnings.warn('Update your `' + object_name +
#      87                               '` call to the Keras 2 API: ' + signature, stacklevel=2)
# ---> 88             return func(*args, **kwargs)
#      89         wrapper._legacy_support_signature = inspect.getargspec(func)
#      90         return wrapper
#
# /usr/local/lib64/python2.7/site-packages/keras/engine/training.pyc in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_q_size, workers, pickle_safe, initial_epoch)
#    1874                     outs = self.train_on_batch(x, y,
#    1875                                                sample_weight=sample_weight,
# -> 1876                                                class_weight=class_weight)
#    1877
#    1878                     if not isinstance(outs, list):
#
# /usr/local/lib64/python2.7/site-packages/keras/engine/training.pyc in train_on_batch(self, x, y, sample_weight, class_weight)
#    1618             ins = x + y + sample_weights
#    1619         self._make_train_function()
# -> 1620         outputs = self.train_function(ins)
#    1621         if len(outputs) == 1:
#    1622             return outputs[0]
#
# /usr/local/lib64/python2.7/site-packages/keras/backend/tensorflow_backend.pyc in __call__(self, inputs)
#    2071         session = get_session()
#    2072         updated = session.run(self.outputs + [self.updates_op],
# -> 2073                               feed_dict=feed_dict)
#    2074         return updated[:len(self.outputs)]
#    2075
#
# /usr/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     765     try:
#     766       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 767                          run_metadata_ptr)
#     768       if run_metadata:
#     769         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     963     if final_fetches or final_targets:
#     964       results = self._do_run(handle, final_targets, final_fetches,
# --> 965                              feed_dict_string, options, run_metadata)
#     966     else:
#     967       results = []
#
# /usr/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1013     if handle is None:
#    1014       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1015                            target_list, options, run_metadata)
#    1016     else:
#    1017       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /usr/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1020   def _do_call(self, fn, *args):
#    1021     try:
# -> 1022       return fn(*args)
#    1023     except errors.OpError as e:
#    1024       message = compat.as_text(e.message)
#
# /usr/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1002         return tf_session.TF_Run(session, options,
#    1003                                  feed_dict, fetch_list, target_list,
# -> 1004                                  status, run_metadata)
#    1005
#    1006     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
#resume training

model, model_name = get_best_model()
# print('Loading model from weights.162-0.4551.hdf5')
# model = load_model(CHECKPOINT_DIR + 'weights.162-0.4551.hdf5')

optimizer = Adam(lr=1e-5)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=600, verbose=1, 
                    callbacks=[early_stopping, model_checkpoint, learningrate_schedule, tensorboard], 
                    validation_data=(X_valid,y_valid), class_weight=class_weight, 
                    workers=3, pickle_safe=True, initial_epoch=194)
# Out:
# Loading model from checkpoint file ./VGG16s_Hybrid_woNoF/checkpoint/weights.193-0.4303.hdf5
# Loading model Done!
# Epoch 195/600
# Epoch 00194: val_loss improved from inf to 0.31972, saving model to ./VGG16s_Hybrid_woNoF/checkpoint/weights.194-0.3197.hdf5
# 55/55 [==============================] - 110s - loss: 0.5199 - acc: 0.9009 - val_loss: 0.3197 - val_acc: 0.9036
# Epoch 196/600
# Epoch 00195: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.3890 - acc: 0.9222 - val_loss: 0.3282 - val_acc: 0.8860
# Epoch 197/600
# Epoch 00196: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.3988 - acc: 0.9236 - val_loss: 0.3333 - val_acc: 0.8966
# Epoch 198/600
# Epoch 00197: val_loss improved from 0.31972 to 0.30476, saving model to ./VGG16s_Hybrid_woNoF/checkpoint/weights.197-0.3048.hdf5
# 55/55 [==============================] - 103s - loss: 0.3630 - acc: 0.9315 - val_loss: 0.3048 - val_acc: 0.8989
# Epoch 199/600
# Epoch 00198: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.3701 - acc: 0.9239 - val_loss: 0.3280 - val_acc: 0.8931
# Epoch 200/600
# Epoch 00199: val_loss improved from 0.30476 to 0.29806, saving model to ./VGG16s_Hybrid_woNoF/checkpoint/weights.199-0.2981.hdf5
# 55/55 [==============================] - 103s - loss: 0.3664 - acc: 0.9210 - val_loss: 0.2981 - val_acc: 0.9130
# Epoch 201/600
# Epoch 00200: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.3789 - acc: 0.9227 - val_loss: 0.3219 - val_acc: 0.8931
# Epoch 202/600
# Epoch 00201: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.3446 - acc: 0.9321 - val_loss: 0.3179 - val_acc: 0.9001
# Epoch 203/600
# Epoch 00202: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.3058 - acc: 0.9344 - val_loss: 0.3276 - val_acc: 0.8954
# Epoch 204/600
# Epoch 00203: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.2979 - acc: 0.9395 - val_loss: 0.3008 - val_acc: 0.9001
# Epoch 205/600
# Epoch 00204: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.3548 - acc: 0.9315 - val_loss: 0.3176 - val_acc: 0.8978
# Epoch 206/600
# Epoch 00205: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.3600 - acc: 0.9315 - val_loss: 0.3484 - val_acc: 0.8825
# Epoch 207/600
# Epoch 00206: val_loss improved from 0.29806 to 0.28827, saving model to ./VGG16s_Hybrid_woNoF/checkpoint/weights.206-0.2883.hdf5
# 55/55 [==============================] - 104s - loss: 0.2760 - acc: 0.9455 - val_loss: 0.2883 - val_acc: 0.9130
# Epoch 208/600
# Epoch 00207: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.2888 - acc: 0.9437 - val_loss: 0.3395 - val_acc: 0.8848
# Epoch 209/600
# Epoch 00208: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.2950 - acc: 0.9330 - val_loss: 0.3048 - val_acc: 0.9072
# Epoch 210/600
# Epoch 00209: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.2869 - acc: 0.9477 - val_loss: 0.3082 - val_acc: 0.9013
# Epoch 211/600
# Epoch 00210: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.3110 - acc: 0.9389 - val_loss: 0.4153 - val_acc: 0.8649
# Epoch 212/600
# Epoch 00211: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.3280 - acc: 0.9386 - val_loss: 0.3167 - val_acc: 0.9025
# Epoch 213/600
# Epoch 00212: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.3075 - acc: 0.9386 - val_loss: 0.3263 - val_acc: 0.8919
# Epoch 214/600
# Epoch 00213: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.3275 - acc: 0.9341 - val_loss: 0.3630 - val_acc: 0.8813
# Epoch 215/600
# Epoch 00214: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.2601 - acc: 0.9443 - val_loss: 0.2905 - val_acc: 0.9142
# Epoch 216/600
# Epoch 00215: val_loss improved from 0.28827 to 0.28694, saving model to ./VGG16s_Hybrid_woNoF/checkpoint/weights.215-0.2869.hdf5
# 55/55 [==============================] - 103s - loss: 0.2640 - acc: 0.9511 - val_loss: 0.2869 - val_acc: 0.9130
# Epoch 217/600
# Epoch 00216: val_loss improved from 0.28694 to 0.28643, saving model to ./VGG16s_Hybrid_woNoF/checkpoint/weights.216-0.2864.hdf5
# 55/55 [==============================] - 104s - loss: 0.2688 - acc: 0.9457 - val_loss: 0.2864 - val_acc: 0.9189
# Epoch 218/600
# Epoch 00217: val_loss improved from 0.28643 to 0.28317, saving model to ./VGG16s_Hybrid_woNoF/checkpoint/weights.217-0.2832.hdf5
# 55/55 [==============================] - 103s - loss: 0.2748 - acc: 0.9460 - val_loss: 0.2832 - val_acc: 0.9248
# Epoch 219/600
# Epoch 00218: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.3022 - acc: 0.9443 - val_loss: 0.3125 - val_acc: 0.9142
# Epoch 220/600
# Epoch 00219: val_loss improved from 0.28317 to 0.27579, saving model to ./VGG16s_Hybrid_woNoF/checkpoint/weights.219-0.2758.hdf5
# 55/55 [==============================] - 103s - loss: 0.2372 - acc: 0.9449 - val_loss: 0.2758 - val_acc: 0.9271
# Epoch 221/600
# Epoch 00220: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.2532 - acc: 0.9517 - val_loss: 0.3087 - val_acc: 0.9072
# Epoch 222/600
# Epoch 00221: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.2842 - acc: 0.9455 - val_loss: 0.2970 - val_acc: 0.9095
# Epoch 223/600
# Epoch 00222: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.2529 - acc: 0.9466 - val_loss: 0.3026 - val_acc: 0.9107
# Epoch 224/600
# Epoch 00223: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.2733 - acc: 0.9398 - val_loss: 0.3022 - val_acc: 0.9119
# Epoch 225/600
# Epoch 00224: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.2357 - acc: 0.9528 - val_loss: 0.3008 - val_acc: 0.9036
# Epoch 226/600
# Epoch 00225: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.2692 - acc: 0.9463 - val_loss: 0.2918 - val_acc: 0.9189
# Epoch 227/600
# Epoch 00226: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.2500 - acc: 0.9483 - val_loss: 0.2768 - val_acc: 0.9224
# Epoch 228/600
# Epoch 00227: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.2434 - acc: 0.9511 - val_loss: 0.2812 - val_acc: 0.9154
# Epoch 229/600
# Epoch 00228: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.2965 - acc: 0.9460 - val_loss: 0.2817 - val_acc: 0.9177
# Epoch 230/600
# Epoch 00229: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.2609 - acc: 0.9418 - val_loss: 0.3231 - val_acc: 0.8954
# Epoch 231/600
# Epoch 00230: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.2472 - acc: 0.9466 - val_loss: 0.2831 - val_acc: 0.9177
# Epoch 232/600
# Epoch 00231: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.2190 - acc: 0.9560 - val_loss: 0.3070 - val_acc: 0.9166
# Epoch 233/600
# Epoch 00232: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.2481 - acc: 0.9494 - val_loss: 0.3201 - val_acc: 0.9060
# Epoch 234/600
# Epoch 00233: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.2184 - acc: 0.9557 - val_loss: 0.3221 - val_acc: 0.9060
# Epoch 235/600
# Epoch 00234: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.2246 - acc: 0.9560 - val_loss: 0.2868 - val_acc: 0.9130
# Epoch 236/600
# Epoch 00235: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.2679 - acc: 0.9412 - val_loss: 0.3041 - val_acc: 0.9154
# Epoch 237/600
# Epoch 00236: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.2411 - acc: 0.9511 - val_loss: 0.3191 - val_acc: 0.9013
# Epoch 238/600
# Epoch 00237: val_loss improved from 0.27579 to 0.26572, saving model to ./VGG16s_Hybrid_woNoF/checkpoint/weights.237-0.2657.hdf5
# 55/55 [==============================] - 103s - loss: 0.2295 - acc: 0.9477 - val_loss: 0.2657 - val_acc: 0.9236
# Epoch 239/600
# Epoch 00238: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.2206 - acc: 0.9551 - val_loss: 0.2908 - val_acc: 0.9119
# Epoch 240/600
# Epoch 00239: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1997 - acc: 0.9625 - val_loss: 0.3027 - val_acc: 0.9048
# Epoch 241/600
# Epoch 00240: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.2270 - acc: 0.9582 - val_loss: 0.3035 - val_acc: 0.9154
# Epoch 242/600
# Epoch 00241: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.2645 - acc: 0.9477 - val_loss: 0.3161 - val_acc: 0.9072
# Epoch 243/600
# Epoch 00242: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.2336 - acc: 0.9477 - val_loss: 0.3441 - val_acc: 0.8919
# Epoch 244/600
# Epoch 00243: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.2082 - acc: 0.9560 - val_loss: 0.2776 - val_acc: 0.9154
# Epoch 245/600
# Epoch 00244: val_loss did not improve
# 55/55 [==============================] - 104s - loss: 0.2481 - acc: 0.9480 - val_loss: 0.3072 - val_acc: 0.9048
# Epoch 246/600
# Epoch 00245: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.2076 - acc: 0.9554 - val_loss: 0.2749 - val_acc: 0.9307
# Epoch 247/600
# Epoch 00246: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.2073 - acc: 0.9611 - val_loss: 0.3328 - val_acc: 0.9048
# Epoch 248/600
# Epoch 00247: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.2338 - acc: 0.9477 - val_loss: 0.3020 - val_acc: 0.9154
# Epoch 249/600
# Epoch 00248: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.2430 - acc: 0.9511 - val_loss: 0.3120 - val_acc: 0.9036
# Epoch 250/600
# Epoch 00249: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.2056 - acc: 0.9591 - val_loss: 0.2889 - val_acc: 0.9154
# Epoch 251/600
# Epoch 00250: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.2206 - acc: 0.9543 - val_loss: 0.2980 - val_acc: 0.9083
# Epoch 252/600
# Epoch 00251: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1885 - acc: 0.9605 - val_loss: 0.2849 - val_acc: 0.9107
# Epoch 253/600
# Epoch 00252: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.2116 - acc: 0.9568 - val_loss: 0.2901 - val_acc: 0.9107
# Epoch 254/600
# Epoch 00253: val_loss improved from 0.26572 to 0.25866, saving model to ./VGG16s_Hybrid_woNoF/checkpoint/weights.253-0.2587.hdf5
# 55/55 [==============================] - 104s - loss: 0.2267 - acc: 0.9562 - val_loss: 0.2587 - val_acc: 0.9224
# Epoch 255/600
# Epoch 00254: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.2712 - acc: 0.9491 - val_loss: 0.3318 - val_acc: 0.9001
# Epoch 256/600
# Epoch 00255: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.2434 - acc: 0.9506 - val_loss: 0.3018 - val_acc: 0.9142
# Epoch 257/600
# Epoch 00256: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.2164 - acc: 0.9608 - val_loss: 0.2823 - val_acc: 0.9142
# Epoch 258/600
# Epoch 00257: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.2361 - acc: 0.9574 - val_loss: 0.3663 - val_acc: 0.8966
# Epoch 259/600
# Epoch 00258: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1964 - acc: 0.9591 - val_loss: 0.2776 - val_acc: 0.9130
# Epoch 260/600
# Epoch 00259: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.2338 - acc: 0.9557 - val_loss: 0.2830 - val_acc: 0.9201
# Epoch 261/600
# Epoch 00260: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1899 - acc: 0.9608 - val_loss: 0.2724 - val_acc: 0.9224
# Epoch 262/600
# Epoch 00261: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.2206 - acc: 0.9545 - val_loss: 0.2673 - val_acc: 0.9177
# Epoch 263/600
# Epoch 00262: val_loss improved from 0.25866 to 0.25378, saving model to ./VGG16s_Hybrid_woNoF/checkpoint/weights.262-0.2538.hdf5
# 55/55 [==============================] - 103s - loss: 0.1946 - acc: 0.9614 - val_loss: 0.2538 - val_acc: 0.9189
# Epoch 264/600
# Epoch 00263: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.2288 - acc: 0.9554 - val_loss: 0.2647 - val_acc: 0.9295
# Epoch 265/600
# Epoch 00264: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.2340 - acc: 0.9551 - val_loss: 0.3241 - val_acc: 0.9177
# Epoch 266/600
# Epoch 00265: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.2206 - acc: 0.9619 - val_loss: 0.2904 - val_acc: 0.9072
# Epoch 267/600
# Epoch 00266: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.2236 - acc: 0.9568 - val_loss: 0.2890 - val_acc: 0.9119
# Epoch 268/600
# Epoch 00267: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.2083 - acc: 0.9591 - val_loss: 0.3343 - val_acc: 0.8872
# Epoch 269/600
# Epoch 00268: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1781 - acc: 0.9577 - val_loss: 0.2677 - val_acc: 0.9260
# Epoch 270/600
# Epoch 00269: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.2068 - acc: 0.9619 - val_loss: 0.3328 - val_acc: 0.8801
# Epoch 271/600
# Epoch 00270: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1955 - acc: 0.9560 - val_loss: 0.2658 - val_acc: 0.9177
# Epoch 272/600
# Epoch 00271: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.2583 - acc: 0.9560 - val_loss: 0.2882 - val_acc: 0.9095
# Epoch 273/600
# Epoch 00272: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1890 - acc: 0.9560 - val_loss: 0.2766 - val_acc: 0.9224
# Epoch 274/600
# Epoch 00273: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.2179 - acc: 0.9528 - val_loss: 0.2723 - val_acc: 0.9177
# Epoch 275/600
# Epoch 00274: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1915 - acc: 0.9537 - val_loss: 0.2754 - val_acc: 0.9142
# Epoch 276/600
# Epoch 00275: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.2092 - acc: 0.9651 - val_loss: 0.2930 - val_acc: 0.9119
# Epoch 277/600
# Epoch 00276: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.2013 - acc: 0.9554 - val_loss: 0.3013 - val_acc: 0.9048
# Epoch 278/600
# Epoch 00277: val_loss improved from 0.25378 to 0.24441, saving model to ./VGG16s_Hybrid_woNoF/checkpoint/weights.277-0.2444.hdf5
# 55/55 [==============================] - 103s - loss: 0.1944 - acc: 0.9585 - val_loss: 0.2444 - val_acc: 0.9365
# Epoch 279/600
# Epoch 00278: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1841 - acc: 0.9645 - val_loss: 0.2850 - val_acc: 0.9224
# Epoch 280/600
# Epoch 00279: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.2102 - acc: 0.9554 - val_loss: 0.2619 - val_acc: 0.9260
# Epoch 281/600
# Epoch 00280: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.2047 - acc: 0.9628 - val_loss: 0.2572 - val_acc: 0.9260
# Epoch 282/600
# Epoch 00281: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1696 - acc: 0.9665 - val_loss: 0.2737 - val_acc: 0.9154
# Epoch 283/600
# Epoch 00282: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.2047 - acc: 0.9554 - val_loss: 0.2763 - val_acc: 0.9142
# Epoch 284/600
# Epoch 00283: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1661 - acc: 0.9659 - val_loss: 0.3295 - val_acc: 0.8942
# Epoch 285/600
# Epoch 00284: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1701 - acc: 0.9651 - val_loss: 0.3341 - val_acc: 0.9060
# Epoch 286/600
# Epoch 00285: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1941 - acc: 0.9565 - val_loss: 0.2652 - val_acc: 0.9213
# Epoch 287/600
# Epoch 00286: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.2014 - acc: 0.9568 - val_loss: 0.2960 - val_acc: 0.9130
# Epoch 288/600
# Epoch 00287: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1972 - acc: 0.9628 - val_loss: 0.2786 - val_acc: 0.9177
# Epoch 289/600
# Epoch 00288: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.2379 - acc: 0.9551 - val_loss: 0.3000 - val_acc: 0.9095
# Epoch 290/600
# Epoch 00289: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1759 - acc: 0.9631 - val_loss: 0.3049 - val_acc: 0.9048
# Epoch 291/600
# Epoch 00290: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1785 - acc: 0.9648 - val_loss: 0.3025 - val_acc: 0.9130
# Epoch 292/600
# Epoch 00291: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1741 - acc: 0.9636 - val_loss: 0.2747 - val_acc: 0.9177
# Epoch 293/600
# Epoch 00292: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1849 - acc: 0.9594 - val_loss: 0.2920 - val_acc: 0.9130
# Epoch 294/600
# Epoch 00293: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1855 - acc: 0.9648 - val_loss: 0.2881 - val_acc: 0.9130
# Epoch 295/600
# Epoch 00294: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1608 - acc: 0.9625 - val_loss: 0.2596 - val_acc: 0.9248
# Epoch 296/600
# Epoch 00295: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1808 - acc: 0.9628 - val_loss: 0.3338 - val_acc: 0.9095
# Epoch 297/600
# Epoch 00296: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1840 - acc: 0.9605 - val_loss: 0.2639 - val_acc: 0.9295
# Epoch 298/600
# Epoch 00297: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1692 - acc: 0.9636 - val_loss: 0.2751 - val_acc: 0.9260
# Epoch 299/600
# Epoch 00298: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1550 - acc: 0.9665 - val_loss: 0.2836 - val_acc: 0.9236
# Epoch 300/600
# Epoch 00299: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1471 - acc: 0.9662 - val_loss: 0.2896 - val_acc: 0.9248
# Epoch 301/600
# Epoch 00300: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1260 - acc: 0.9730 - val_loss: 0.2493 - val_acc: 0.9283
# Epoch 302/600
# Epoch 00301: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1751 - acc: 0.9665 - val_loss: 0.2874 - val_acc: 0.9201
# Epoch 303/600
# Epoch 00302: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1776 - acc: 0.9656 - val_loss: 0.2614 - val_acc: 0.9295
# Epoch 304/600
# Epoch 00303: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1704 - acc: 0.9693 - val_loss: 0.3264 - val_acc: 0.9154
# Epoch 305/600
# Epoch 00304: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1639 - acc: 0.9662 - val_loss: 0.2693 - val_acc: 0.9213
# Epoch 306/600
# Epoch 00305: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1433 - acc: 0.9670 - val_loss: 0.3024 - val_acc: 0.9177
# Epoch 307/600
# Epoch 00306: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1389 - acc: 0.9685 - val_loss: 0.2493 - val_acc: 0.9330
# Epoch 308/600
# Epoch 00307: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1588 - acc: 0.9733 - val_loss: 0.2655 - val_acc: 0.9260
# Epoch 309/600
# Epoch 00308: val_loss did not improve
#
# Epoch 00308: reducing learning rate to 9.99999974738e-07.
# 55/55 [==============================] - 104s - loss: 0.1915 - acc: 0.9628 - val_loss: 0.2769 - val_acc: 0.9260
# Epoch 310/600
# Epoch 00309: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1758 - acc: 0.9619 - val_loss: 0.2761 - val_acc: 0.9271
# Epoch 311/600
# Epoch 00310: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1757 - acc: 0.9642 - val_loss: 0.2672 - val_acc: 0.9260
# Epoch 312/600
# Epoch 00311: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1534 - acc: 0.9659 - val_loss: 0.2656 - val_acc: 0.9271
# Epoch 313/600
# Epoch 00312: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1323 - acc: 0.9696 - val_loss: 0.2569 - val_acc: 0.9295
# Epoch 314/600
# Epoch 00313: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1574 - acc: 0.9736 - val_loss: 0.2546 - val_acc: 0.9271
# Epoch 315/600
# Epoch 00314: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1495 - acc: 0.9685 - val_loss: 0.2514 - val_acc: 0.9295
# Epoch 316/600
# Epoch 00315: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1430 - acc: 0.9690 - val_loss: 0.2557 - val_acc: 0.9283
# Epoch 317/600
# Epoch 00316: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1606 - acc: 0.9682 - val_loss: 0.2508 - val_acc: 0.9295
# Epoch 318/600
# Epoch 00317: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1344 - acc: 0.9707 - val_loss: 0.2504 - val_acc: 0.9307
# Epoch 319/600
# Epoch 00318: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1531 - acc: 0.9696 - val_loss: 0.2499 - val_acc: 0.9330
# Epoch 320/600
# Epoch 00319: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1376 - acc: 0.9705 - val_loss: 0.2458 - val_acc: 0.9342
# Epoch 321/600
# Epoch 00320: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1395 - acc: 0.9724 - val_loss: 0.2478 - val_acc: 0.9295
# Epoch 322/600
# Epoch 00321: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1292 - acc: 0.9773 - val_loss: 0.2488 - val_acc: 0.9330
# Epoch 323/600
# Epoch 00322: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1308 - acc: 0.9727 - val_loss: 0.2474 - val_acc: 0.9318
# Epoch 324/600
# Epoch 00323: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1727 - acc: 0.9679 - val_loss: 0.2517 - val_acc: 0.9283
# Epoch 325/600
# Epoch 00324: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1354 - acc: 0.9724 - val_loss: 0.2535 - val_acc: 0.9271
# Epoch 326/600
# Epoch 00325: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1288 - acc: 0.9702 - val_loss: 0.2499 - val_acc: 0.9271
# Epoch 327/600
# Epoch 00326: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1574 - acc: 0.9710 - val_loss: 0.2463 - val_acc: 0.9330
# Epoch 328/600
# Epoch 00327: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1338 - acc: 0.9730 - val_loss: 0.2465 - val_acc: 0.9295
# Epoch 329/600
# Epoch 00328: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1511 - acc: 0.9724 - val_loss: 0.2477 - val_acc: 0.9318
# Epoch 330/600
# Epoch 00329: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1487 - acc: 0.9670 - val_loss: 0.2516 - val_acc: 0.9283
# Epoch 331/600
# Epoch 00330: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1338 - acc: 0.9688 - val_loss: 0.2458 - val_acc: 0.9318
# Epoch 332/600
# Epoch 00331: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1499 - acc: 0.9750 - val_loss: 0.2559 - val_acc: 0.9283
# Epoch 333/600
# Epoch 00332: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1448 - acc: 0.9682 - val_loss: 0.2550 - val_acc: 0.9283
# Epoch 334/600
# Epoch 00333: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1513 - acc: 0.9699 - val_loss: 0.2528 - val_acc: 0.9283
# Epoch 335/600
# Epoch 00334: val_loss improved from 0.24441 to 0.24173, saving model to ./VGG16s_Hybrid_woNoF/checkpoint/weights.334-0.2417.hdf5
# 55/55 [==============================] - 103s - loss: 0.1241 - acc: 0.9696 - val_loss: 0.2417 - val_acc: 0.9330
# Epoch 336/600
# Epoch 00335: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1219 - acc: 0.9773 - val_loss: 0.2427 - val_acc: 0.9318
# Epoch 337/600
# Epoch 00336: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1219 - acc: 0.9747 - val_loss: 0.2442 - val_acc: 0.9354
# Epoch 338/600
# Epoch 00337: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1400 - acc: 0.9747 - val_loss: 0.2491 - val_acc: 0.9307
# Epoch 339/600
# Epoch 00338: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1528 - acc: 0.9705 - val_loss: 0.2454 - val_acc: 0.9295
# Epoch 340/600
# Epoch 00339: val_loss improved from 0.24173 to 0.23918, saving model to ./VGG16s_Hybrid_woNoF/checkpoint/weights.339-0.2392.hdf5
# 55/55 [==============================] - 103s - loss: 0.1051 - acc: 0.9767 - val_loss: 0.2392 - val_acc: 0.9330
# Epoch 341/600
# Epoch 00340: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1277 - acc: 0.9744 - val_loss: 0.2409 - val_acc: 0.9377
# Epoch 342/600
# Epoch 00341: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1213 - acc: 0.9776 - val_loss: 0.2441 - val_acc: 0.9354
# Epoch 343/600
# Epoch 00342: val_loss improved from 0.23918 to 0.23769, saving model to ./VGG16s_Hybrid_woNoF/checkpoint/weights.342-0.2377.hdf5
# 55/55 [==============================] - 103s - loss: 0.1356 - acc: 0.9750 - val_loss: 0.2377 - val_acc: 0.9318
# Epoch 344/600
# Epoch 00343: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1317 - acc: 0.9690 - val_loss: 0.2427 - val_acc: 0.9318
# Epoch 345/600
# Epoch 00344: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1220 - acc: 0.9759 - val_loss: 0.2397 - val_acc: 0.9342
# Epoch 346/600
# Epoch 00345: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1676 - acc: 0.9685 - val_loss: 0.2465 - val_acc: 0.9307
# Epoch 347/600
# Epoch 00346: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1466 - acc: 0.9719 - val_loss: 0.2412 - val_acc: 0.9342
# Epoch 348/600
# Epoch 00347: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1199 - acc: 0.9767 - val_loss: 0.2462 - val_acc: 0.9307
# Epoch 349/600
# Epoch 00348: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1587 - acc: 0.9724 - val_loss: 0.2424 - val_acc: 0.9295
# Epoch 350/600
# Epoch 00349: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1811 - acc: 0.9724 - val_loss: 0.2398 - val_acc: 0.9307
# Epoch 351/600
# Epoch 00350: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1380 - acc: 0.9679 - val_loss: 0.2425 - val_acc: 0.9354
# Epoch 352/600
# Epoch 00351: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1232 - acc: 0.9724 - val_loss: 0.2396 - val_acc: 0.9354
# Epoch 353/600
# Epoch 00352: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1554 - acc: 0.9670 - val_loss: 0.2438 - val_acc: 0.9342
# Epoch 354/600
# Epoch 00353: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1258 - acc: 0.9702 - val_loss: 0.2417 - val_acc: 0.9307
# Epoch 355/600
# Epoch 00354: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1433 - acc: 0.9747 - val_loss: 0.2404 - val_acc: 0.9342
# Epoch 356/600
# Epoch 00355: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1426 - acc: 0.9747 - val_loss: 0.2447 - val_acc: 0.9330
# Epoch 357/600
# Epoch 00356: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1365 - acc: 0.9705 - val_loss: 0.2474 - val_acc: 0.9318
# Epoch 358/600
# Epoch 00357: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1131 - acc: 0.9761 - val_loss: 0.2482 - val_acc: 0.9330
# Epoch 359/600
# Epoch 00358: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1487 - acc: 0.9727 - val_loss: 0.2509 - val_acc: 0.9330
# Epoch 360/600
# Epoch 00359: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1463 - acc: 0.9707 - val_loss: 0.2518 - val_acc: 0.9295
# Epoch 361/600
# Epoch 00360: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1371 - acc: 0.9733 - val_loss: 0.2590 - val_acc: 0.9318
# Epoch 362/600
# Epoch 00361: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1244 - acc: 0.9685 - val_loss: 0.2582 - val_acc: 0.9283
# Epoch 363/600
# Epoch 00362: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1317 - acc: 0.9724 - val_loss: 0.2523 - val_acc: 0.9283
# Epoch 364/600
# Epoch 00363: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1096 - acc: 0.9759 - val_loss: 0.2536 - val_acc: 0.9283
# Epoch 365/600
# Epoch 00364: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1261 - acc: 0.9696 - val_loss: 0.2505 - val_acc: 0.9283
# Epoch 366/600
# Epoch 00365: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1321 - acc: 0.9770 - val_loss: 0.2506 - val_acc: 0.9295
# Epoch 367/600
# Epoch 00366: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1296 - acc: 0.9710 - val_loss: 0.2435 - val_acc: 0.9318
# Epoch 368/600
# Epoch 00367: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1381 - acc: 0.9730 - val_loss: 0.2428 - val_acc: 0.9342
# Epoch 369/600
# Epoch 00368: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1595 - acc: 0.9713 - val_loss: 0.2409 - val_acc: 0.9342
# Epoch 370/600
# Epoch 00369: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1450 - acc: 0.9693 - val_loss: 0.2430 - val_acc: 0.9330
# Epoch 371/600
# Epoch 00370: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1417 - acc: 0.9724 - val_loss: 0.2470 - val_acc: 0.9342
# Epoch 372/600
# Epoch 00371: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1259 - acc: 0.9736 - val_loss: 0.2462 - val_acc: 0.9342
# Epoch 373/600
# Epoch 00372: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1206 - acc: 0.9770 - val_loss: 0.2472 - val_acc: 0.9354
# Epoch 374/600
# Epoch 00373: val_loss did not improve
#
# Epoch 00373: reducing learning rate to 9.99999997475e-08.
# 55/55 [==============================] - 103s - loss: 0.1382 - acc: 0.9736 - val_loss: 0.2464 - val_acc: 0.9318
# Epoch 375/600
# Epoch 00374: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1123 - acc: 0.9764 - val_loss: 0.2450 - val_acc: 0.9330
# Epoch 376/600
# Epoch 00375: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1526 - acc: 0.9741 - val_loss: 0.2472 - val_acc: 0.9307
# Epoch 377/600
# Epoch 00376: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1436 - acc: 0.9710 - val_loss: 0.2467 - val_acc: 0.9318
# Epoch 378/600
# Epoch 00377: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1345 - acc: 0.9690 - val_loss: 0.2467 - val_acc: 0.9354
# Epoch 379/600
# Epoch 00378: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1613 - acc: 0.9724 - val_loss: 0.2476 - val_acc: 0.9342
# Epoch 380/600
# Epoch 00379: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1334 - acc: 0.9707 - val_loss: 0.2479 - val_acc: 0.9307
# Epoch 381/600
# Epoch 00380: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1241 - acc: 0.9744 - val_loss: 0.2477 - val_acc: 0.9318
# Epoch 382/600
# Epoch 00381: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1211 - acc: 0.9727 - val_loss: 0.2482 - val_acc: 0.9330
# Epoch 383/600
# Epoch 00382: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1415 - acc: 0.9739 - val_loss: 0.2461 - val_acc: 0.9342
# Epoch 384/600
# Epoch 00383: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1203 - acc: 0.9736 - val_loss: 0.2473 - val_acc: 0.9354
# Epoch 385/600
# Epoch 00384: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1240 - acc: 0.9716 - val_loss: 0.2462 - val_acc: 0.9330
# Epoch 386/600
# Epoch 00385: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1166 - acc: 0.9733 - val_loss: 0.2452 - val_acc: 0.9342
# Epoch 387/600
# Epoch 00386: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1410 - acc: 0.9690 - val_loss: 0.2474 - val_acc: 0.9318
# Epoch 388/600
# Epoch 00387: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1429 - acc: 0.9696 - val_loss: 0.2468 - val_acc: 0.9330
# Epoch 389/600
# Epoch 00388: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1201 - acc: 0.9764 - val_loss: 0.2451 - val_acc: 0.9318
# Epoch 390/600
# Epoch 00389: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1186 - acc: 0.9767 - val_loss: 0.2453 - val_acc: 0.9330
# Epoch 391/600
# Epoch 00390: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1346 - acc: 0.9713 - val_loss: 0.2464 - val_acc: 0.9307
# Epoch 392/600
# Epoch 00391: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1154 - acc: 0.9770 - val_loss: 0.2475 - val_acc: 0.9318
# Epoch 393/600
# Epoch 00392: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1351 - acc: 0.9716 - val_loss: 0.2462 - val_acc: 0.9307
# Epoch 394/600
# Epoch 00393: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1300 - acc: 0.9730 - val_loss: 0.2479 - val_acc: 0.9318
# Epoch 395/600
# Epoch 00394: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1192 - acc: 0.9750 - val_loss: 0.2464 - val_acc: 0.9354
# Epoch 396/600
# Epoch 00395: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1119 - acc: 0.9770 - val_loss: 0.2461 - val_acc: 0.9342
# Epoch 397/600
# Epoch 00396: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1320 - acc: 0.9673 - val_loss: 0.2475 - val_acc: 0.9330
# Epoch 398/600
# Epoch 00397: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1167 - acc: 0.9744 - val_loss: 0.2456 - val_acc: 0.9342
# Epoch 399/600
# Epoch 00398: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1174 - acc: 0.9750 - val_loss: 0.2443 - val_acc: 0.9330
# Epoch 400/600
# Epoch 00399: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1171 - acc: 0.9759 - val_loss: 0.2476 - val_acc: 0.9342
# Epoch 401/600
# Epoch 00400: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1251 - acc: 0.9753 - val_loss: 0.2455 - val_acc: 0.9330
# Epoch 402/600
# Epoch 00401: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1247 - acc: 0.9724 - val_loss: 0.2456 - val_acc: 0.9342
# Epoch 403/600
# Epoch 00402: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1219 - acc: 0.9750 - val_loss: 0.2453 - val_acc: 0.9330
# Epoch 404/600
# Epoch 00403: val_loss did not improve
#
# Epoch 00403: reducing learning rate to 1.00000001169e-08.
# 55/55 [==============================] - 103s - loss: 0.1313 - acc: 0.9702 - val_loss: 0.2456 - val_acc: 0.9342
# Epoch 405/600
# Epoch 00404: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1351 - acc: 0.9727 - val_loss: 0.2446 - val_acc: 0.9330
# Epoch 406/600
# Epoch 00405: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1317 - acc: 0.9773 - val_loss: 0.2453 - val_acc: 0.9342
# Epoch 407/600
# Epoch 00406: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1254 - acc: 0.9750 - val_loss: 0.2450 - val_acc: 0.9342
# Epoch 408/600
# Epoch 00407: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1452 - acc: 0.9722 - val_loss: 0.2440 - val_acc: 0.9354
# Epoch 409/600
# Epoch 00408: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1258 - acc: 0.9710 - val_loss: 0.2469 - val_acc: 0.9330
# Epoch 410/600
# Epoch 00409: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1269 - acc: 0.9722 - val_loss: 0.2455 - val_acc: 0.9365
# Epoch 411/600
# Epoch 00410: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1268 - acc: 0.9750 - val_loss: 0.2449 - val_acc: 0.9365
# Epoch 412/600
# Epoch 00411: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1287 - acc: 0.9730 - val_loss: 0.2464 - val_acc: 0.9318
# Epoch 413/600
# Epoch 00412: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1347 - acc: 0.9699 - val_loss: 0.2447 - val_acc: 0.9342
# Epoch 414/600
# Epoch 00413: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1255 - acc: 0.9759 - val_loss: 0.2463 - val_acc: 0.9318
# Epoch 415/600
# Epoch 00414: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1535 - acc: 0.9739 - val_loss: 0.2448 - val_acc: 0.9318
# Epoch 416/600
# Epoch 00415: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1231 - acc: 0.9787 - val_loss: 0.2447 - val_acc: 0.9354
# Epoch 417/600
# Epoch 00416: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1388 - acc: 0.9741 - val_loss: 0.2451 - val_acc: 0.9354
# Epoch 418/600
# Epoch 00417: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1310 - acc: 0.9770 - val_loss: 0.2469 - val_acc: 0.9354
# Epoch 419/600
# Epoch 00418: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1225 - acc: 0.9739 - val_loss: 0.2440 - val_acc: 0.9330
# Epoch 420/600
# Epoch 00419: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1401 - acc: 0.9739 - val_loss: 0.2460 - val_acc: 0.9354
# Epoch 421/600
# Epoch 00420: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1232 - acc: 0.9736 - val_loss: 0.2443 - val_acc: 0.9318
# Epoch 422/600
# Epoch 00421: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1143 - acc: 0.9753 - val_loss: 0.2453 - val_acc: 0.9330
# Epoch 423/600
# Epoch 00422: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1201 - acc: 0.9750 - val_loss: 0.2449 - val_acc: 0.9354
# Epoch 424/600
# Epoch 00423: val_loss did not improve
# 55/55 [==============================] - 103s - loss: 0.1360 - acc: 0.9741 - val_loss: 0.2438 - val_acc: 0.9342
# Epoch 00423: early stopping

# %%
#test prepare

test_model, test_model_name = get_best_model()
# print('Loading model from weights.004-0.0565.hdf5')
# test_model = load_model('./checkpoints/checkpoint2/weights.004-0.0565.hdf5')

def test_generator(df, mean, datagen = None, batch_size = BATCHSIZE):
    n = df.shape[0]
    batch_index = 0
    while 1:
        current_index = batch_index * batch_size
        if n >= current_index + batch_size:
            current_batch_size = batch_size
            batch_index += 1    
        else:
            current_batch_size = n - current_index
            batch_index = 0        
        batch_df = df[current_index:current_index+current_batch_size]
        batch_x = np.zeros((batch_df.shape[0], ROWS, COLS, 3), dtype=K.floatx())
        i = 0
        for index,row in batch_df.iterrows():
            image_file = row['image_file']
            bbox = [row['xmin'],row['ymin'],row['xmax'],row['ymax']]
            cropped = load_img(TEST_DIR+image_file,bbox,target_size=(ROWS,COLS))
            x = np.asarray(cropped, dtype=K.floatx())
            x /= 255.
            if datagen is not None: x = datagen.random_transform(x)            
            x = preprocess_input(x, mean)
            batch_x[i] = x
            i += 1
        if batch_index%50 == 0: print('batch_index', batch_index)
        yield(batch_x)
        
test_aug_datagen = ImageDataGenerator(
    rotation_range=180,
    shear_range=0.2,
    zoom_range=0.1,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    vertical_flip=True)
# Out:
# Loading model from checkpoint file ./VGG16s_Hybrid_woNoF/checkpoint/weights.342-0.2377.hdf5
# Loading model Done!

# %%
train_mean = [0.37698776,  0.41491762,  0.38681713]

# %%
#validation data fish logloss
 
valid_pred = test_model.predict(X_valid, batch_size=BATCHSIZE, verbose=1)
# valid_pred = test_model.predict_generator(test_generator(df=valid_df, mean=valid_mean),
#                                           val_samples=valid_df.shape[0], nb_worker=1, pickle_safe=False)
valid_logloss_df = pd.DataFrame(columns=['logloss','class'])
for i in range(y_valid.shape[0]):
    index = np.argmax(y_valid[i,:])
    fish = CROP_CLASSES[index]
    logloss = -math.log(valid_pred[i,index])
    valid_logloss_df.loc[len(valid_logloss_df)]=[logloss,fish]                                       
print('valid loss:', valid_logloss_df.groupby(['class'])['logloss'].mean())
print(valid_logloss_df['logloss'].mean())

train_pred = test_model.predict(X_train, batch_size=BATCHSIZE, verbose=1)
# train_pred = test_model.predict_generator(test_generator(df=train_df, ),
#                                           val_samples=train_df.shape[0], nb_worker=1, pickle_safe=False)
train_logloss_df = pd.DataFrame(columns=['logloss','class'])
for i in range(y_train.shape[0]):
    index = np.argmax(y_train[i,:])
    fish = CROP_CLASSES[index]
    logloss = -math.log(train_pred[i,index])
    train_logloss_df.loc[len(train_logloss_df)]=[logloss,fish]                                       
print('train loss:', train_logloss_df.groupby(['class'])['logloss'].mean())
print(train_logloss_df['logloss'].mean())
# Out:
# 851/851 [==============================] - 7s
# valid loss: class
# ALB      0.177104
# BET      0.811169
# DOL      0.373588
# LAG      0.000418
# OTHER    0.183211
# SHARK    0.481116
# YFT      0.197708
# Name: logloss, dtype: float64
# 0.24065890214
# 3520/3520 [==============================] - 32s
# train loss: class
# ALB      0.060359
# BET      0.002202
# DOL      0.000074
# LAG      0.000014
# OTHER    0.000880
# SHARK    0.000044
# YFT      0.009852
# Name: logloss, dtype: float64
# 0.0367313227023

# %%
#GTbbox_CROPpred_df = ['image_file','crop_index','crop_class','xmin','ymin','xmax','ymax',
#                      'NoF', 'ALB', 'BET', 'DOL', 'LAG', 'OTHER', 'SHARK', 'YFT', 'logloss']

file_name = 'GTbbox_CROPpred_df_'+test_model_name+'_.pickle'
if os.path.exists(OUTPUT_DIR+file_name):
    print ('Loading from file '+file_name)
    GTbbox_CROPpred_df = pd.read_pickle(OUTPUT_DIR+file_name)
else:
    print ('Generating file '+file_name) 
    nb_augmentation = 1
    if nb_augmentation ==1:
        test_preds = test_model.predict_generator(test_generator(df=GTbbox_df, mean=train_mean), 
                                                  val_samples=GTbbox_df.shape[0], nb_worker=1, pickle_safe=False)
    else:
        test_preds = np.zeros((GTbbox_df.shape[0], len(FISH_CLASSES)), dtype=K.floatx())
        for idx in range(nb_augmentation):
            print('{}th augmentation for testing ...'.format(idx+1))
            test_preds += test_model.predict_generator(test_generator(df=GTbbox_df, mean=train_mean, datagen=test_aug_datagen), 
                                                       val_samples=GTbbox_df.shape[0], nb_worker=1, pickle_safe=False)
        test_preds /= nb_augmentation

    CROPpred_df = pd.DataFrame(test_preds, columns=['ALB', 'BET', 'DOL', 'LAG', 'NoF', 'OTHER', 'SHARK', 'YFT'])
    GTbbox_CROPpred_df = pd.concat([GTbbox_df,CROPpred_df], axis=1)
    GTbbox_CROPpred_df['logloss'] = GTbbox_CROPpred_df.apply(lambda row: -math.log(row[row['crop_class']]), axis=1)
    GTbbox_CROPpred_df.to_pickle(OUTPUT_DIR+file_name) 

#logloss of every fish class
print(GTbbox_CROPpred_df.groupby(['crop_class'])['logloss'].mean())
print(GTbbox_CROPpred_df['logloss'].mean())

# %%
# RFCNbbox_RFCNpred_df = ['image_class','image_file','crop_index','xmin','ymin','xmax','ymax',
#                          'NoF_RFCN', 'ALB_RFCN', 'BET_RFCN', 'DOL_RFCN',
#                          'LAG_RFCN', 'OTHER_RFCN', 'SHARK_RFCN', 'YFT_RFCN']
# select fish_conf >= CONF_THRESH

file_name = 'RFCNbbox_RFCNpred_df_conf{:.2f}.pickle'.format(CONF_THRESH)
if os.path.exists(OUTPUT_DIR+file_name):
    print ('Loading from file '+file_name)
    RFCNbbox_RFCNpred_df = pd.read_pickle(OUTPUT_DIR+file_name)
else:
    print ('Generating file '+file_name)        
    RFCNbbox_RFCNpred_df = pd.DataFrame(columns=['image_class','image_file','crop_index','xmin','ymin','xmax','ymax',
                                                  'NoF_RFCN', 'ALB_RFCN', 'BET_RFCN', 'DOL_RFCN',
                                                  'LAG_RFCN', 'OTHER_RFCN', 'SHARK_RFCN', 'YFT_RFCN']) 

    with open('../data/RFCN_detections/detections_full_AGNOSTICnms_'+RFCN_MODEL+'.pkl','rb') as f:
        detections_full_AGNOSTICnms = pickle.load(f, encoding='latin1') 
    with open("../RFCN/ImageSets/Main/test.txt","r") as f:
        test_files = f.readlines()
    with open("../RFCN/ImageSets/Main/train_test.txt","r") as f:
        train_file_labels = f.readlines()
    assert len(detections_full_AGNOSTICnms) == len(test_files)
    
    count = np.zeros(len(detections_full_AGNOSTICnms))
    
    for im in range(len(detections_full_AGNOSTICnms)):
        if im%1000 == 0: print(im)
        basename = test_files[im][:9]
        if im<1000:
            image_class = '--'
        else:
            for i in range(len(train_file_labels)):
                if train_file_labels[i][:9] == basename:
                    image_class = train_file_labels[i][10:-1]
                    break
        image = Image.open(TEST_DIR+'/'+basename+'.jpg')
        width_image, height_image = image.size
        
        bboxes = []
        detects_im = detections_full_AGNOSTICnms[im]
        for i in range(len(detects_im)):
#             if np.sum(detects_im[i,5:]) >= CONF_THRESH:
            if np.max(detects_im[i,5:]) >= CONF_THRESH:
                bboxes.append(detects_im[i,:]) 
        count[im] = len(bboxes)
        if len(bboxes) == 0:
            ind = np.argmax(np.sum(detects_im[:,5:], axis=1))
            bboxes.append(detects_im[ind,:])
        bboxes = np.asarray(bboxes)

        for j in range(len(bboxes)):    
            bbox = bboxes[j]
            xmin = bbox[0]
            ymin = bbox[1]
            xmax = bbox[2]
            ymax = bbox[3]
            assert max(xmin,0)<min(xmax,width_image)
            assert max(ymin,0)<min(ymax,height_image)
            RFCNbbox_RFCNpred_df.loc[len(RFCNbbox_RFCNpred_df)]=[image_class,basename+'.jpg',j,max(xmin,0),max(ymin,0),
                                                                   min(xmax,width_image),min(ymax,height_image),
                                                                   bbox[4],bbox[5],bbox[6],bbox[7],bbox[8],bbox[9],bbox[10],bbox[11]]   
    
    RFCNbbox_RFCNpred_df.to_pickle(OUTPUT_DIR+file_name)

# %%
GTbbox_CROPpred_df.loc[GTbbox_CROPpred_df['crop_class']!='NoF']

# %% [raw]
# file_name = 'data_test_Crop_{}_{}.pickle'.format(ROWS, COLS)
# if os.path.exists(OUTPUT_DIR+file_name):
#     print ('Loading from file '+file_name)
#     with open(OUTPUT_DIR+file_name, 'rb') as f:
#         data_test = pickle.load(f)
#     X_test_crop = data_train['X_test_crop']
# else:
#     print ('Generating file '+file_name)
#
#     X_test_crop = np.ndarray((RFCNbbox_RFCNpred_df.shape[0], ROWS, COLS, 3), dtype=np.uint8)
#     i = 0
#     for index,row in RFCNbbox_RFCNpred_df.iterrows():
#         image_file = row['image_file']
#         bbox = [row['xmin'],row['ymin'],row['xmax'],row['ymax']]
#         cropped = load_img(TEST_DIR+image_file,bbox,target_size=(ROWS,COLS))
#         X_test_crop[i] = np.asarray(cropped)
#         i += 1
#
#     #save data to file
#     data_test = {'X_test_crop': X_test_crop}
#     with open(OUTPUT_DIR+file_name, 'wb') as f:
#         pickle.dump(data_test, f)
#
# print('Loading data done.')
# X_test_crop = X_test_crop.astype(np.float32)
# print('Convert to float32 done.')
# X_test_crop /= 255.
# print('Rescale by 255 done.')

# %%
file_name = 'data_trainfish_Crop_{}_{}.pickle'.format(ROWS, COLS)
if os.path.exists(OUTPUT_DIR+file_name):
    print ('Loading from file '+file_name)
    with open(OUTPUT_DIR+file_name, 'rb') as f:
        data_trainfish = pickle.load(f)
    X_trainfish_crop = data_train['X_trainfish_crop']
else:
    print ('Generating file '+file_name)

    GTbbox_CROPpred_fish_df = GTbbox_CROPpred_df.loc[GTbbox_CROPpred_df['crop_class']!='NoF']
    X_trainfish_crop = np.ndarray((GTbbox_CROPpred_fish_df.shape[0], ROWS, COLS, 3), dtype=np.uint8)
    i = 0
    for index,row in GTbbox_CROPpred_fish_df.iterrows():
        image_file = row['image_file']
        bbox = [row['xmin'],row['ymin'],row['xmax'],row['ymax']]
        cropped = load_img(TEST_DIR+image_file,bbox,target_size=(ROWS,COLS))
        X_trainfish_crop[i] = np.asarray(cropped)
        i += 1
   
    #save data to file
    data_trainfish = {'X_trainfish_crop': X_trainfish_crop}
    with open(OUTPUT_DIR+file_name, 'wb') as f:
        pickle.dump(data_trainfish, f)
        
print('Loading data done.')
X_trainfish_crop = X_trainfish_crop.astype(np.float32)
print('Convert to float32 done.')
X_trainfish_crop /= 255.
print('Rescale by 255 done.')

# %%
mean(X_trainfish_crop)

# %%
mean(X_test_crop[1251:])

# %%
# test_mean = [0.41019869,  0.43978861,  0.39873621]
test_mean = [0.37698776,  0.41491762,  0.38681713]

# %%
# RFCNbbox_RFCNpred_CROPpred_HYBRIDpred_df = ['image_class', 'image_file','crop_index','xmin','ymin','xmax','ymax',
#                                    'NoF_RFCN', 'ALB_RFCN', 'BET_RFCN', 'DOL_RFCN',
#                                    'LAG_RFCN', 'OTHER_RFCN', 'SHARK_RFCN', 'YFT_RFCN',
#                                    'NoF_CROP', 'ALB_CROP', 'BET_CROP', 'DOL_CROP',
#                                    'LAG_CROP', 'OTHER_CROP', 'SHARK_CROP', 'YFT_CROP',
#                                    'NoF', 'ALB', 'BET', 'DOL', 'LAG', 'OTHER', 'SHARK', 'YFT']

file_name = 'RFCNbbox_RFCNpred_CROPpred_HYBRIDpred_df_'+test_model_name+'_.pickle'
if os.path.exists(OUTPUT_DIR+file_name):
    print ('Loading from file '+file_name)
    RFCNbbox_RFCNpred_CROPpred_HYBRIDpred_df = pd.read_pickle(OUTPUT_DIR+file_name)
else:
    print ('Generating file '+file_name)  
    nb_augmentation = 1
    if nb_augmentation ==1:
        test_preds = test_model.predict_generator(test_generator(df=RFCNbbox_RFCNpred_df, mean=test_mean), 
                                                  val_samples=RFCNbbox_RFCNpred_df.shape[0], nb_worker=1, pickle_safe=False)
    else:
        test_preds = np.zeros((RFCNbbox_RFCNpred_df.shape[0], len(FISH_CLASSES)), dtype=K.floatx())
        for idx in range(nb_augmentation):
            print('{}th augmentation for testing ...'.format(idx+1))
            test_preds += test_model.predict_generator(test_generator(df=RFCNbbox_RFCNpred_df, mean=test_mean, datagen=test_aug_datagen), 
                                                       val_samples=RFCNbbox_RFCNpred_df.shape[0], nb_worker=1, pickle_safe=False)
        test_preds /= nb_augmentation

    CROPpred_df = pd.DataFrame(test_preds, columns=['ALB_CROP', 'BET_CROP', 'DOL_CROP', 'LAG_CROP', 'NoF_CROP', 'OTHER_CROP', 'SHARK_CROP', 'YFT_CROP'])
    RFCNbbox_RFCNpred_CROPpred_HYBRIDpred_df = pd.concat([RFCNbbox_RFCNpred_df,CROPpred_df], axis=1)
    
    RFCNbbox_RFCNpred_CROPpred_HYBRIDpred_df['NoF'] = RFCNbbox_RFCNpred_CROPpred_HYBRIDpred_df['NoF_RFCN']
    for fish in ['ALB', 'BET', 'DOL', 'LAG', 'OTHER', 'SHARK', 'YFT']:
        RFCNbbox_RFCNpred_CROPpred_HYBRIDpred_df[fish] = RFCNbbox_RFCNpred_CROPpred_HYBRIDpred_df.apply(lambda row: (1-row['NoF_RFCN'])*row[[fish+'_CROP']]/(1-row['NoF_CROP']) if row['NoF_CROP']!=1 else 0, axis=1)
#     for fish in FISH_CLASSES:
#         RFCNbbox_RFCNpred_CROPpred_HYBRIDpred_df[fish] = RFCNbbox_RFCNpred_CROPpred_HYBRIDpred_df[fish+'_CROP']

    RFCNbbox_RFCNpred_CROPpred_HYBRIDpred_df.to_pickle(OUTPUT_DIR+file_name)

# %%
# clsMaxAve and hybrid RFCNpred&CROPpred such that RFCNpred for NoF and CROPpred for fish
# test_pred_df = ['logloss','image_class','image_file','NoF', 'ALB', 'BET', 'DOL', 'LAG', 'OTHER', 'SHARK', 'YFT']
# RFCNbbox_RFCNpred_CROPpred_HYBRIDpred_df = ['image_class', 'image_file','crop_index','xmin','ymin','xmax','ymax',
#                                    'NoF_RFCN', 'ALB_RFCN', 'BET_RFCN', 'DOL_RFCN',
#                                    'LAG_RFCN', 'OTHER_RFCN', 'SHARK_RFCN', 'YFT_RFCN',
#                                    'ALB_CROP', 'BET_CROP', 'DOL_CROP',
#                                    'LAG_CROP', 'OTHER_CROP', 'SHARK_CROP', 'YFT_CROP',
#                                    'NoF', 'ALB', 'BET', 'DOL', 'LAG', 'OTHER', 'SHARK', 'YFT']

file_name = 'test_pred_df_Hybrid_'+test_model_name+'_.pickle'
if os.path.exists(OUTPUT_DIR+file_name):
    print ('Loading from file '+file_name)
    test_pred_df = pd.read_pickle(OUTPUT_DIR+file_name)
else:
    print ('Generating file '+file_name)  
    with open("../RFCN/ImageSets/Main/test.txt","r") as f:
        test_files = f.readlines()
    
    test_pred_df = pd.DataFrame(columns=['logloss','image_class','image_file','NoF', 'ALB', 'BET', 'DOL', 'LAG', 'OTHER', 'SHARK', 'YFT'])  
    for j in range(len(test_files)): 
        image_file = test_files[j][:-1]+'.jpg'
        test_pred_im_df = RFCNbbox_RFCNpred_CROPpred_HYBRIDpred_df.loc[RFCNbbox_RFCNpred_CROPpred_HYBRIDpred_df['image_file'] == image_file,
                                                                       ['image_class', 'NoF', 'ALB', 'BET', 'DOL', 'LAG', 'OTHER', 'SHARK', 'YFT']]
        image_class = test_pred_im_df.iloc[0]['image_class']
        test_pred_im_df.drop('image_class', axis=1, inplace=True)
        max_score = test_pred_im_df.max(axis=1)
        max_cls = test_pred_im_df.idxmax(axis=1)
        test_pred_im_df['max_score'] = max_score
        test_pred_im_df['max_cls'] = max_cls
        test_pred_im_df['Count'] = test_pred_im_df.groupby(['max_cls'])['max_cls'].transform('count')
        idx = test_pred_im_df.groupby(['max_cls'])['max_score'].transform(max) == test_pred_im_df['max_score']
        test_pred_im_clsMax_df = test_pred_im_df.loc[idx,['NoF', 'ALB', 'BET', 'DOL', 'LAG', 'OTHER', 'SHARK', 'YFT', 'Count']]
        test_pred_im_clsMax_array = test_pred_im_clsMax_df.values
        pred = np.average(test_pred_im_clsMax_array[:,:-1], axis=0, weights=test_pred_im_clsMax_array[:,-1], returned=False).tolist()
        if image_class!='--':
            ind = FISH_CLASSES.index(image_class)
            logloss = -math.log(pred[ind]) 
        else:
            logloss = np.nan
        test_pred_im_clsMaxAve = [logloss,image_class,image_file]
        test_pred_im_clsMaxAve.extend(pred)
        test_pred_df.loc[len(test_pred_df)]=test_pred_im_clsMaxAve

    test_pred_df.to_pickle(OUTPUT_DIR+file_name)

# %%
#### visualization
# RFCNbbox_RFCNpred_CROPpred_df = ['image_class', 'image_file','crop_index','x_min','y_min','x_max','ymax',
#                                    'NoF_RFCN', 'ALB_RFCN', 'BET_RFCN', 'DOL_RFCN',
#                                    'LAG_RFCN', 'OTHER_RFCN', 'SHARK_RFCN', 'YFT_RFCN'
#                                    'NoF_CROP', 'ALB_CROP', 'BET_CROP', 'DOL_CROP',
#                                    'LAG_CROP', 'OTHER_CROP', 'SHARK_CROP', 'YFT_CROP']
#GTbbox_CROPpred_df = ['image_file','crop_index','crop_class','xmin','ymin','xmax','ymax',
#                      'NoF', 'ALB', 'BET', 'DOL', 'LAG', 'OTHER', 'SHARK', 'YFT', 'logloss']
# test_pred_df = ['logloss','image_class','image_file','NoF', 'ALB', 'BET', 'DOL', 'LAG', 'OTHER', 'SHARK', 'YFT']

for j in range(test_pred_df.shape[0]):
    image_logloss = test_pred_df.iat[j,0]
    image_class = test_pred_df.iat[j,1]
    image_file = test_pred_df.iat[j,2]
    if j<1000 and j%30== 0:
        pass
    else: 
        continue
    im = Image.open('../RFCN/JPEGImages/'+image_file)
    im = np.asarray(im)
    fig, ax = plt.subplots(figsize=(10, 8))
    ax.imshow(im, aspect='equal')
    RFCN_dets = RFCNbbox_RFCNpred_CROPpred_HYBRIDpred_df.loc[RFCNbbox_RFCNpred_CROPpred_HYBRIDpred_df['image_file']==image_file]
    for index,row in RFCN_dets.iterrows():
        bbox = [row['xmin'],row['ymin'],row['xmax'],row['ymax']]
        RFCN = [row['NoF_RFCN'],row['ALB_RFCN'],row['BET_RFCN'],row['DOL_RFCN'],row['LAG_RFCN'],row['OTHER_RFCN'],row['SHARK_RFCN'],row['YFT_RFCN']]
        CROP = [row['NoF'],row['ALB'],row['BET'],row['DOL'],row['LAG'],row['OTHER'],row['SHARK'],row['YFT']]
        score_RFCN = max(RFCN)
        score_CROP = max(CROP)
        index_RFCN = RFCN.index(score_RFCN)
        index_CROP = CROP.index(score_CROP)
        class_RFCN = FISH_CLASSES[index_RFCN]
        class_CROP = FISH_CLASSES[index_CROP]
        ax.add_patch(plt.Rectangle((bbox[0], bbox[1]), bbox[2] - bbox[0], bbox[3] - bbox[1], fill=False, edgecolor='red', linewidth=2))
        ax.text(bbox[0], bbox[1] - 2, 'RFCN_{:s} {:.3f} \nHYBRID_{:s} {:.3f}'.format(class_RFCN, score_RFCN, class_CROP, score_CROP), bbox=dict(facecolor='red', alpha=0.5), fontsize=8, color='white')       
    GT_dets = GTbbox_CROPpred_df.loc[GTbbox_CROPpred_df['image_file']==image_file]
    for index,row in GT_dets.iterrows():
        bbox = [row['xmin'],row['ymin'],row['xmax'],row['ymax']]
        CROP = [row['NoF'],row['ALB'],row['BET'],row['DOL'],row['LAG'],row['OTHER'],row['SHARK'],row['YFT']]
        score_CROP = max(CROP)
        index_CROP = CROP.index(score_CROP)
        class_CROP = FISH_CLASSES[index_CROP]
        ax.add_patch(plt.Rectangle((bbox[0], bbox[1]), bbox[2] - bbox[0], bbox[3] - bbox[1], fill=False, edgecolor='green', linewidth=2))
        ax.text(bbox[0], bbox[3] + 40, 'GT_{:s} \nCROP_{:s} {:.3f}'.format(row['crop_class'], class_CROP, score_CROP), bbox=dict(facecolor='green', alpha=0.5), fontsize=8, color='white')
    ax.set_title(('Image {:s}    FISH {:s}    logloss {}').format(image_file, image_class, image_logloss), fontsize=10) 
    plt.axis('off')
    plt.tight_layout()
    plt.draw()

# %%
#temperature
T = 1
test_pred_array = test_pred_df[FISH_CLASSES].values
test_pred_T_array = np.exp(np.log(test_pred_array)/T)
test_pred_T_array = test_pred_T_array/np.sum(test_pred_T_array, axis=1, keepdims=True)
test_pred_T_df = pd.DataFrame(test_pred_T_array, columns=FISH_CLASSES)
test_pred_T_df = pd.concat([test_pred_df[['image_class','image_file']],test_pred_T_df], axis=1)

#add logloss
test_pred_T_df['logloss'] = test_pred_T_df.apply(lambda row: -math.log(row[row['image_class']]) if row['image_class']!='--' else np.nan, axis=1)

#calculate train logloss
print(test_pred_T_df.groupby(['image_class'])['logloss'].mean())
train_logloss = test_pred_T_df['logloss'].mean()
print('logloss of train is', train_logloss )

# %%
#test submission
submission = test_pred_T_df.loc[:999,['image_file','NoF', 'ALB', 'BET', 'DOL', 'LAG', 'OTHER', 'SHARK', 'YFT']]
submission.rename(columns={'image_file':'image'}, inplace=True)
sub_file = 'RFCN_AGONOSTICnms_'+RFCN_MODEL+'_'+CROP_MODEL+'_clsMaxAve_conf{:.2f}_T{}_'.format(CONF_THRESH, T)+'{:.4f}'.format(train_logloss)+'.csv'
submission.to_csv(sub_file, index=False)
print('Done!'+sub_file)

# %%
def create_model_VGG10s():
    model = Sequential()

    model.add(Conv2D(32, (3, 3), padding='same', name='block1_conv1', input_shape=(ROWS, COLS, 3)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.33))
    model.add(Conv2D(32, (3, 3), strides=(2, 2), padding='same', name='block1_conv2'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.33))
    
    model.add(Conv2D(64, (3, 3), padding='same', name='block2_conv1'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.33))
    model.add(Conv2D(64, (3, 3), strides=(2, 2), padding='same', name='block2_conv2'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.33))

    model.add(Conv2D(128, (3, 3), padding='same', name='block3_conv1'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.33))
    model.add(Conv2D(128, (3, 3), strides=(2, 2), padding='same', name='block3_conv2'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.33))
    
    model.add(Conv2D(256, (3, 3), padding='same', name='block4_conv1'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.33))
    model.add(Conv2D(256, (3, 3), strides=(2, 2), padding='same', name='block4_conv2'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.33))
    
    model.add(Conv2D(256, (3, 3), padding='same', name='block5_conv1'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.33))
    model.add(Conv2D(256, (3, 3), strides=(2, 2), padding='same', name='block5_conv2'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.33))
    
    model.add(Flatten())
#     model.add(GlobalAveragePooling2D())
#     model.add(Dense(512, activation='relu'))
#     model.add(Dropout(0.8))
    model.add(Dense(len(CROP_CLASSES), activation='softmax'))

    return model

# %%
def create_model_VGG10():
    model = Sequential()

    model.add(Conv2D(64, (3, 3), padding='same', name='block1_conv1', input_shape=(ROWS, COLS, 3)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.33))
    model.add(Conv2D(64, (3, 3), strides=(2, 2), padding='same', name='block1_conv2'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.33))
    
    model.add(Conv2D(128, (3, 3), padding='same', name='block2_conv1'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.33))
    model.add(Conv2D(128, (3, 3), strides=(2, 2), padding='same', name='block2_conv2'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.33))

    model.add(Conv2D(256, (3, 3), padding='same', name='block3_conv1'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.33))
    model.add(Conv2D(256, (3, 3), strides=(2, 2), padding='same', name='block3_conv2'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.33))
    
    model.add(Conv2D(512, (3, 3), padding='same', name='block4_conv1'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.33))
    model.add(Conv2D(512, (3, 3), strides=(2, 2), padding='same', name='block4_conv2'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.33))
    
    model.add(Conv2D(512, (3, 3), padding='same', name='block5_conv1'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.33))
    model.add(Conv2D(512, (3, 3), strides=(2, 2), padding='same', name='block5_conv2'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.33))
    
    model.add(Flatten())
#     model.add(GlobalAveragePooling2D())
#     model.add(Dense(512, activation='relu'))
#     model.add(Dropout(0.8))
    model.add(Dense(len(CROP_CLASSES), activation='softmax'))

    return model

# %%
def create_model_VGG13s():
    model = Sequential()

    model.add(Conv2D(32, (3, 3), padding='same', name='block1_conv1', input_shape=(ROWS, COLS, 3)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.33))
    model.add(Conv2D(32, (3, 3), strides=(2, 2), padding='same', name='block1_conv2'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.33))
    
    model.add(Conv2D(64, (3, 3), padding='same', name='block2_conv1'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.33))
    model.add(Conv2D(64, (3, 3), strides=(2, 2), padding='same', name='block2_conv2'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.33))

    model.add(Conv2D(128, (3, 3), padding='same', name='block3_conv1'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.33))
    model.add(Conv2D(128, (3, 3), padding='same', name='block3_conv2'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.33))
    model.add(Conv2D(128, (3, 3), strides=(2, 2), padding='same', name='block3_conv3'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.33))
    
    model.add(Conv2D(256, (3, 3), padding='same', name='block4_conv1'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.33))
    model.add(Conv2D(256, (3, 3), padding='same', name='block4_conv2'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.33))
    model.add(Conv2D(256, (3, 3), strides=(2, 2), padding='same', name='block4_conv3'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.33))
    
    model.add(Conv2D(256, (3, 3), padding='same', name='block5_conv1'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.33))
    model.add(Conv2D(256, (3, 3), padding='same', name='block5_conv2'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.33))
    model.add(Conv2D(256, (3, 3), strides=(2, 2), padding='same', name='block5_conv3'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.33))
    
    model.add(Flatten())
#     model.add(GlobalAveragePooling2D())
#     model.add(Dense(256, activation='relu'))
#     model.add(Dropout(0.8))
    model.add(Dense(len(CROP_CLASSES), activation='softmax'))

    return model

# %%
def create_model_VGG13():
    model = Sequential()

    model.add(Conv2D(64, (3, 3), padding='same', name='block1_conv1', input_shape=(ROWS, COLS, 3)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.33))
    model.add(Conv2D(64, (3, 3), strides=(2, 2), padding='same', name='block1_conv2'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.33))
    
    model.add(Conv2D(128, (3, 3), padding='same', name='block2_conv1'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.33))
    model.add(Conv2D(128, (3, 3), strides=(2, 2), padding='same', name='block2_conv2'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.33))

    model.add(Conv2D(256, (3, 3), padding='same', name='block3_conv1'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.33))
    model.add(Conv2D(256, (3, 3), padding='same', name='block3_conv2'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.33))
    model.add(Conv2D(256, (3, 3), strides=(2, 2), padding='same', name='block3_conv3'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.33))
    
    model.add(Conv2D(512, (3, 3), padding='same', name='block4_conv1'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.33))
    model.add(Conv2D(512, (3, 3), padding='same', name='block4_conv2'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.33))
    model.add(Conv2D(512, (3, 3), strides=(2, 2), padding='same', name='block4_conv3'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.33))
    
    model.add(Conv2D(512, (3, 3), padding='same', name='block5_conv1'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.33))
    model.add(Conv2D(512, (3, 3), padding='same', name='block5_conv2'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.33))
    model.add(Conv2D(512, (3, 3), strides=(2, 2), padding='same', name='block5_conv3'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.33))
    
    model.add(Flatten())
#     model.add(GlobalAveragePooling2D())
#     model.add(Dense(512, activation='relu'))
#     model.add(Dropout(0.8))
    model.add(Dense(len(CROP_CLASSES), activation='softmax'))

    return model

# %%
def create_model_VGG16():
    model = Sequential()

    model.add(Conv2D(64, (3, 3), padding='same', name='block1_conv1', input_shape=(ROWS, COLS, 3)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.33))
    model.add(Conv2D(64, (3, 3), strides=(2, 2), padding='same', name='block1_conv2'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.33))
    
    model.add(Conv2D(128, (3, 3), padding='same', name='block2_conv1'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.33))
    model.add(Conv2D(128, (3, 3), strides=(2, 2), padding='same', name='block2_conv2'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.33))
    
    model.add(Conv2D(256, (3, 3), padding='same', name='block3_conv1'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.33))
    model.add(Conv2D(256, (3, 3), padding='same', name='block3_conv2'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.33))
    model.add(Conv2D(256, (3, 3), padding='same', name='block3_conv3'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.33))
    model.add(Conv2D(256, (3, 3), strides=(2, 2), padding='same', name='block3_conv4'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.33))
    
    model.add(Conv2D(512, (3, 3), padding='same', name='block4_conv1'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.33))
    model.add(Conv2D(512, (3, 3), padding='same', name='block4_conv2'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.33))
    model.add(Conv2D(512, (3, 3), padding='same', name='block4_conv3'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.33))
    model.add(Conv2D(512, (3, 3), strides=(2, 2), padding='same', name='block4_conv4'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.33))
    
    model.add(Conv2D(512, (3, 3), padding='same', name='block5_conv1'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.33))
    model.add(Conv2D(512, (3, 3), padding='same', name='block5_conv2'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.33))
    model.add(Conv2D(512, (3, 3), padding='same', name='block5_conv3'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.33))
    model.add(Conv2D(512, (3, 3), strides=(2, 2), padding='same', name='block5_conv4'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.33))
    
    model.add(Flatten())
#     model.add(GlobalAveragePooling2D())
#     model.add(Dense(512, activation='relu'))
#     model.add(Dropout(0.8))
    model.add(Dense(len(CROP_CLASSES), activation='softmax'))

    return model
